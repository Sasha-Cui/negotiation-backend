# %% [markdown]
# # 🏘️ Main Street Negotiation - Comprehensive Analysis Dashboard
#
# Complete analysis of Main Street real estate negotiations (Fred Starr vs Rosalind Cain)
#
# **Analysis Sections:**
# 1. 📋 All Negotiation Records Overview
# 2. 👥 Student Demographics & Characteristics Analysis
# 3. 💰 Configuration Comparison: Base vs M vs M+P (Price Analysis)
# 4. 🧠 Memory (M) Evolution Tracking
# 5. 🎯 Planning (P) Strategy Tracking
# 6. 💬 Full Transcript Viewer
# 7. 📊 Performance Metrics Dashboard
#
# ---

# %% [markdown]
# ## Setup

# %%
import sqlite3
import pandas as pd
import json
import numpy as np
from datetime import datetime
from IPython.display import display, HTML, Markdown
import warnings
warnings.filterwarnings('ignore')

# ==================== CONFIGURATION ====================
DB_PATH = "negotiations_mainst.db"  #
SCENARIO_FILTER = "Main_Street"  # Focus on Main Street scenario

conn = sqlite3.connect(DB_PATH)
print(f"✅ Connected to: {DB_PATH}")
print(f"🎯 Analyzing scenario: {SCENARIO_FILTER}")
# Out:
# ✅ Connected to: negotiations_mainst.db
# 🎯 Analyzing scenario: Main_Street

# %%
# 在 df_all = pd.read_sql_query(query_all, conn) 之前添加：

# ==================== PANDAS DISPLAY SETTINGS ====================
pd.set_option('display.max_rows', None)  # 显示所有行
pd.set_option('display.max_columns', None)  # 显示所有列
pd.set_option('display.width', None)  # 自动调整宽度
pd.set_option('display.max_colwidth', 50)  # 列内容最大宽度

# %%
# Helper Functions
def safe_json_load(json_str):
    if not json_str or json_str == 'null':
        return None
    try:
        return json.loads(json_str)
    except:
        return None

def calculate_duration(start, end):
    try:
        return (pd.to_datetime(end) - pd.to_datetime(start)).total_seconds() / 60
    except:
        return None

def get_config_label(use_memory, use_plan):
    if use_memory and use_plan:
        return 'M+P'
    elif use_memory:
        return 'M'
    elif use_plan:
        return 'P'
    else:
        return 'Base'

def print_header(title, char='=', width=100):
    print("\n" + char * width)
    print(f"{title.center(width)}")
    print(char * width + "\n")

def print_subheader(title, char='-', width=80):
    print("\n" + char * width)
    print(title)
    print(char * width)

print("✅ Helper functions loaded")
# Out:
# ✅ Helper functions loaded

# %% [markdown]
# ---
# ## 1. 📋 All Negotiation Records Overview
#
# Complete list of all Main Street negotiations

# %%
# Load all Main Street sessions
query_all = f"""
SELECT 
    session_id,
    student_role,
    ai_model,
    student_goes_first,
    use_memory,
    use_plan,
    total_rounds,
    deal_reached,
    deal_failed,
    status,
    created_at,
    updated_at,
    major,
    gender,
    negotiation_experience,
    transcript,
    student_deal_json,
    ai_deal_json
FROM negotiation_sessions
WHERE scenario_name = '{SCENARIO_FILTER}'
ORDER BY created_at DESC
"""

df_all = pd.read_sql_query(query_all, conn)

# Add derived columns
df_all['Config'] = df_all.apply(lambda r: get_config_label(r['use_memory'], r['use_plan']), axis=1)
df_all['Duration (min)'] = df_all.apply(lambda r: calculate_duration(r['created_at'], r['updated_at']), axis=1)
df_all['Outcome'] = df_all.apply(lambda r: 
    '✅ Deal' if r['deal_reached'] 
    else '❌ Failed' if r['deal_failed'] 
    else '⏸️ Incomplete', axis=1)

df_all['Role'] = df_all['student_role'].map({
    'side1': '🏢 Buyer (Fred)',
    'side2': '🏘️ Seller (Rosalind)'
})

print_header("📋 ALL MAIN STREET NEGOTIATIONS")
print(f"Total Sessions: {len(df_all)}")
print(f"Successful Deals: {df_all['deal_reached'].sum()}")
print(f"Failed Negotiations: {df_all['deal_failed'].sum()}")
print(f"Incomplete: {(~df_all['deal_reached'] & ~df_all['deal_failed']).sum()}")

print(f"\n📊 Configuration Breakdown:")
print(df_all['Config'].value_counts().to_string())

print(f"\n🎭 Role Distribution:")
print(df_all['Role'].value_counts().to_string())

# Display table
display_df = df_all[[
    'session_id', 'Role', 'Config', 'Outcome',
    'major', 'gender', 'negotiation_experience',  
    'Duration (min)', 'created_at'
]].copy()

display_df['session_id'] = display_df['session_id'].str[:8]
display_df['created_at'] = pd.to_datetime(display_df['created_at']).dt.strftime('%Y-%m-%d %H:%M')
display_df['Duration (min)'] = display_df['Duration (min)'].round(1)


display_df.columns = ['Session', 'Role', 'Config', 'Outcome', 'Major', 'Gender', 'Exp', 'Duration', 'Created']

print("\n" + "="*150) 
display(display_df)
# Out:
# ====================================================================================================
#                                    📋 ALL MAIN STREET NEGOTIATIONS
# ====================================================================================================
#
# Total Sessions: 154
# Successful Deals: 81
# Failed Negotiations: 2
# Incomplete: -237
#
# 📊 Configuration Breakdown:
# Config
# Base    86
# M+P     68
#
# 🎭 Role Distribution:
# Role
# 🏘️ Seller (Rosalind)    149
# 🏢 Buyer (Fred)            5
#
# ======================================================================================================================================================
#       Session                  Role Config        Outcome  \
# 0    f81e9731  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 1    b37f26ac  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 2    33f1a7e7  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 3    1da9f9c4  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 4    0ad06bea  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 5    d0f674cd  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 6    799f52db  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 7    95e44a5d  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 8    16eceb2c  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 9    798d365f        🏢 Buyer (Fred)   Base         ✅ Deal
# 10   31db345d  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 11   88bdd965  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 12   50f35769  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 13   1c047b8c  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 14   1accb1db  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 15   bb74becf  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 16   91bf642e  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 17   7443cda3  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 18   938b042a  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 19   562a5935  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 20   0b0c3e36  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 21   efc8ced7  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 22   e4db51d8  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 23   2707b436  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 24   98028e11  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 25   9864a8ac  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 26   19189653  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 27   65568ba8  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 28   09116786  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 29   350ef762  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 30   f8b904d4  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 31   2b985adf  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 32   538cd73f  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 33   516685e6  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 34   ee8d9c66  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 35   d08ef3f9  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 36   e00fe024  🏘️ Seller (Rosalind)   Base       ❌ Failed
# 37   4eb7d6b7  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 38   0edb4787  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 39   b19200a0  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 40   4240e9c5  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 41   6c890dba  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 42   20b90946  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 43   47ccd90e  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 44   aaf88b7e  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 45   fef88ef0  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 46   f8108b66  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 47   cba42d83  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 48   c18ba8b7  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 49   21380327  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 50   44902306  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 51   9b40af5c  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 52   519ed03e  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 53   d61b1421  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 54   8f327691  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 55   49f9367b  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 56   def6ce77  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 57   a6587ccb  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 58   ff4187e1  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 59   2c58997c  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 60   1c64c52d  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 61   22e1c990  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 62   320f365c  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 63   583603ec  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 64   f727eff6  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 65   24a24ce4  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 66   a027bad3  🏘️ Seller (Rosalind)   Base       ❌ Failed
# 67   da8e805c  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 68   bb4f01c8  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 69   6ba03567  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 70   fefa4d90  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 71   3ce4dbec  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 72   53c67d59  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 73   fae036e8  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 74   e014a8cd  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 75   bf242471  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 76   daa71a3a  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 77   187ee6e1  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 78   7ab01b6d  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 79   a5a7bbed  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 80   f0c044d9  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 81   cba8d9c9  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 82   dd354523  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 83   5c9d6f09  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 84   118af3de  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 85   486f9419  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 86   13697589  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 87   81eafc5a  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 88   fe68b67b  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 89   a5291dbb  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 90   baf91c79  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 91   f167c9c9  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 92   ed40d7bb  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 93   9a00be6e  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 94   da734cf6  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 95   023fa610  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 96   2e473faf  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 97   35cd2da6  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 98   73297254  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 99   34bd3d91  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 100  fef6c2b3  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 101  e15e86b4  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 102  cdb4b68d  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 103  33365183  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 104  fabc68b2  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 105  526567fb  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 106  6a1f1023  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 107  746b9508  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 108  2527e1ea  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 109  4093ffc5  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 110  073b248f  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 111  82de1f8e  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 112  20260374  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 113  8fe436e8  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 114  c29a5a57  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 115  7fe2649b  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 116  7f6097c2  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 117  71b68756  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 118  2c8f497a  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 119  30fb5303  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 120  839df400  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 121  2d8133ce  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 122  c909aecd  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 123  d32b69d6  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 124  875b6386  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 125  78b1039b  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 126  e6dcac4e  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 127  8a73a6b2  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 128  b8e3a740  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 129  452f8c2b  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 130  59abb8e6  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 131  e5b6107b  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 132  d1c19ae5  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 133  ac9d1e05  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 134  7b0da794  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 135  865142bf  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 136  c38e57af  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 137  a9418128  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 138  05013a9d  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 139  c0f1968e  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 140  aad0413f  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 141  8489341a        🏢 Buyer (Fred)   Base  ⏸️ Incomplete
# 142  bd69dd72        🏢 Buyer (Fred)   Base  ⏸️ Incomplete
# 143  97a5581f  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 144  8b6b248e        🏢 Buyer (Fred)   Base  ⏸️ Incomplete
# 145  caa1b230        🏢 Buyer (Fred)   Base  ⏸️ Incomplete
# 146  490f8110  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 147  e4be60ec  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 148  f981cb0e  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 149  addb2ad6  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 150  9992a0ff  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 151  7271f344  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 152  67f91417  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 153  bbb6c9f7  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
#
#                                        Major      Gender              Exp  \
# 0                                        MBA        Male  A few instances
# 1                                    Theater      Female       Occasional
# 2                                    Theater      Female       Occasional
# 3                                        GBS
# 4                                        MBA
# 5                                        GBS
# 6                               MBA Exchange              A few instances
# 7                                        MBA        Male  A few instances
# 8                                        GBS      Female  A few instances
# 9                                        MBA        Male  A few instances
# 10                                      Tech        Male       Occasional
# 11
# 12                                  Business        Male  A few instances
# 13
# 14               Global Business and Society        Male       Occasional
# 15                                  Business        Male             None
# 16                                       MBA      Female       Occasional
# 17                                       GBS      Female
# 18                                    2Y MBA      Female  A few instances
# 19                                       GBS      Female       Occasional
# 20                                       GBS      Female  A few instances
# 21                                       MBA      Female       Occasional
# 22                                       MBA      Female       Occasional
# 23                                   Theater      Female       Occasional
# 24
# 25                                       GBS      Female  A few instances
# 26                                       MBA        Male  A few instances
# 27                                       MBA
# 28                                Management        Male  A few instances
# 29
# 30                      School of Management        Male  A few instances
# 31                                       GBS      Female  A few instances
# 32                                       MBA
# 33                                       GBS        Male  A few instances
# 34                     Healthcare Management      Female  A few instances
# 35                                                  Male  A few instances
# 36                                       MBA        Male  A few instances
# 37                                       MBA        Male  A few instances
# 38                                       GBS      Female  A few instances
# 39                                       MBA        Male  A few instances
# 40                                       MBA        Male  A few instances
# 41   Master of Business Administration (MBA)        Male             None
# 42                                Management        Male       Occasional
# 43                                       SDS
# 44                                       SDS
# 45                                       GBS      Female       Occasional
# 46                        Health Informatics      Female             None
# 47                                       SDS
# 48                                       SDS
# 49                                       SDS
# 50                                  Business
# 51                                       SDS
# 52                                Management        Male  A few instances
# 53
# 54
# 55                                  Business
# 56                             public health      Female             None
# 57                                       MBA        Male         Frequent
# 58                                       GBS      Female  A few instances
# 59                 Global Business & Society        Male       Occasional
# 60                 Global Business & Society        Male  A few instances
# 61                                       GBS      Female  A few instances
# 62                                       GBS      Female             None
# 63                                       GBS        Male             None
# 64                    Mechanical Engineering        Male       Occasional
# 65                                       GBS        Male  A few instances
# 66                                       GBS        Male     Professional
# 67                                Management        Male             None
# 68                                       MBA      Female       Occasional
# 69                 Global Business & Society        Male  A few instances
# 70                                Management      Female  A few instances
# 71
# 72                                  Business        Male       Occasional
# 73                        Management Science      Female       Occasional
# 74                     Technology Management        Male       Occasional
# 75                                       MBA      Female  A few instances
# 76         Master of Business Administration        Male             None
# 77                                       MBA        Male         Frequent
# 78                                       MBA        Male  A few instances
# 79                                       GBS      Female  A few instances
# 80                                       GBS      Female  A few instances
# 81                        Management Science        Male             None
# 82                                       MBA        Male  A few instances
# 83                            Yale SOM - GBS      Female       Occasional
# 84                                       MBA        Male  A few instances
# 85                                       MBA        Male  A few instances
# 86                             Arrchitecture        Male  A few instances
# 87                                Management      Female  A few instances
# 88                  Master in Management GBS      Female
# 89                                       GBS      Female         Frequent
# 90                               Mathematics        Male  A few instances
# 91                 Global Business & Society        Male       Occasional
# 92               Global Business and Society  Non-binary       Occasional
# 93
# 94                          Asset Management        Male  A few instances
# 95                             public health      Female             None
# 96            Masters of Advanced Management        Male       Occasional
# 97                                Management        Male             None
# 98                    Mechanical Engineering        Male       Occasional
# 99         Master of Business Administration      Female  A few instances
# 100                                      GBS        Male             None
# 101                                      GBS      Female  A few instances
# 102                           Global Affairs        Male  A few instances
# 103                                      MBA        Male       Occasional
# 104                               Management        Male  A few instances
# 105
# 106                               Management        Male       Occasional
# 107
# 108                                      MBA        Male  A few instances
# 109              Global business and society        Male  A few instances
# 110                                      Law        Male             None
# 111                               Management        Male       Occasional
# 112              Global Business and Society              A few instances
# 113                               Management        Male       Occasional
# 114                                      MBA
# 115                                      MBA        Male         Frequent
# 116                       Management Science        Male       Occasional
# 117                                      SDS
# 118                                     prof        Male     Professional
# 119
# 120                                      SDS
# 121                                      SDS
# 122                                      SDS
# 123                                      SDS
# 124                                      SDS
# 125                                      SDS
# 126                                      SDS
# 127                                      SDS
# 128                                      SDS
# 129                                      SDS
# 130                                      SDS        Male     Professional
# 131                                      SDS      Female         Frequent
# 132                                      SDS        Male       Occasional
# 133                                      SDS        Male  A few instances
# 134                                      SDS
# 135                                      SDS        Male         Frequent
# 136                                      SDS        Male             None
# 137                                      SDS        Male     Professional
# 138                                      SDS        Male       Occasional
# 139                                      SDS
# 140                                     prof        Male     Professional
# 141                                      sds
# 142                                      sds
# 143                                      sds
# 144                                      sds        Male
# 145                                      SDS        Male
# 146                                      sds
# 147                                      SDS
# 148                                     prof        Male     Professional
# 149                                      SDS
# 150                                     prof        Male     Professional
# 151                                      SDS
# 152                                      SDS        Male       Occasional
# 153                                      SDS        Male       Occasional
#
#      Duration           Created
# 0         7.2  2025-12-10 20:01
# 1         7.1  2025-12-10 19:52
# 2         0.8  2025-12-10 19:51
# 3        29.1  2025-12-10 19:49
# 4        11.4  2025-12-10 19:44
# 5         0.0  2025-12-10 19:44
# 6        27.0  2025-12-10 19:39
# 7         8.7  2025-12-10 19:38
# 8        42.6  2025-12-10 19:37
# 9        12.4  2025-12-10 19:36
# 10       22.7  2025-12-10 19:35
# 11       20.5  2025-12-10 19:35
# 12       20.2  2025-12-10 19:35
# 13       25.3  2025-12-10 19:35
# 14       44.0  2025-12-10 19:35
# 15       18.4  2025-12-10 19:35
# 16       20.2  2025-12-10 19:34
# 17       18.1  2025-12-10 19:34
# 18       19.5  2025-12-10 19:34
# 19       24.7  2025-12-10 19:33
# 20        0.9  2025-12-10 19:33
# 21       24.0  2025-12-10 19:33
# 22        1.2  2025-12-10 19:32
# 23       13.5  2025-12-10 19:32
# 24       25.4  2025-12-10 19:31
# 25       20.3  2025-12-10 19:31
# 26       31.8  2025-12-10 19:31
# 27       26.6  2025-12-10 19:30
# 28       29.2  2025-12-10 19:29
# 29        0.6  2025-12-10 19:29
# 30       41.2  2025-12-10 19:28
# 31       49.8  2025-12-10 19:28
# 32        0.6  2025-12-10 19:28
# 33       38.1  2025-12-10 19:28
# 34       23.7  2025-12-10 19:27
# 35       34.2  2025-12-10 19:26
# 36       40.9  2025-12-10 19:25
# 37       11.5  2025-12-10 19:23
# 38       29.3  2025-12-10 19:23
# 39        9.9  2025-12-10 19:23
# 40       12.7  2025-12-10 19:23
# 41       16.6  2025-12-10 19:22
# 42        0.0  2025-12-10 19:21
# 43        0.0  2025-12-10 17:30
# 44        0.0  2025-12-10 17:23
# 45       30.3  2025-12-10 15:48
# 46       16.4  2025-12-10 15:37
# 47        1.0  2025-12-10 15:28
# 48        0.5  2025-12-10 15:28
# 49        0.0  2025-12-10 15:28
# 50        0.5  2025-12-10 15:28
# 51        0.0  2025-12-10 15:28
# 52        0.0  2025-12-10 15:25
# 53       11.9  2025-12-10 15:10
# 54       18.6  2025-12-10 15:09
# 55        0.5  2025-12-10 15:09
# 56       11.0  2025-12-10 15:07
# 57        0.6  2025-12-10 15:01
# 58       20.5  2025-12-10 15:00
# 59        9.2  2025-12-10 14:59
# 60       14.9  2025-12-10 14:57
# 61        8.5  2025-12-10 14:52
# 62       17.3  2025-12-10 14:50
# 63       17.6  2025-12-10 14:50
# 64        0.7  2025-12-10 14:49
# 65       15.0  2025-12-10 14:49
# 66       20.4  2025-12-10 14:48
# 67       29.4  2025-12-10 14:48
# 68       11.5  2025-12-10 14:48
# 69        4.9  2025-12-10 14:48
# 70       28.4  2025-12-10 14:48
# 71       21.9  2025-12-10 14:47
# 72       30.1  2025-12-10 14:47
# 73       20.8  2025-12-10 14:47
# 74       32.3  2025-12-10 14:47
# 75       10.9  2025-12-10 14:47
# 76       26.5  2025-12-10 14:47
# 77       18.6  2025-12-10 14:47
# 78       19.1  2025-12-10 14:47
# 79       25.2  2025-12-10 14:47
# 80       11.3  2025-12-10 14:46
# 81       21.2  2025-12-10 14:46
# 82        8.0  2025-12-10 14:46
# 83       24.1  2025-12-10 14:46
# 84       13.8  2025-12-10 14:46
# 85       15.6  2025-12-10 14:46
# 86       22.9  2025-12-10 14:46
# 87       23.0  2025-12-10 14:45
# 88       18.6  2025-12-10 14:45
# 89       40.5  2025-12-10 14:45
# 90       29.5  2025-12-10 14:45
# 91       11.8  2025-12-10 14:44
# 92       31.0  2025-12-10 14:44
# 93       18.4  2025-12-10 14:43
# 94       33.9  2025-12-10 14:43
# 95       18.3  2025-12-10 14:43
# 96       22.3  2025-12-10 14:43
# 97       28.1  2025-12-10 14:42
# 98        6.7  2025-12-10 14:42
# 99       31.4  2025-12-10 14:41
# 100      32.3  2025-12-10 14:41
# 101      34.2  2025-12-10 14:40
# 102      27.1  2025-12-10 14:40
# 103      41.2  2025-12-10 14:39
# 104      42.7  2025-12-10 14:39
# 105      24.5  2025-12-10 14:39
# 106      28.9  2025-12-10 14:39
# 107      34.9  2025-12-10 14:39
# 108      18.6  2025-12-10 14:39
# 109      21.2  2025-12-10 14:38
# 110      33.7  2025-12-10 14:38
# 111       0.7  2025-12-10 14:38
# 112      26.2  2025-12-10 14:38
# 113       1.0  2025-12-10 14:37
# 114      26.1  2025-12-10 14:37
# 115      20.1  2025-12-10 14:36
# 116      28.3  2025-12-10 14:36
# 117       4.5  2025-12-10 13:28
# 118       0.9  2025-12-10 11:19
# 119       1.1  2025-12-10 11:16
# 120       1.4  2025-12-10 05:08
# 121       1.2  2025-12-10 05:08
# 122       1.2  2025-12-10 05:08
# 123       1.6  2025-12-10 05:07
# 124       1.6  2025-12-10 05:07
# 125       0.8  2025-12-10 05:07
# 126       1.1  2025-12-10 05:07
# 127       1.3  2025-12-10 05:07
# 128       0.7  2025-12-10 05:07
# 129       0.8  2025-12-10 05:07
# 130       0.0  2025-12-10 04:22
# 131       0.6  2025-12-10 04:22
# 132       1.0  2025-12-10 04:22
# 133       0.0  2025-12-10 04:21
# 134       0.0  2025-12-10 04:16
# 135       0.0  2025-12-10 03:50
# 136       0.0  2025-12-10 03:50
# 137       1.1  2025-12-10 03:50
# 138       0.6  2025-12-10 03:50
# 139       4.8  2025-12-10 02:16
# 140       6.5  2025-12-10 02:13
# 141       0.0  2025-12-10 01:52
# 142       0.0  2025-12-10 01:52
# 143       0.0  2025-12-10 01:51
# 144       0.0  2025-12-10 01:46
# 145       0.0  2025-12-10 01:41
# 146      82.1  2025-12-10 00:57
# 147       0.0  2025-12-10 00:46
# 148      19.8  2025-12-10 00:44
# 149       3.9  2025-12-10 00:40
# 150      11.8  2025-12-10 00:31
# 151       4.6  2025-12-10 00:11
# 152       1.3  2025-12-10 00:05
# 153       0.0  2025-12-10 00:04

# %%
# ==================== DATA FILTERING ====================
# 1. Filter by time: Only keep sessions after 2025-12-10 14:36
cutoff_time = pd.to_datetime('2025-12-10 14:36')
df_all = df_all[pd.to_datetime(df_all['created_at']) >= cutoff_time].copy()

# 2. Filter by major: Exclude SDS/sds
df_all = df_all[
    ~df_all['major'].str.lower().isin(['sds']) | df_all['major'].isna()
].copy()

# Recreate derived columns after filtering
df_all['Config'] = df_all.apply(lambda r: get_config_label(r['use_memory'], r['use_plan']), axis=1)
df_all['Duration (min)'] = df_all.apply(lambda r: calculate_duration(r['created_at'], r['updated_at']), axis=1)
df_all['Outcome'] = df_all.apply(lambda r: 
    '✅ Deal' if r['deal_reached'] 
    else '❌ Failed' if r['deal_failed'] 
    else '⏸️ Incomplete', axis=1)
df_all['Role'] = df_all['student_role'].map({
    'side1': '🏢 Buyer (Fred)',
    'side2': '🏘️ Seller (Rosalind)'
})

# Update display dataframe with filtered data
display_df = df_all[[
    'session_id', 'Role', 'Config', 'Outcome',
    'major', 'gender', 'negotiation_experience',  
    'Duration (min)', 'created_at'
]].copy()

display_df['session_id'] = display_df['session_id'].str[:8]
display_df['created_at'] = pd.to_datetime(display_df['created_at']).dt.strftime('%Y-%m-%d %H:%M')
display_df['Duration (min)'] = display_df['Duration (min)'].round(1)
display_df.columns = ['Session', 'Role', 'Config', 'Outcome', 'Major', 'Gender', 'Exp', 'Duration', 'Created']

# Print filtered statistics
print("\n" + "="*150)
print("🔍 FILTERED DATA (After 2025-12-10 14:36, Excluding SDS/sds majors)")
print("="*150)
print(f"Total Sessions: {len(df_all)}")
print(f"Successful Deals: {df_all['deal_reached'].sum()}")
print(f"Failed Negotiations: {df_all['deal_failed'].sum()}")
print(f"Incomplete: {(~df_all['deal_reached'] & ~df_all['deal_failed']).sum()}")

print(f"\n📊 Configuration Breakdown:")
print(df_all['Config'].value_counts().to_string())

print(f"\n🎭 Role Distribution:")
print(df_all['Role'].value_counts().to_string())

print("\n" + "="*150) 
display(display_df)
# Out:
# ======================================================================================================================================================
# 🔍 FILTERED DATA (After 2025-12-10 14:36, Excluding SDS/sds majors)
# ======================================================================================================================================================
# Total Sessions: 76
# Successful Deals: 76
# Failed Negotiations: 0
# Incomplete: -152
#
# 📊 Configuration Breakdown:
# Config
# M+P     39
# Base    37
#
# 🎭 Role Distribution:
# Role
# 🏘️ Seller (Rosalind)    76
#
# ======================================================================================================================================================
#       Session                  Role Config Outcome  \
# 1    b37f26ac  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 3    1da9f9c4  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 4    0ad06bea  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 6    799f52db  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 7    95e44a5d  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 8    16eceb2c  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 10   31db345d  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 11   88bdd965  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 12   50f35769  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 13   1c047b8c  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 14   1accb1db  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 15   bb74becf  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 16   91bf642e  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 17   7443cda3  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 19   562a5935  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 21   efc8ced7  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 24   98028e11  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 25   9864a8ac  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 26   19189653  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 27   65568ba8  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 28   09116786  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 30   f8b904d4  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 31   2b985adf  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 33   516685e6  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 35   d08ef3f9  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 37   4eb7d6b7  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 38   0edb4787  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 46   f8108b66  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 54   8f327691  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 56   def6ce77  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 58   ff4187e1  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 59   2c58997c  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 60   1c64c52d  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 62   320f365c  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 63   583603ec  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 65   24a24ce4  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 67   da8e805c  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 68   bb4f01c8  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 70   fefa4d90  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 72   53c67d59  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 73   fae036e8  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 74   e014a8cd  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 75   bf242471  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 76   daa71a3a  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 77   187ee6e1  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 78   7ab01b6d  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 79   a5a7bbed  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 80   f0c044d9  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 81   cba8d9c9  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 83   5c9d6f09  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 84   118af3de  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 85   486f9419  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 86   13697589  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 87   81eafc5a  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 88   fe68b67b  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 89   a5291dbb  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 90   baf91c79  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 92   ed40d7bb  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 93   9a00be6e  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 94   da734cf6  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 96   2e473faf  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 97   35cd2da6  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 98   73297254  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 99   34bd3d91  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 100  fef6c2b3  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 101  e15e86b4  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 102  cdb4b68d  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 103  33365183  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 104  fabc68b2  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 105  526567fb  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 106  6a1f1023  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 107  746b9508  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 108  2527e1ea  🏘️ Seller (Rosalind)   Base  ✅ Deal
# 109  4093ffc5  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 110  073b248f  🏘️ Seller (Rosalind)    M+P  ✅ Deal
# 112  20260374  🏘️ Seller (Rosalind)    M+P  ✅ Deal
#
#                                  Major      Gender              Exp  Duration  \
# 1                              Theater      Female       Occasional       7.1
# 3                                  GBS                                   29.1
# 4                                  MBA                                   11.4
# 6                         MBA Exchange              A few instances      27.0
# 7                                  MBA        Male  A few instances       8.7
# 8                                  GBS      Female  A few instances      42.6
# 10                                Tech        Male       Occasional      22.7
# 11                                                                       20.5
# 12                            Business        Male  A few instances      20.2
# 13                                                                       25.3
# 14         Global Business and Society        Male       Occasional      44.0
# 15                            Business        Male             None      18.4
# 16                                 MBA      Female       Occasional      20.2
# 17                                 GBS      Female                       18.1
# 19                                 GBS      Female       Occasional      24.7
# 21                                 MBA      Female       Occasional      24.0
# 24                                                                       25.4
# 25                                 GBS      Female  A few instances      20.3
# 26                                 MBA        Male  A few instances      31.8
# 27                                 MBA                                   26.6
# 28                          Management        Male  A few instances      29.2
# 30                School of Management        Male  A few instances      41.2
# 31                                 GBS      Female  A few instances      49.8
# 33                                 GBS        Male  A few instances      38.1
# 35                                            Male  A few instances      34.2
# 37                                 MBA        Male  A few instances      11.5
# 38                                 GBS      Female  A few instances      29.3
# 46                  Health Informatics      Female             None      16.4
# 54                                                                       18.6
# 56                       public health      Female             None      11.0
# 58                                 GBS      Female  A few instances      20.5
# 59           Global Business & Society        Male       Occasional       9.2
# 60           Global Business & Society        Male  A few instances      14.9
# 62                                 GBS      Female             None      17.3
# 63                                 GBS        Male             None      17.6
# 65                                 GBS        Male  A few instances      15.0
# 67                          Management        Male             None      29.4
# 68                                 MBA      Female       Occasional      11.5
# 70                          Management      Female  A few instances      28.4
# 72                            Business        Male       Occasional      30.1
# 73                  Management Science      Female       Occasional      20.8
# 74               Technology Management        Male       Occasional      32.3
# 75                                 MBA      Female  A few instances      10.9
# 76   Master of Business Administration        Male             None      26.5
# 77                                 MBA        Male         Frequent      18.6
# 78                                 MBA        Male  A few instances      19.1
# 79                                 GBS      Female  A few instances      25.2
# 80                                 GBS      Female  A few instances      11.3
# 81                  Management Science        Male             None      21.2
# 83                      Yale SOM - GBS      Female       Occasional      24.1
# 84                                 MBA        Male  A few instances      13.8
# 85                                 MBA        Male  A few instances      15.6
# 86                       Arrchitecture        Male  A few instances      22.9
# 87                          Management      Female  A few instances      23.0
# 88            Master in Management GBS      Female                       18.6
# 89                                 GBS      Female         Frequent      40.5
# 90                         Mathematics        Male  A few instances      29.5
# 92         Global Business and Society  Non-binary       Occasional      31.0
# 93                                                                       18.4
# 94                    Asset Management        Male  A few instances      33.9
# 96      Masters of Advanced Management        Male       Occasional      22.3
# 97                          Management        Male             None      28.1
# 98              Mechanical Engineering        Male       Occasional       6.7
# 99   Master of Business Administration      Female  A few instances      31.4
# 100                                GBS        Male             None      32.3
# 101                                GBS      Female  A few instances      34.2
# 102                     Global Affairs        Male  A few instances      27.1
# 103                                MBA        Male       Occasional      41.2
# 104                         Management        Male  A few instances      42.7
# 105                                                                      24.5
# 106                         Management        Male       Occasional      28.9
# 107                                                                      34.9
# 108                                MBA        Male  A few instances      18.6
# 109        Global business and society        Male  A few instances      21.2
# 110                                Law        Male             None      33.7
# 112        Global Business and Society              A few instances      26.2
#
#               Created
# 1    2025-12-10 19:52
# 3    2025-12-10 19:49
# 4    2025-12-10 19:44
# 6    2025-12-10 19:39
# 7    2025-12-10 19:38
# 8    2025-12-10 19:37
# 10   2025-12-10 19:35
# 11   2025-12-10 19:35
# 12   2025-12-10 19:35
# 13   2025-12-10 19:35
# 14   2025-12-10 19:35
# 15   2025-12-10 19:35
# 16   2025-12-10 19:34
# 17   2025-12-10 19:34
# 19   2025-12-10 19:33
# 21   2025-12-10 19:33
# 24   2025-12-10 19:31
# 25   2025-12-10 19:31
# 26   2025-12-10 19:31
# 27   2025-12-10 19:30
# 28   2025-12-10 19:29
# 30   2025-12-10 19:28
# 31   2025-12-10 19:28
# 33   2025-12-10 19:28
# 35   2025-12-10 19:26
# 37   2025-12-10 19:23
# 38   2025-12-10 19:23
# 46   2025-12-10 15:37
# 54   2025-12-10 15:09
# 56   2025-12-10 15:07
# 58   2025-12-10 15:00
# 59   2025-12-10 14:59
# 60   2025-12-10 14:57
# 62   2025-12-10 14:50
# 63   2025-12-10 14:50
# 65   2025-12-10 14:49
# 67   2025-12-10 14:48
# 68   2025-12-10 14:48
# 70   2025-12-10 14:48
# 72   2025-12-10 14:47
# 73   2025-12-10 14:47
# 74   2025-12-10 14:47
# 75   2025-12-10 14:47
# 76   2025-12-10 14:47
# 77   2025-12-10 14:47
# 78   2025-12-10 14:47
# 79   2025-12-10 14:47
# 80   2025-12-10 14:46
# 81   2025-12-10 14:46
# 83   2025-12-10 14:46
# 84   2025-12-10 14:46
# 85   2025-12-10 14:46
# 86   2025-12-10 14:46
# 87   2025-12-10 14:45
# 88   2025-12-10 14:45
# 89   2025-12-10 14:45
# 90   2025-12-10 14:45
# 92   2025-12-10 14:44
# 93   2025-12-10 14:43
# 94   2025-12-10 14:43
# 96   2025-12-10 14:43
# 97   2025-12-10 14:42
# 98   2025-12-10 14:42
# 99   2025-12-10 14:41
# 100  2025-12-10 14:41
# 101  2025-12-10 14:40
# 102  2025-12-10 14:40
# 103  2025-12-10 14:39
# 104  2025-12-10 14:39
# 105  2025-12-10 14:39
# 106  2025-12-10 14:39
# 107  2025-12-10 14:39
# 108  2025-12-10 14:39
# 109  2025-12-10 14:38
# 110  2025-12-10 14:38
# 112  2025-12-10 14:38

# %% [markdown]
# ---
# ## 2. 👥 Student Demographics & Characteristics Analysis

# %%
print_header("👥 STUDENT DEMOGRAPHICS & CHARACTERISTICS")

# Filter out rows with no demographic data
df_demo = df_all.copy()

# Major Analysis
print_subheader("📚 Academic Major Distribution")
if df_demo['major'].notna().sum() > 0:
    major_counts = df_demo['major'].value_counts()
    print(f"Total with major data: {df_demo['major'].notna().sum()}")
    print("\nMajor breakdown:")
    for major, count in major_counts.items():
        pct = count / len(df_demo) * 100
        print(f"  {major}: {count} ({pct:.1f}%)")
else:
    print("No major data available")

# Gender Analysis
print_subheader("⚧ Gender Distribution")
if df_demo['gender'].notna().sum() > 0:
    gender_counts = df_demo['gender'].value_counts()
    print(f"Total with gender data: {df_demo['gender'].notna().sum()}")
    print("\nGender breakdown:")
    for gender, count in gender_counts.items():
        pct = count / len(df_demo) * 100
        print(f"  {gender}: {count} ({pct:.1f}%)")
else:
    print("No gender data available")

# Experience Analysis
print_subheader("💼 Negotiation Experience Distribution")
if df_demo['negotiation_experience'].notna().sum() > 0:
    exp_counts = df_demo['negotiation_experience'].value_counts()
    print(f"Total with experience data: {df_demo['negotiation_experience'].notna().sum()}")
    print("\nExperience breakdown:")
    for exp, count in exp_counts.items():
        pct = count / len(df_demo) * 100
        print(f"  {exp}: {count} ({pct:.1f}%)")
else:
    print("No experience data available")

# Success rate by demographics
print_subheader("📈 Success Rates by Demographics")

if df_demo['major'].notna().sum() > 0:
    print("\nBy Major:")
    major_success = df_demo.groupby('major')['deal_reached'].agg(['sum', 'count', 'mean'])
    major_success.columns = ['Deals', 'Total', 'Success Rate']
    major_success['Success Rate'] = (major_success['Success Rate'] * 100).round(1)
    print(major_success.to_string())

if df_demo['gender'].notna().sum() > 0:
    print("\nBy Gender:")
    gender_success = df_demo.groupby('gender')['deal_reached'].agg(['sum', 'count', 'mean'])
    gender_success.columns = ['Deals', 'Total', 'Success Rate']
    gender_success['Success Rate'] = (gender_success['Success Rate'] * 100).round(1)
    print(gender_success.to_string())

if df_demo['negotiation_experience'].notna().sum() > 0:
    print("\nBy Negotiation Experience:")
    exp_success = df_demo.groupby('negotiation_experience')['deal_reached'].agg(['sum', 'count', 'mean'])
    exp_success.columns = ['Deals', 'Total', 'Success Rate']
    exp_success['Success Rate'] = (exp_success['Success Rate'] * 100).round(1)
    print(exp_success.to_string())
# Out:
# ====================================================================================================
#                               👥 STUDENT DEMOGRAPHICS & CHARACTERISTICS
# ====================================================================================================
#
#
# --------------------------------------------------------------------------------
# 📚 Academic Major Distribution
# --------------------------------------------------------------------------------
# Total with major data: 76
#
# Major breakdown:
#   GBS: 17 (22.4%)
#   MBA: 15 (19.7%)
#   : 8 (10.5%)
#   Management: 7 (9.2%)
#   Global Business and Society: 3 (3.9%)
#   Business: 3 (3.9%)
#   Global Business & Society: 2 (2.6%)
#   Master of Business Administration: 2 (2.6%)
#   Management Science: 2 (2.6%)
#   Theater: 1 (1.3%)
#   School of Management: 1 (1.3%)
#   Tech: 1 (1.3%)
#   MBA Exchange: 1 (1.3%)
#   public health: 1 (1.3%)
#   Health Informatics: 1 (1.3%)
#   Technology Management: 1 (1.3%)
#   Yale SOM - GBS: 1 (1.3%)
#   Arrchitecture: 1 (1.3%)
#   Master in Management GBS: 1 (1.3%)
#   Mathematics: 1 (1.3%)
#   Asset Management: 1 (1.3%)
#   Masters of Advanced Management: 1 (1.3%)
#   Mechanical Engineering: 1 (1.3%)
#   Global Affairs: 1 (1.3%)
#   Global business and society: 1 (1.3%)
#   Law: 1 (1.3%)
#
# --------------------------------------------------------------------------------
# ⚧ Gender Distribution
# --------------------------------------------------------------------------------
# Total with gender data: 76
#
# Gender breakdown:
#   Male: 38 (50.0%)
#   Female: 25 (32.9%)
#   : 12 (15.8%)
#   Non-binary: 1 (1.3%)
#
# --------------------------------------------------------------------------------
# 💼 Negotiation Experience Distribution
# --------------------------------------------------------------------------------
# Total with experience data: 76
#
# Experience breakdown:
#   A few instances: 34 (44.7%)
#   Occasional: 17 (22.4%)
#   : 12 (15.8%)
#   None: 11 (14.5%)
#   Frequent: 2 (2.6%)
#
# --------------------------------------------------------------------------------
# 📈 Success Rates by Demographics
# --------------------------------------------------------------------------------
#
# By Major:
#                                    Deals  Total  Success Rate
# major
#                                        8      8         100.0
# Arrchitecture                          1      1         100.0
# Asset Management                       1      1         100.0
# Business                               3      3         100.0
# GBS                                   17     17         100.0
# Global Affairs                         1      1         100.0
# Global Business & Society              2      2         100.0
# Global Business and Society            3      3         100.0
# Global business and society            1      1         100.0
# Health Informatics                     1      1         100.0
# Law                                    1      1         100.0
# MBA                                   15     15         100.0
# MBA Exchange                           1      1         100.0
# Management                             7      7         100.0
# Management Science                     2      2         100.0
# Master in Management GBS               1      1         100.0
# Master of Business Administration      2      2         100.0
# Masters of Advanced Management         1      1         100.0
# Mathematics                            1      1         100.0
# Mechanical Engineering                 1      1         100.0
# School of Management                   1      1         100.0
# Tech                                   1      1         100.0
# Technology Management                  1      1         100.0
# Theater                                1      1         100.0
# Yale SOM - GBS                         1      1         100.0
# public health                          1      1         100.0
#
# By Gender:
#             Deals  Total  Success Rate
# gender
#                12     12         100.0
# Female         25     25         100.0
# Male           38     38         100.0
# Non-binary      1      1         100.0
#
# By Negotiation Experience:
#                         Deals  Total  Success Rate
# negotiation_experience
#                            12     12         100.0
# A few instances            34     34         100.0
# Frequent                    2      2         100.0
# None                       11     11         100.0
# Occasional                 17     17         100.0

# %% [markdown]
# ---
# ## 3. 💰 Configuration Comparison: Base vs M vs M+P
#
# Analysis of deal prices across different AI configurations

# %%
# Load successful deals with price data
query_deals = f"""
SELECT 
    session_id,
    student_role,
    ai_role,
    use_memory,
    use_plan,
    student_deal_json,
    ai_deal_json,
    transcript,
    created_at,
    updated_at
FROM negotiation_sessions
WHERE scenario_name = '{SCENARIO_FILTER}' AND deal_reached = 1
ORDER BY created_at DESC
"""

df_deals = pd.read_sql_query(query_deals, conn)

# Parse deal JSONs and extract prices
def extract_price(deal_json_str):
    deal = safe_json_load(deal_json_str)
    if deal and 'final_price' in deal:
        return deal['final_price']
    return None

df_deals['student_price'] = df_deals['student_deal_json'].apply(extract_price)
df_deals['ai_price'] = df_deals['ai_deal_json'].apply(extract_price)
df_deals['config'] = df_deals.apply(lambda r: get_config_label(r['use_memory'], r['use_plan']), axis=1)
df_deals['duration'] = df_deals.apply(lambda r: calculate_duration(r['created_at'], r['updated_at']), axis=1)

# Count rounds
def count_rounds(transcript_json):
    transcript = safe_json_load(transcript_json)
    return len(transcript) // 2 if transcript else 0

df_deals['rounds'] = df_deals['transcript'].apply(count_rounds)

# Map roles
df_deals['student_role_label'] = df_deals['student_role'].map({
    'side1': 'Buyer (Fred)',
    'side2': 'Seller (Rosalind)'
})

df_deals['ai_role_label'] = df_deals['ai_role'].map({
    'side1': 'Buyer (Fred)',
    'side2': 'Seller (Rosalind)'
})

print_header("💰 DEAL PRICE ANALYSIS BY CONFIGURATION")

if len(df_deals) == 0:
    print("❌ No successful deals found")
else:
    print(f"Total Successful Deals: {len(df_deals)}\n")
    
    # Overall statistics
    print_subheader("📊 Overall Price Statistics")
    print(f"Average Final Price: ${df_deals['student_price'].mean():,.0f}")
    print(f"Median Final Price: ${df_deals['student_price'].median():,.0f}")
    print(f"Min Price: ${df_deals['student_price'].min():,.0f}")
    print(f"Max Price: ${df_deals['student_price'].max():,.0f}")
    print(f"Std Dev: ${df_deals['student_price'].std():,.0f}")
    
    # Price by configuration
    print_subheader("🔧 Average Price by Configuration")
    
    config_stats = df_deals.groupby('config').agg({
        'student_price': ['count', 'mean', 'median', 'std', 'min', 'max']
    }).round(0)
    
    print("\nConfiguration Summary:")
    print("="*80)
    for config in ['Base', 'M', 'P', 'M+P']:
        if config in config_stats.index:
            stats = config_stats.loc[config, 'student_price']
            print(f"\n{config}:")
            print(f"  Count: {int(stats['count'])} deals")
            print(f"  Average: ${stats['mean']:,.0f}")
            print(f"  Median:  ${stats['median']:,.0f}")
            print(f"  Range:   ${stats['min']:,.0f} - ${stats['max']:,.0f}")
            if stats['count'] > 1:
                print(f"  Std Dev: ${stats['std']:,.0f}")
    
    # Price by role and configuration
    print_subheader("🎭 Average Price by Role & Configuration")
    
    role_config_stats = df_deals.groupby(['student_role_label', 'config'])['student_price'].agg(['count', 'mean', 'median']).round(0)
    
    print("\nWhen Student is BUYER (Fred Starr):")
    print("  Goal: Minimize price (lower is better)")
    print("  BATNA: $675,000 (will walk away if price > $675k)")
    print("-"*80)
    if 'Buyer (Fred)' in role_config_stats.index.get_level_values(0):
        buyer_stats = role_config_stats.loc['Buyer (Fred)']
        for config in buyer_stats.index:
            stats = buyer_stats.loc[config]
            print(f"  {config}: ${stats['mean']:,.0f} avg (n={int(stats['count'])})")
    
    print("\nWhen Student is SELLER (Rosalind Cain):")
    print("  Goal: Maximize price (higher is better)")
    print("  BATNA: $475,000 (will walk away if price < $475k)")
    print("-"*80)
    if 'Seller (Rosalind)' in role_config_stats.index.get_level_values(0):
        seller_stats = role_config_stats.loc['Seller (Rosalind)']
        for config in seller_stats.index:
            stats = seller_stats.loc[config]
            print(f"  {config}: ${stats['mean']:,.0f} avg (n={int(stats['count'])})")

    # Detailed deal list
    print_subheader("📋 All Deals - Detailed List")

    deal_display = df_deals[[
        'session_id', 'student_role_label', 'config', 
        'student_price', 'rounds', 'duration', 'created_at'  # ← 添加 created_at
    ]].copy()

    deal_display['session_id'] = deal_display['session_id'].str[:8]
    deal_display['student_price'] = deal_display['student_price'].apply(lambda x: f"${x:,.0f}" if pd.notna(x) else "N/A")
    deal_display['duration'] = deal_display['duration'].round(1)
    deal_display['created_at'] = pd.to_datetime(deal_display['created_at']).dt.strftime('%m-%d %H:%M')  # ← 格式化时间

    deal_display.columns = ['Session', 'Student Role', 'Config', 'Final Price', 'Rounds', 'Duration (min)', 'Created']  # ← 添加列名

    display(deal_display)
# Out:
# ====================================================================================================
#                                💰 DEAL PRICE ANALYSIS BY CONFIGURATION
# ====================================================================================================
#
# Total Successful Deals: 81
#
#
# --------------------------------------------------------------------------------
# 📊 Overall Price Statistics
# --------------------------------------------------------------------------------
# Average Final Price: $554,023
# Median Final Price: $550,000
# Min Price: $465,000
# Max Price: $670,000
# Std Dev: $39,907
#
# --------------------------------------------------------------------------------
# 🔧 Average Price by Configuration
# --------------------------------------------------------------------------------
#
# Configuration Summary:
# ================================================================================
#
# Base:
#   Count: 35 deals
#   Average: $557,943
#   Median:  $550,000
#   Range:   $465,000 - $670,000
#   Std Dev: $47,761
#
# M+P:
#   Count: 31 deals
#   Average: $549,597
#   Median:  $550,000
#   Range:   $500,000 - $630,000
#   Std Dev: $28,762
#
# --------------------------------------------------------------------------------
# 🎭 Average Price by Role & Configuration
# --------------------------------------------------------------------------------
#
# When Student is BUYER (Fred Starr):
#   Goal: Minimize price (lower is better)
#   BATNA: $675,000 (will walk away if price > $675k)
# --------------------------------------------------------------------------------
#   Base: $595,000 avg (n=1)
#
# When Student is SELLER (Rosalind Cain):
#   Goal: Maximize price (higher is better)
#   BATNA: $475,000 (will walk away if price < $475k)
# --------------------------------------------------------------------------------
#   Base: $556,853 avg (n=34)
#   M+P: $549,597 avg (n=31)
#
# --------------------------------------------------------------------------------
# 📋 All Deals - Detailed List
# --------------------------------------------------------------------------------
#      Session       Student Role Config Final Price  Rounds  Duration (min)  \
# 0   f81e9731  Seller (Rosalind)   Base    $670,000       6             7.2
# 1   b37f26ac  Seller (Rosalind)   Base    $575,000       4             7.1
# 2   1da9f9c4  Seller (Rosalind)    M+P         N/A       4            29.1
# 3   0ad06bea  Seller (Rosalind)   Base    $465,000       6            11.4
# 4   799f52db  Seller (Rosalind)   Base    $549,000       6            27.0
# 5   95e44a5d  Seller (Rosalind)   Base    $570,000       6             8.7
# 6   16eceb2c  Seller (Rosalind)    M+P    $585,000       8            42.6
# 7   798d365f       Buyer (Fred)   Base    $595,000       5            12.4
# 8   31db345d  Seller (Rosalind)    M+P    $565,000       5            22.7
# 9   88bdd965  Seller (Rosalind)   Base         N/A       5            20.5
# 10  50f35769  Seller (Rosalind)   Base         N/A       5            20.2
# 11  1c047b8c  Seller (Rosalind)    M+P    $550,000       6            25.3
# 12  1accb1db  Seller (Rosalind)    M+P    $630,000       6            44.0
# 13  bb74becf  Seller (Rosalind)   Base         N/A       6            18.4
# 14  91bf642e  Seller (Rosalind)    M+P    $525,000       6            20.2
# 15  7443cda3  Seller (Rosalind)    M+P    $540,000       5            18.1
# 16  562a5935  Seller (Rosalind)   Base    $590,000       6            24.7
# 17  efc8ced7  Seller (Rosalind)    M+P    $560,000       6            24.0
# 18  98028e11  Seller (Rosalind)    M+P    $552,000       6            25.4
# 19  9864a8ac  Seller (Rosalind)   Base    $512,500       5            20.3
# 20  19189653  Seller (Rosalind)    M+P         N/A       5            31.8
# 21  65568ba8  Seller (Rosalind)   Base         N/A       5            26.6
# 22  09116786  Seller (Rosalind)   Base    $650,000       6            29.2
# 23  f8b904d4  Seller (Rosalind)    M+P    $585,000       7            41.2
# 24  2b985adf  Seller (Rosalind)   Base    $555,000       6            49.8
# 25  516685e6  Seller (Rosalind)    M+P         N/A       5            38.1
# 26  d08ef3f9  Seller (Rosalind)    M+P         N/A       5            34.2
# 27  4eb7d6b7  Seller (Rosalind)   Base    $550,000       6            11.5
# 28  0edb4787  Seller (Rosalind)    M+P    $508,000       5            29.3
# 29  fef88ef0  Seller (Rosalind)   Base         N/A       6            30.3
# 30  f8108b66  Seller (Rosalind)   Base    $490,000       5            16.4
# 31  8f327691  Seller (Rosalind)   Base    $545,000       6            18.6
# 32  def6ce77  Seller (Rosalind)   Base    $530,000       6            11.0
# 33  ff4187e1  Seller (Rosalind)    M+P    $570,000       6            20.5
# 34  2c58997c  Seller (Rosalind)   Base    $535,000       6             9.2
# 35  1c64c52d  Seller (Rosalind)   Base    $600,000       6            14.9
# 36  320f365c  Seller (Rosalind)   Base    $600,000       6            17.3
# 37  583603ec  Seller (Rosalind)    M+P         N/A       6            17.6
# 38  24a24ce4  Seller (Rosalind)    M+P    $555,000       4            15.0
# 39  da8e805c  Seller (Rosalind)    M+P    $540,000       6            29.4
# 40  bb4f01c8  Seller (Rosalind)   Base    $535,000       6            11.5
# 41  fefa4d90  Seller (Rosalind)   Base         N/A       5            28.4
# 42  53c67d59  Seller (Rosalind)    M+P         N/A       6            30.1
# 43  fae036e8  Seller (Rosalind)   Base    $550,000       6            20.8
# 44  e014a8cd  Seller (Rosalind)   Base    $550,000       6            32.3
# 45  bf242471  Seller (Rosalind)   Base    $540,000       5            10.9
# 46  daa71a3a  Seller (Rosalind)   Base    $540,000       6            26.5
# 47  187ee6e1  Seller (Rosalind)   Base    $560,000       6            18.6
# 48  7ab01b6d  Seller (Rosalind)    M+P    $550,000       6            19.1
# 49  a5a7bbed  Seller (Rosalind)    M+P    $555,000       6            25.2
# 50  f0c044d9  Seller (Rosalind)   Base    $575,000       6            11.3
# 51  cba8d9c9  Seller (Rosalind)   Base    $590,000       6            21.2
# 52  5c9d6f09  Seller (Rosalind)   Base         N/A       5            24.1
# 53  118af3de  Seller (Rosalind)   Base    $545,000       5            13.8
# 54  486f9419  Seller (Rosalind)   Base    $535,000       4            15.6
# 55  13697589  Seller (Rosalind)   Base    $480,000       6            22.9
# 56  81eafc5a  Seller (Rosalind)    M+P    $500,000       6            23.0
# 57  fe68b67b  Seller (Rosalind)    M+P    $595,000       6            18.6
# 58  a5291dbb  Seller (Rosalind)    M+P    $548,000       6            40.5
# 59  baf91c79  Seller (Rosalind)    M+P    $550,000       6            29.5
# 60  ed40d7bb  Seller (Rosalind)   Base    $517,500       6            31.0
# 61  9a00be6e  Seller (Rosalind)    M+P         N/A       5            18.4
# 62  da734cf6  Seller (Rosalind)    M+P    $550,000       7            33.9
# 63  2e473faf  Seller (Rosalind)    M+P    $560,000       6            22.3
# 64  35cd2da6  Seller (Rosalind)   Base    $549,000       6            28.1
# 65  73297254  Seller (Rosalind)    M+P    $505,000       3             6.7
# 66  34bd3d91  Seller (Rosalind)    M+P    $578,500       6            31.4
# 67  fef6c2b3  Seller (Rosalind)    M+P    $520,000       6            32.3
# 68  e15e86b4  Seller (Rosalind)    M+P    $540,000       5            34.2
# 69  cdb4b68d  Seller (Rosalind)   Base    $650,000       7            27.1
# 70  33365183  Seller (Rosalind)    M+P    $538,500       6            41.2
# 71  fabc68b2  Seller (Rosalind)   Base    $535,000       6            42.7
# 72  526567fb  Seller (Rosalind)    M+P         N/A       5            24.5
# 73  6a1f1023  Seller (Rosalind)    M+P    $510,000       6            28.9
# 74  746b9508  Seller (Rosalind)    M+P    $570,000       6            34.9
# 75  2527e1ea  Seller (Rosalind)   Base    $575,000       6            18.6
# 76  4093ffc5  Seller (Rosalind)    M+P    $515,000       6            21.2
# 77  073b248f  Seller (Rosalind)    M+P    $525,000       6            33.7
# 78  20260374  Seller (Rosalind)    M+P    $562,500       6            26.2
# 79  9992a0ff  Seller (Rosalind)   Base    $640,000       6            11.8
# 80  7271f344  Seller (Rosalind)   Base    $480,000       2             4.6
#
#         Created
# 0   12-10 20:01
# 1   12-10 19:52
# 2   12-10 19:49
# 3   12-10 19:44
# 4   12-10 19:39
# 5   12-10 19:38
# 6   12-10 19:37
# 7   12-10 19:36
# 8   12-10 19:35
# 9   12-10 19:35
# 10  12-10 19:35
# 11  12-10 19:35
# 12  12-10 19:35
# 13  12-10 19:35
# 14  12-10 19:34
# 15  12-10 19:34
# 16  12-10 19:33
# 17  12-10 19:33
# 18  12-10 19:31
# 19  12-10 19:31
# 20  12-10 19:31
# 21  12-10 19:30
# 22  12-10 19:29
# 23  12-10 19:28
# 24  12-10 19:28
# 25  12-10 19:28
# 26  12-10 19:26
# 27  12-10 19:23
# 28  12-10 19:23
# 29  12-10 15:48
# 30  12-10 15:37
# 31  12-10 15:09
# 32  12-10 15:07
# 33  12-10 15:00
# 34  12-10 14:59
# 35  12-10 14:57
# 36  12-10 14:50
# 37  12-10 14:50
# 38  12-10 14:49
# 39  12-10 14:48
# 40  12-10 14:48
# 41  12-10 14:48
# 42  12-10 14:47
# 43  12-10 14:47
# 44  12-10 14:47
# 45  12-10 14:47
# 46  12-10 14:47
# 47  12-10 14:47
# 48  12-10 14:47
# 49  12-10 14:47
# 50  12-10 14:46
# 51  12-10 14:46
# 52  12-10 14:46
# 53  12-10 14:46
# 54  12-10 14:46
# 55  12-10 14:46
# 56  12-10 14:45
# 57  12-10 14:45
# 58  12-10 14:45
# 59  12-10 14:45
# 60  12-10 14:44
# 61  12-10 14:43
# 62  12-10 14:43
# 63  12-10 14:43
# 64  12-10 14:42
# 65  12-10 14:42
# 66  12-10 14:41
# 67  12-10 14:41
# 68  12-10 14:40
# 69  12-10 14:40
# 70  12-10 14:39
# 71  12-10 14:39
# 72  12-10 14:39
# 73  12-10 14:39
# 74  12-10 14:39
# 75  12-10 14:39
# 76  12-10 14:38
# 77  12-10 14:38
# 78  12-10 14:38
# 79  12-10 00:31
# 80  12-10 00:11

# %% [markdown]
# ### 3.1 Price Comparison Summary Table

# %%
# Create comprehensive comparison table
if len(df_deals) > 0:
    print("\n" + "="*100)
    print("COMPREHENSIVE PRICE COMPARISON: BASE vs M vs M+P".center(100))
    print("="*100 + "\n")
    
    comparison_data = []
    
    for config in ['Base', 'M', 'P', 'M+P']:
        config_data = df_deals[df_deals['config'] == config]
        
        if len(config_data) > 0:
            comparison_data.append({
                'Configuration': config,
                'N Deals': len(config_data),
                'Avg Price': f"${config_data['student_price'].mean():,.0f}",
                'Median Price': f"${config_data['student_price'].median():,.0f}",
                'Min Price': f"${config_data['student_price'].min():,.0f}",
                'Max Price': f"${config_data['student_price'].max():,.0f}",
                'Avg Rounds': f"{config_data['rounds'].mean():.1f}",
                'Avg Duration': f"{config_data['duration'].mean():.1f} min"
            })
    
    if comparison_data:
        comparison_df = pd.DataFrame(comparison_data)
        display(comparison_df)
        
        print("\n💡 Key Insights:")
        print("-"*80)
        
        # Calculate buyer vs seller average for each config
        for config in ['Base', 'M', 'P', 'M+P']:
            config_data = df_deals[df_deals['config'] == config]
            if len(config_data) > 0:
                buyer_avg = config_data[config_data['student_role'] == 'side1']['student_price'].mean()
                seller_avg = config_data[config_data['student_role'] == 'side2']['student_price'].mean()
                
                print(f"\n{config}:")
                if not pd.isna(buyer_avg):
                    print(f"  When student is buyer: ${buyer_avg:,.0f} (student wants lower)")
                if not pd.isna(seller_avg):
                    print(f"  When student is seller: ${seller_avg:,.0f} (student wants higher)")
else:
    print("No deal data available for comparison")
# Out:
# ====================================================================================================
#                           COMPREHENSIVE PRICE COMPARISON: BASE vs M vs M+P
# ====================================================================================================
#   Configuration  N Deals Avg Price Median Price Min Price Max Price  \
# 0          Base       42  $557,943     $550,000  $465,000  $670,000
# 1           M+P       39  $549,597     $550,000  $500,000  $630,000
#
#   Avg Rounds Avg Duration
# 0        5.6     19.9 min
# 1        5.7     27.8 min
# 💡 Key Insights:
# --------------------------------------------------------------------------------
#
# Base:
#   When student is buyer: $595,000 (student wants lower)
#   When student is seller: $556,853 (student wants higher)
#
# M+P:
#   When student is seller: $549,597 (student wants higher)

# %%
# ==================== DETAILED ANALYSIS: WHO GOES FIRST ====================
if len(df_deals) > 0:
    print("\n" + "="*100)
    print("DETAILED ANALYSIS: IMPACT OF WHO GOES FIRST".center(100))
    print("="*100 + "\n")
    
    # Add student_goes_first column to df_deals if not already there
    if 'student_goes_first' not in df_deals.columns:
        # Need to re-query with student_goes_first
        query_deals_detailed = f"""
        SELECT 
            session_id,
            student_role,
            ai_role,
            use_memory,
            use_plan,
            student_goes_first,
            student_deal_json,
            ai_deal_json,
            transcript,
            created_at,
            updated_at
        FROM negotiation_sessions
        WHERE scenario_name = '{SCENARIO_FILTER}' AND deal_reached = 1
        ORDER BY created_at DESC
        """
        df_deals = pd.read_sql_query(query_deals_detailed, conn)
        
        # Re-apply all transformations
        df_deals['student_price'] = df_deals['student_deal_json'].apply(extract_price)
        df_deals['ai_price'] = df_deals['ai_deal_json'].apply(extract_price)
        df_deals['config'] = df_deals.apply(lambda r: get_config_label(r['use_memory'], r['use_plan']), axis=1)
        df_deals['duration'] = df_deals.apply(lambda r: calculate_duration(r['created_at'], r['updated_at']), axis=1)
        df_deals['rounds'] = df_deals['transcript'].apply(count_rounds)
        df_deals['student_role_label'] = df_deals['student_role'].map({
            'side1': 'Buyer (Fred)',
            'side2': 'Seller (Rosalind)'
        })
        df_deals['ai_role_label'] = df_deals['ai_role'].map({
            'side1': 'Buyer (Fred)',
            'side2': 'Seller (Rosalind)'
        })
    
    # Create detailed breakdown by config and who goes first
    for config in ['Base', 'M', 'P', 'M+P']:
        config_data = df_deals[df_deals['config'] == config]
        
        if len(config_data) > 0:
            print(f"\n{'─'*100}")
            print(f"📊 {config} Configuration")
            print(f"{'─'*100}")
            
            # Student goes first
            student_first = config_data[config_data['student_goes_first'] == True]
            ai_first = config_data[config_data['student_goes_first'] == False]
            
            print(f"\n🎯 When STUDENT goes first (n={len(student_first)}):")
            if len(student_first) > 0:
                print(f"   Average Price: ${student_first['student_price'].mean():,.0f}")
                print(f"   Median Price:  ${student_first['student_price'].median():,.0f}")
                print(f"   Range: ${student_first['student_price'].min():,.0f} - ${student_first['student_price'].max():,.0f}")
                
                # Breakdown by role
                buyer_student_first = student_first[student_first['student_role'] == 'side1']
                seller_student_first = student_first[student_first['student_role'] == 'side2']
                
                if len(buyer_student_first) > 0:
                    print(f"     → As Buyer (n={len(buyer_student_first)}): ${buyer_student_first['student_price'].mean():,.0f} avg")
                if len(seller_student_first) > 0:
                    print(f"     → As Seller (n={len(seller_student_first)}): ${seller_student_first['student_price'].mean():,.0f} avg")
            else:
                print("   No data")
            
            print(f"\n🤖 When AI goes first (n={len(ai_first)}):")
            if len(ai_first) > 0:
                print(f"   Average Price: ${ai_first['student_price'].mean():,.0f}")
                print(f"   Median Price:  ${ai_first['student_price'].median():,.0f}")
                print(f"   Range: ${ai_first['student_price'].min():,.0f} - ${ai_first['student_price'].max():,.0f}")
                
                # Breakdown by role
                buyer_ai_first = ai_first[ai_first['student_role'] == 'side1']
                seller_ai_first = ai_first[ai_first['student_role'] == 'side2']
                
                if len(buyer_ai_first) > 0:
                    print(f"     → As Buyer (n={len(buyer_ai_first)}): ${buyer_ai_first['student_price'].mean():,.0f} avg")
                if len(seller_ai_first) > 0:
                    print(f"     → As Seller (n={len(seller_ai_first)}): ${seller_ai_first['student_price'].mean():,.0f} avg")
            else:
                print("   No data")
            
            # Calculate impact
            if len(student_first) > 0 and len(ai_first) > 0:
                diff = student_first['student_price'].mean() - ai_first['student_price'].mean()
                print(f"\n💡 Impact: Student going first vs AI going first = ${abs(diff):,.0f} difference")
                if diff > 0:
                    print(f"   → Prices are HIGHER when student goes first")
                elif diff < 0:
                    print(f"   → Prices are LOWER when student goes first")
                else:
                    print(f"   → No difference")
    
    # Summary table
    print("\n" + "="*100)
    print("SUMMARY TABLE: WHO GOES FIRST IMPACT".center(100))
    print("="*100 + "\n")
    
    summary_data = []
    for config in ['Base', 'M', 'P', 'M+P']:
        config_data = df_deals[df_deals['config'] == config]
        if len(config_data) > 0:
            student_first = config_data[config_data['student_goes_first'] == True]
            ai_first = config_data[config_data['student_goes_first'] == False]
            
            summary_data.append({
                'Config': config,
                'Student First (n)': len(student_first),
                'Student First Avg': f"${student_first['student_price'].mean():,.0f}" if len(student_first) > 0 else "N/A",
                'AI First (n)': len(ai_first),
                'AI First Avg': f"${ai_first['student_price'].mean():,.0f}" if len(ai_first) > 0 else "N/A",
                'Difference': f"${abs(student_first['student_price'].mean() - ai_first['student_price'].mean()):,.0f}" 
                              if len(student_first) > 0 and len(ai_first) > 0 else "N/A"
            })
    
    if summary_data:
        summary_df = pd.DataFrame(summary_data)
        display(summary_df)
# Out:
# ====================================================================================================
#                             DETAILED ANALYSIS: IMPACT OF WHO GOES FIRST
# ====================================================================================================
#
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# 📊 Base Configuration
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# 🎯 When STUDENT goes first (n=19):
#    Average Price: $569,059
#    Median Price:  $560,000
#    Range: $480,000 - $650,000
#      → As Buyer (n=1): $595,000 avg
#      → As Seller (n=18): $567,438 avg
#
# 🤖 When AI goes first (n=23):
#    Average Price: $547,444
#    Median Price:  $545,000
#    Range: $465,000 - $670,000
#      → As Seller (n=23): $547,444 avg
#
# 💡 Impact: Student going first vs AI going first = $21,614 difference
#    → Prices are HIGHER when student goes first
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# 📊 M+P Configuration
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# 🎯 When STUDENT goes first (n=18):
#    Average Price: $557,107
#    Median Price:  $558,750
#    Range: $508,000 - $595,000
#      → As Seller (n=18): $557,107 avg
#
# 🤖 When AI goes first (n=21):
#    Average Price: $543,412
#    Median Price:  $548,000
#    Range: $500,000 - $630,000
#      → As Seller (n=21): $543,412 avg
#
# 💡 Impact: Student going first vs AI going first = $13,695 difference
#    → Prices are HIGHER when student goes first
#
# ====================================================================================================
#                                 SUMMARY TABLE: WHO GOES FIRST IMPACT
# ====================================================================================================
#   Config  Student First (n) Student First Avg  AI First (n) AI First Avg  \
# 0   Base                 19          $569,059            23     $547,444
# 1    M+P                 18          $557,107            21     $543,412
#
#   Difference
# 0    $21,614
# 1    $13,695

# %% [markdown]
# ---
# ## 4. 🧠 Memory (M) Evolution Tracking
#
# Track how AI memory evolves round-by-round

# %%
# ============================================================================
# Section 4: 🧠 Memory (M) Evolution Tracking
# ============================================================================

print_header("🧠 AI MEMORY EVOLUTION TRACKING")

# Use filtered df_all and query additional fields
memory_sessions = df_all[df_all['use_memory'] == True]['session_id'].tolist()

if len(memory_sessions) == 0:
    print("❌ No sessions with memory in filtered data")
else:
    # Query full details for memory sessions
    session_ids_str = "','".join(memory_sessions)
    query_memory = f"""
    SELECT 
        session_id,
        student_role,
        use_memory,
        use_plan,
        ai_memory,
        ai_memory_history,
        transcript,
        deal_reached,
        student_deal_json,
        ai_deal_json,
        created_at
    FROM negotiation_sessions
    WHERE session_id IN ('{session_ids_str}')
      AND ai_memory_history IS NOT NULL
      AND ai_memory_history != '[]'
    ORDER BY created_at DESC
    """
    
    df_memory = pd.read_sql_query(query_memory, conn)
    
    if len(df_memory) == 0:
        print("❌ No sessions with memory history data")
    else:
        print(f"Found {len(df_memory)} sessions with Memory tracking (from filtered data)\n")
        
        # ==================== STEP 1: LIST ALL MEMORY SESSIONS ====================
        print("="*150)
        print("📋 All Sessions with Memory (M) - Choose one to analyze")
        print("="*150)
        print(f"{'IDX':>4} | {'SESSION':>10} | {'CFG':>4} | {'ROLE':>6} | {'STATUS':>10} | {'PRICE':>10} | {'TIME':>12} | {'UPDATES':>7}")
        print("-"*150)
        
        for idx, row in df_memory.iterrows():
            config = get_config_label(row['use_memory'], row['use_plan'])
            status = "✅ Deal" if row['deal_reached'] else "❌ No Deal"
            role = "Buyer" if row['student_role'] == 'side1' else "Seller"
            created = pd.to_datetime(row['created_at']).strftime('%m-%d %H:%M')
            
            # Count memory updates
            memory_history = safe_json_load(row['ai_memory_history'])
            updates = len(memory_history) if memory_history else 0
            
            # Extract final price
            if row['deal_reached']:
                deal_json = safe_json_load(row['student_deal_json'])
                price = deal_json.get('final_price') if deal_json else None
                price_str = f"${price:,}" if price else "N/A"
            else:
                price_str = "---"
            
            print(f"{idx:>4} | {row['session_id'][:10]:>10} | {config:>4} | {role:>6} | {status:>10} | {price_str:>10} | {created:>12} | {updates:>7}")
        
        print("="*150)
        print("\n⚠️  Set session_idx below to analyze a specific session\n")
        
        # ==================== STEP 2: ANALYZE SELECTED SESSION ====================
        session_idx = 0  # ⚠️ CHANGE THIS to analyze different sessions
        
        if session_idx >= len(df_memory):
            print(f"❌ Invalid session_idx: {session_idx}. Max index is {len(df_memory)-1}")
        else:
            session = df_memory.iloc[session_idx]
            
            print("\n" + "="*120)
            print(f"📌 Analyzing Session: {session['session_id'][:8]}...")
            print("="*120)
            print(f"   Student Role: {'Buyer (Fred)' if session['student_role'] == 'side1' else 'Seller (Rosalind)'}")
            print(f"   Configuration: {get_config_label(session['use_memory'], session['use_plan'])}")
            print(f"   Deal Reached: {'✅ Yes' if session['deal_reached'] else '❌ No'}")
            
            # Show final price if deal reached
            if session['deal_reached']:
                deal_json = safe_json_load(session['student_deal_json'])
                if deal_json and 'final_price' in deal_json:
                    print(f"   Final Price: ${deal_json['final_price']:,}")
            
            memory_history = safe_json_load(session['ai_memory_history'])
            
            if memory_history and len(memory_history) > 0:
                print(f"   Total Memory Updates: {len(memory_history)}\n")
                
                # Show each memory state
                print("="*120)
                print("MEMORY EVOLUTION (Round-by-Round)")
                print("="*120)
                
                for i, memory_state in enumerate(memory_history):
                    round_info = memory_state.get('round', f'Update {i+1}')
                    content = memory_state.get('content', '')
                    
                    print(f"\n{'─'*120}")
                    print(f"🧠 MEMORY STATE #{i+1} | Round {round_info}")
                    print(f"{'─'*120}")
                    print(content)
                
                # Show final memory state
                print(f"\n\n{'='*120}")
                print(f"🎯 FINAL MEMORY STATE")
                print(f"{'='*120}")
                current_memory = session['ai_memory']
                if current_memory:
                    print(current_memory)
                else:
                    print("(empty)")
                print(f"{'='*120}")
                
                # Analysis statistics
                transcript = safe_json_load(session['transcript'])
                if transcript and len(transcript) > 0:
                    total_rounds = len(transcript) // 2
                    print(f"\n📊 Memory Evolution Statistics:")
                    print(f"{'─'*80}")
                    print(f"   Total Rounds Completed: {total_rounds}")
                    print(f"   Memory Updates: {len(memory_history)}")
                    if total_rounds > 0:
                        print(f"   Updates per Round: {len(memory_history)/total_rounds:.2f}")
                    print(f"{'─'*80}")
                else:
                    print(f"\n⚠️  No transcript data available for analysis")
            else:
                print("❌ No memory history data found for this session")
# Out:
# ====================================================================================================
#                                    🧠 AI MEMORY EVOLUTION TRACKING
# ====================================================================================================
#
# Found 44 sessions with Memory tracking (from filtered data)
#
# ======================================================================================================================================================
# 📋 All Sessions with Memory (M) - Choose one to analyze
# ======================================================================================================================================================
#  IDX |    SESSION |  CFG |   ROLE |     STATUS |      PRICE |         TIME | UPDATES
# ------------------------------------------------------------------------------------------------------------------------------------------------------
#    0 | 1da9f9c4-9 |  M+P | Seller |     ✅ Deal |        N/A |  12-10 19:49 |       3
#    1 | 16eceb2c-f |  M+P | Seller |     ✅ Deal |   $585,000 |  12-10 19:37 |       6
#    2 | 31db345d-a |  M+P | Seller |     ✅ Deal |   $565,000 |  12-10 19:35 |       5
#    3 | 1c047b8c-3 |  M+P | Seller |     ✅ Deal |   $550,000 |  12-10 19:35 |       5
#    4 | 1accb1db-0 |  M+P | Seller |     ✅ Deal |   $630,000 |  12-10 19:35 |       5
#    5 | 91bf642e-d |  M+P | Seller |     ✅ Deal |   $525,000 |  12-10 19:34 |       5
#    6 | 7443cda3-2 |  M+P | Seller |     ✅ Deal |   $540,000 |  12-10 19:34 |       4
#    7 | efc8ced7-5 |  M+P | Seller |     ✅ Deal |   $560,000 |  12-10 19:33 |       5
#    8 | 2707b436-d |  M+P | Seller |  ❌ No Deal |        --- |  12-10 19:32 |       3
#    9 | 98028e11-8 |  M+P | Seller |     ✅ Deal |   $552,000 |  12-10 19:31 |       5
#   10 | 19189653-d |  M+P | Seller |     ✅ Deal |        N/A |  12-10 19:31 |       4
#   11 | f8b904d4-f |  M+P | Seller |     ✅ Deal |   $585,000 |  12-10 19:28 |       6
#   12 | 516685e6-e |  M+P | Seller |     ✅ Deal |        N/A |  12-10 19:28 |       4
#   13 | d08ef3f9-f |  M+P | Seller |     ✅ Deal |        N/A |  12-10 19:26 |       4
#   14 | 0edb4787-0 |  M+P | Seller |     ✅ Deal |   $508,000 |  12-10 19:23 |       4
#   15 | 6c890dba-4 |  M+P | Seller |  ❌ No Deal |        --- |  12-10 19:22 |       3
#   16 | ff4187e1-4 |  M+P | Seller |     ✅ Deal |   $570,000 |  12-10 15:00 |       6
#   17 | 22e1c990-1 |  M+P | Seller |  ❌ No Deal |        --- |  12-10 14:52 |       2
#   18 | 583603ec-b |  M+P | Seller |     ✅ Deal |        N/A |  12-10 14:50 |       5
#   19 | 24a24ce4-e |  M+P | Seller |     ✅ Deal |   $555,000 |  12-10 14:49 |       4
#   20 | da8e805c-e |  M+P | Seller |     ✅ Deal |   $540,000 |  12-10 14:48 |       6
#   21 | 53c67d59-4 |  M+P | Seller |     ✅ Deal |        N/A |  12-10 14:47 |       5
#   22 | 7ab01b6d-8 |  M+P | Seller |     ✅ Deal |   $550,000 |  12-10 14:47 |       5
#   23 | a5a7bbed-a |  M+P | Seller |     ✅ Deal |   $555,000 |  12-10 14:47 |       5
#   24 | 81eafc5a-b |  M+P | Seller |     ✅ Deal |   $500,000 |  12-10 14:45 |       5
#   25 | fe68b67b-d |  M+P | Seller |     ✅ Deal |   $595,000 |  12-10 14:45 |       6
#   26 | a5291dbb-a |  M+P | Seller |     ✅ Deal |   $548,000 |  12-10 14:45 |       5
#   27 | baf91c79-b |  M+P | Seller |     ✅ Deal |   $550,000 |  12-10 14:45 |       6
#   28 | 9a00be6e-6 |  M+P | Seller |     ✅ Deal |        N/A |  12-10 14:43 |       4
#   29 | da734cf6-5 |  M+P | Seller |     ✅ Deal |   $550,000 |  12-10 14:43 |       5
#   30 | 023fa610-c |  M+P | Seller |  ❌ No Deal |        --- |  12-10 14:43 |       4
#   31 | 2e473faf-3 |  M+P | Seller |     ✅ Deal |   $560,000 |  12-10 14:43 |       5
#   32 | 73297254-b |  M+P | Seller |     ✅ Deal |   $505,000 |  12-10 14:42 |       2
#   33 | 34bd3d91-6 |  M+P | Seller |     ✅ Deal |   $578,500 |  12-10 14:41 |       6
#   34 | fef6c2b3-1 |  M+P | Seller |     ✅ Deal |   $520,000 |  12-10 14:41 |       5
#   35 | e15e86b4-c |  M+P | Seller |     ✅ Deal |   $540,000 |  12-10 14:40 |       4
#   36 | 33365183-4 |  M+P | Seller |     ✅ Deal |   $538,500 |  12-10 14:39 |       6
#   37 | 526567fb-b |  M+P | Seller |     ✅ Deal |        N/A |  12-10 14:39 |       4
#   38 | 6a1f1023-f |  M+P | Seller |     ✅ Deal |   $510,000 |  12-10 14:39 |       5
#   39 | 746b9508-0 |  M+P | Seller |     ✅ Deal |   $570,000 |  12-10 14:39 |       5
#   40 | 4093ffc5-4 |  M+P | Seller |     ✅ Deal |   $515,000 |  12-10 14:38 |       6
#   41 | 073b248f-5 |  M+P | Seller |     ✅ Deal |   $525,000 |  12-10 14:38 |       5
#   42 | 20260374-2 |  M+P | Seller |     ✅ Deal |   $562,500 |  12-10 14:38 |       5
#   43 | c29a5a57-5 |  M+P | Seller |  ❌ No Deal |        --- |  12-10 14:37 |       4
# ======================================================================================================================================================
#
# ⚠️  Set session_idx below to analyze a specific session
#
#
# ========================================================================================================================
# 📌 Analyzing Session: 1da9f9c4...
# ========================================================================================================================
#    Student Role: Seller (Rosalind)
#    Configuration: M+P
#    Deal Reached: ✅ Yes
#    Total Memory Updates: 3
#
# ========================================================================================================================
# MEMORY EVOLUTION (Round-by-Round)
# ========================================================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# 🧠 MEMORY STATE #1 | Round 1.2
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# OFFERS: [Us: Price: not yet; Them: Price: not yet; Them-best-for-us: none]
# OPPONENT PATTERNS: [Cordial; opened with rapport; asked about our interests/plans (info-gathering); no price anchor; no resistance signals yet]
# OPPONENT PRIORITIES: [Understanding buyer’s intended use/vision—Hypothesis (based on questions); Neighborhood/relationship goodwill—Hypothesis]
# OPPONENT CONSTRAINTS: [None stated]
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# 🧠 MEMORY STATE #2 | Round 2.2
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# OFFERS: [Us: Price: not yet→$495,000 [updated]; Them: Price: not yet→$620,000+ [updated] (cites comps $550–600k); Them-best-for-us: Price: $620,000+]
# OPPONENT PATTERNS: [Cordial; info-gathering continued (asked our timeline); pushed back on $495k with comps/monetization narrative; anchored high (>$620k); highlighted dual residential-commercial zoning; no acceptance of any part of our price; no mention of other offers]
# OPPONENT PRIORITIES: [Maximize price (target ≥$620k)—Stated; Validate value via dual zoning and “monetization opportunities”—Stated; Understand buyer timeline—Stated; Portfolio rebalancing motive—Stated; Neighborhood/relationship goodwill—Hypothesis]
# OPPONENT CONSTRAINTS: [Not in a rush on timing—Stated; Price floor ~>$620k—Hypothesis; Other offers: not yet]
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# 🧠 MEMORY STATE #3 | Round 3.2
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# OFFERS: [Us: Price: $510,000 [unchanged]; Them: Price: $620,000+→$550,000+ [updated]; Them-best-for-us: Price: $550,000+]
# OPPONENT PATTERNS: [Conceded materially on price (>$620k to >$550k); invoked written offers (no amounts) for leverage; probed our alternatives (why not use adjacent property); signals preference for our office-use plan; receptive to quick close if price meets target; no acceptance of our number]
# OPPONENT PRIORITIES: [Maximize price—High (Stated); Streamline holdings to SFH—Med (Stated); Quick, clean close—Med (Stated); Validate value via dual zoning/monetization—Med (Stated); Buyer fit/neighborhood goodwill—Low–Med (Hypothesis)]
# OPPONENT CONSTRAINTS: [Written offers exist—Stated; Not in a rush on timing—Stated; Price target ≥$550,000—Stated; Other offer details—Not disclosed]
#
#
# ========================================================================================================================
# 🎯 FINAL MEMORY STATE
# ========================================================================================================================
# OFFERS: [Us: Price: $510,000 [unchanged]; Them: Price: $620,000+→$550,000+ [updated]; Them-best-for-us: Price: $550,000+]
# OPPONENT PATTERNS: [Conceded materially on price (>$620k to >$550k); invoked written offers (no amounts) for leverage; probed our alternatives (why not use adjacent property); signals preference for our office-use plan; receptive to quick close if price meets target; no acceptance of our number]
# OPPONENT PRIORITIES: [Maximize price—High (Stated); Streamline holdings to SFH—Med (Stated); Quick, clean close—Med (Stated); Validate value via dual zoning/monetization—Med (Stated); Buyer fit/neighborhood goodwill—Low–Med (Hypothesis)]
# OPPONENT CONSTRAINTS: [Written offers exist—Stated; Not in a rush on timing—Stated; Price target ≥$550,000—Stated; Other offer details—Not disclosed]
# ========================================================================================================================
#
# 📊 Memory Evolution Statistics:
# ────────────────────────────────────────────────────────────────────────────────
#    Total Rounds Completed: 4
#    Memory Updates: 3
#    Updates per Round: 0.75
# ────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ---
# ## 5. 🎯 Planning (P) Strategy Tracking
#
# Track how AI planning evolves round-by-round

# %%
# ============================================================================
# Section 5: 🎯 Planning (P) Strategy Tracking
# ============================================================================

print_header("🎯 AI PLANNING STRATEGY TRACKING")

# Use filtered df_all and query additional fields
plan_sessions = df_all[df_all['use_plan'] == True]['session_id'].tolist()

if len(plan_sessions) == 0:
    print("❌ No sessions with planning in filtered data")
else:
    # Query full details for planning sessions
    session_ids_str = "','".join(plan_sessions)
    query_plan = f"""
    SELECT 
        session_id,
        student_role,
        use_memory,
        use_plan,
        ai_plan,
        ai_plan_history,
        transcript,
        deal_reached,
        student_deal_json,
        ai_deal_json,
        created_at
    FROM negotiation_sessions
    WHERE session_id IN ('{session_ids_str}')
      AND ai_plan_history IS NOT NULL
      AND ai_plan_history != '[]'
    ORDER BY created_at DESC
    """
    
    df_plan = pd.read_sql_query(query_plan, conn)
    
    if len(df_plan) == 0:
        print("❌ No sessions with plan history data")
    else:
        print(f"Found {len(df_plan)} sessions with Planning tracking (from filtered data)\n")
        
        # ==================== STEP 1: LIST ALL PLANNING SESSIONS ====================
        print("="*150)
        print("📋 All Sessions with Planning (P) - Choose one to analyze")
        print("="*150)
        print(f"{'IDX':>4} | {'SESSION':>10} | {'CFG':>4} | {'ROLE':>6} | {'STATUS':>10} | {'PRICE':>10} | {'TIME':>12} | {'UPDATES':>7}")
        print("-"*150)
        
        for idx, row in df_plan.iterrows():
            config = get_config_label(row['use_memory'], row['use_plan'])
            status = "✅ Deal" if row['deal_reached'] else "❌ No Deal"
            role = "Buyer" if row['student_role'] == 'side1' else "Seller"
            created = pd.to_datetime(row['created_at']).strftime('%m-%d %H:%M')
            
            # Count plan updates
            plan_history = safe_json_load(row['ai_plan_history'])
            updates = len(plan_history) if plan_history else 0
            
            # Extract final price
            if row['deal_reached']:
                deal_json = safe_json_load(row['student_deal_json'])
                price = deal_json.get('final_price') if deal_json else None
                price_str = f"${price:,}" if price else "N/A"
            else:
                price_str = "---"
            
            print(f"{idx:>4} | {row['session_id'][:10]:>10} | {config:>4} | {role:>6} | {status:>10} | {price_str:>10} | {created:>12} | {updates:>7}")
        
        print("="*150)
        print("\n⚠️  Set session_idx below to analyze a specific session\n")
        
        # ==================== STEP 2: ANALYZE SELECTED SESSION ====================
        session_idx = 0  # ⚠️ CHANGE THIS to analyze different sessions
        
        if session_idx >= len(df_plan):
            print(f"❌ Invalid session_idx: {session_idx}. Max index is {len(df_plan)-1}")
        else:
            session = df_plan.iloc[session_idx]
            
            print("\n" + "="*120)
            print(f"📌 Analyzing Session: {session['session_id'][:8]}...")
            print("="*120)
            print(f"   Student Role: {'Buyer (Fred)' if session['student_role'] == 'side1' else 'Seller (Rosalind)'}")
            print(f"   Configuration: {get_config_label(session['use_memory'], session['use_plan'])}")
            print(f"   Deal Reached: {'✅ Yes' if session['deal_reached'] else '❌ No'}")
            
            # Show final price if deal reached
            if session['deal_reached']:
                deal_json = safe_json_load(session['student_deal_json'])
                if deal_json and 'final_price' in deal_json:
                    print(f"   Final Price: ${deal_json['final_price']:,}")
            
            plan_history = safe_json_load(session['ai_plan_history'])
            
            if plan_history and len(plan_history) > 0:
                print(f"   Total Plan Updates: {len(plan_history)}\n")
                
                # Show each plan state
                print("="*120)
                print("PLANNING EVOLUTION (Round-by-Round)")
                print("="*120)
                
                for i, plan_state in enumerate(plan_history):
                    round_info = plan_state.get('round', f'Update {i+1}')
                    content = plan_state.get('content', '')
                    
                    print(f"\n{'─'*120}")
                    print(f"🎯 PLAN STATE #{i+1} | Round {round_info}")
                    print(f"{'─'*120}")
                    print(content)
                
                # Show final plan state
                print(f"\n\n{'='*120}")
                print(f"🏁 FINAL PLAN STATE")
                print(f"{'='*120}")
                current_plan = session['ai_plan']
                if current_plan:
                    print(current_plan)
                else:
                    print("(empty)")
                print(f"{'='*120}")
                
                # Analysis statistics
                transcript = safe_json_load(session['transcript'])
                if transcript and len(transcript) > 0:
                    total_rounds = len(transcript) // 2
                    print(f"\n📊 Planning Evolution Statistics:")
                    print(f"{'─'*80}")
                    print(f"   Total Rounds Completed: {total_rounds}")
                    print(f"   Plan Updates: {len(plan_history)}")
                    if total_rounds > 0:
                        print(f"   Updates per Round: {len(plan_history)/total_rounds:.2f}")
                    print(f"{'─'*80}")
                else:
                    print(f"\n⚠️  No transcript data available for analysis")
            else:
                print("❌ No plan history data found for this session")
# Out:
# ====================================================================================================
#                                   🎯 AI PLANNING STRATEGY TRACKING
# ====================================================================================================
#
# Found 49 sessions with Planning tracking (from filtered data)
#
# ======================================================================================================================================================
# 📋 All Sessions with Planning (P) - Choose one to analyze
# ======================================================================================================================================================
#  IDX |    SESSION |  CFG |   ROLE |     STATUS |      PRICE |         TIME | UPDATES
# ------------------------------------------------------------------------------------------------------------------------------------------------------
#    0 | 1da9f9c4-9 |  M+P | Seller |     ✅ Deal |        N/A |  12-10 19:49 |       3
#    1 | 16eceb2c-f |  M+P | Seller |     ✅ Deal |   $585,000 |  12-10 19:37 |       6
#    2 | 31db345d-a |  M+P | Seller |     ✅ Deal |   $565,000 |  12-10 19:35 |       5
#    3 | 1c047b8c-3 |  M+P | Seller |     ✅ Deal |   $550,000 |  12-10 19:35 |       6
#    4 | 1accb1db-0 |  M+P | Seller |     ✅ Deal |   $630,000 |  12-10 19:35 |       6
#    5 | 91bf642e-d |  M+P | Seller |     ✅ Deal |   $525,000 |  12-10 19:34 |       6
#    6 | 7443cda3-2 |  M+P | Seller |     ✅ Deal |   $540,000 |  12-10 19:34 |       5
#    7 | 0b0c3e36-0 |  M+P | Seller |  ❌ No Deal |        --- |  12-10 19:33 |       1
#    8 | efc8ced7-5 |  M+P | Seller |     ✅ Deal |   $560,000 |  12-10 19:33 |       6
#    9 | e4db51d8-b |  M+P | Seller |  ❌ No Deal |        --- |  12-10 19:32 |       1
#   10 | 2707b436-d |  M+P | Seller |  ❌ No Deal |        --- |  12-10 19:32 |       3
#   11 | 98028e11-8 |  M+P | Seller |     ✅ Deal |   $552,000 |  12-10 19:31 |       5
#   12 | 19189653-d |  M+P | Seller |     ✅ Deal |        N/A |  12-10 19:31 |       4
#   13 | f8b904d4-f |  M+P | Seller |     ✅ Deal |   $585,000 |  12-10 19:28 |       6
#   14 | 516685e6-e |  M+P | Seller |     ✅ Deal |        N/A |  12-10 19:28 |       5
#   15 | d08ef3f9-f |  M+P | Seller |     ✅ Deal |        N/A |  12-10 19:26 |       5
#   16 | 0edb4787-0 |  M+P | Seller |     ✅ Deal |   $508,000 |  12-10 19:23 |       4
#   17 | 6c890dba-4 |  M+P | Seller |  ❌ No Deal |        --- |  12-10 19:22 |       4
#   18 | ff4187e1-4 |  M+P | Seller |     ✅ Deal |   $570,000 |  12-10 15:00 |       6
#   19 | 22e1c990-1 |  M+P | Seller |  ❌ No Deal |        --- |  12-10 14:52 |       2
#   20 | 583603ec-b |  M+P | Seller |     ✅ Deal |        N/A |  12-10 14:50 |       5
#   21 | f727eff6-e |  M+P | Seller |  ❌ No Deal |        --- |  12-10 14:49 |       1
#   22 | 24a24ce4-e |  M+P | Seller |     ✅ Deal |   $555,000 |  12-10 14:49 |       4
#   23 | da8e805c-e |  M+P | Seller |     ✅ Deal |   $540,000 |  12-10 14:48 |       6
#   24 | 53c67d59-4 |  M+P | Seller |     ✅ Deal |        N/A |  12-10 14:47 |       5
#   25 | 7ab01b6d-8 |  M+P | Seller |     ✅ Deal |   $550,000 |  12-10 14:47 |       6
#   26 | a5a7bbed-a |  M+P | Seller |     ✅ Deal |   $555,000 |  12-10 14:47 |       6
#   27 | 81eafc5a-b |  M+P | Seller |     ✅ Deal |   $500,000 |  12-10 14:45 |       6
#   28 | fe68b67b-d |  M+P | Seller |     ✅ Deal |   $595,000 |  12-10 14:45 |       6
#   29 | a5291dbb-a |  M+P | Seller |     ✅ Deal |   $548,000 |  12-10 14:45 |       6
#   30 | baf91c79-b |  M+P | Seller |     ✅ Deal |   $550,000 |  12-10 14:45 |       6
#   31 | 9a00be6e-6 |  M+P | Seller |     ✅ Deal |        N/A |  12-10 14:43 |       5
#   32 | da734cf6-5 |  M+P | Seller |     ✅ Deal |   $550,000 |  12-10 14:43 |       6
#   33 | 023fa610-c |  M+P | Seller |  ❌ No Deal |        --- |  12-10 14:43 |       5
#   34 | 2e473faf-3 |  M+P | Seller |     ✅ Deal |   $560,000 |  12-10 14:43 |       6
#   35 | 73297254-b |  M+P | Seller |     ✅ Deal |   $505,000 |  12-10 14:42 |       3
#   36 | 34bd3d91-6 |  M+P | Seller |     ✅ Deal |   $578,500 |  12-10 14:41 |       6
#   37 | fef6c2b3-1 |  M+P | Seller |     ✅ Deal |   $520,000 |  12-10 14:41 |       6
#   38 | e15e86b4-c |  M+P | Seller |     ✅ Deal |   $540,000 |  12-10 14:40 |       5
#   39 | 33365183-4 |  M+P | Seller |     ✅ Deal |   $538,500 |  12-10 14:39 |       6
#   40 | 526567fb-b |  M+P | Seller |     ✅ Deal |        N/A |  12-10 14:39 |       5
#   41 | 6a1f1023-f |  M+P | Seller |     ✅ Deal |   $510,000 |  12-10 14:39 |       6
#   42 | 746b9508-0 |  M+P | Seller |     ✅ Deal |   $570,000 |  12-10 14:39 |       6
#   43 | 4093ffc5-4 |  M+P | Seller |     ✅ Deal |   $515,000 |  12-10 14:38 |       6
#   44 | 073b248f-5 |  M+P | Seller |     ✅ Deal |   $525,000 |  12-10 14:38 |       6
#   45 | 82de1f8e-b |  M+P | Seller |  ❌ No Deal |        --- |  12-10 14:38 |       1
#   46 | 20260374-2 |  M+P | Seller |     ✅ Deal |   $562,500 |  12-10 14:38 |       5
#   47 | 8fe436e8-b |  M+P | Seller |  ❌ No Deal |        --- |  12-10 14:37 |       1
#   48 | c29a5a57-5 |  M+P | Seller |  ❌ No Deal |        --- |  12-10 14:37 |       5
# ======================================================================================================================================================
#
# ⚠️  Set session_idx below to analyze a specific session
#
#
# ========================================================================================================================
# 📌 Analyzing Session: 1da9f9c4...
# ========================================================================================================================
#    Student Role: Seller (Rosalind)
#    Configuration: M+P
#    Deal Reached: ✅ Yes
#    Total Plan Updates: 3
#
# ========================================================================================================================
# PLANNING EVOLUTION (Round-by-Round)
# ========================================================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# 🎯 PLAN STATE #1 | Round 1.2
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# - ROUND GOAL: Set an aggressive low anchor at $495,000; probe Rosalind’s urgency and constraints; elicit a concrete counter while revealing minimal info about our plans.
# - KEY LEVERS: Price; local market softness (lobster downturn); property condition/deferred maintenance; current occupancy/income; seller timing/urgency; presence/absence of other offers.
# - TACTICS: Build brief rapport; ask 3 probes: “What’s got you selling now?”, “Any timing you need to hit?”, “How are the units performing/any recent repairs or vacancies?”; deflect detailed future-use questions; present $495k with calm, data-framed rationale; reference viable alternatives in town; invite her counter; use silence; avoid signaling strong need for this parcel.
# - OFFER SCAFFOLD: Price: $495,000.
# - ANCHORING NOTE: Frame $495k off conservative rental comps/cap rate and needed updates; market is soft; as-is pricing expectation.
# - INFORMATION CONTROL: Do not reveal adjacency/synergy or max willingness; keep plans “small professional offices.”
# - CONCESSION PLAN (internal): If pushed, one small move only to $510–$515k; otherwise hold at $495k and ask for her number.
# - ADAPTATION TRIGGER: If she counters above $600k without justification, re-assert comps/market softness and re-ask about urgency/alternatives to pressure downward.
# - CLOSING DECISION: Do not accept this round; aim to secure a counter and anchor the bargaining range in the low- to mid-500s.
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# 🎯 PLAN STATE #2 | Round 2.2
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# - ROUND GOAL: Pull anchor from $620k+ into low-500s; secure concrete downward movement; table a firm $510,000 counter and surface any urgency/competing offers.
# - KEY LEVERS: Price comps/cap rates (as rental $550–600k needing updates); market softness (lobster downturn); as-is condition/deferred maintenance; tenant stability/income; absence of other offers; seller “portfolio rebalancing” motive.
# - TACTICS: Calmly reject $620k+ as above as-is value; reframe on income approach and current condition; ask 3 probes: (1) Do you have any written offers near your number? (2) Vacancies/repairs in last 12 months and current rents? (3) If price is right, is a clean, quick close attractive?; signal I’m shopping alternatives; avoid revealing adjacency/synergy; after stating offer, go quiet and invite a move sub-$575k.
# - OFFER SCAFFOLD: Price: $510,000 (as-is).
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# 🎯 PLAN STATE #3 | Round 3.2
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# - ROUND GOAL: Drag seller’s floor below $540k; secure movement toward $515–$525; table a small but credible concession at $515k.
# - KEY LEVERS: Rental comps/market softness (triplex as-is ~550–600k); deferred maintenance/as-is condition; test “written offers” (amounts/conditions); seller portfolio simplification; quick, clean close as rationale (not a give).
# - TACTICS: Acknowledge her movement; reframe 550k as still above as-is value; probe: “What are the exact numbers/conditions on those written offers—any firm above 540k?”; counter at $515k framed as today’s stretch for speed/certainty; signal alternatives; if she backtracks, anchor to her 550k prior; state number once, then go quiet.
# - OFFER SCAFFOLD: Price: $515,000 (as-is).
#
#
# ========================================================================================================================
# 🏁 FINAL PLAN STATE
# ========================================================================================================================
# - ROUND GOAL: Drag seller’s floor below $540k; secure movement toward $515–$525; table a small but credible concession at $515k.
# - KEY LEVERS: Rental comps/market softness (triplex as-is ~550–600k); deferred maintenance/as-is condition; test “written offers” (amounts/conditions); seller portfolio simplification; quick, clean close as rationale (not a give).
# - TACTICS: Acknowledge her movement; reframe 550k as still above as-is value; probe: “What are the exact numbers/conditions on those written offers—any firm above 540k?”; counter at $515k framed as today’s stretch for speed/certainty; signal alternatives; if she backtracks, anchor to her 550k prior; state number once, then go quiet.
# - OFFER SCAFFOLD: Price: $515,000 (as-is).
# ========================================================================================================================
#
# 📊 Planning Evolution Statistics:
# ────────────────────────────────────────────────────────────────────────────────
#    Total Rounds Completed: 4
#    Plan Updates: 3
#    Updates per Round: 0.75
# ────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ---
# ## 6. 💬 Full Transcript Viewer
#
# Display complete conversation transcripts

# %%
# ============================================================================
# Section 6: 💬 Full Transcript Viewer
# ============================================================================

print_header("💬 FULL CONVERSATION TRANSCRIPT")

# df_deals should already be filtered from Section 3
# But let's make sure it's using the filtered sessions
if 'df_deals' not in locals() or len(df_deals) == 0:
    print("❌ No deal data available. Please run Section 3 first.")
else:
    print(f"Found {len(df_deals)} successful deals (from filtered data)\n")
    
    # ==================== STEP 1: LIST ALL SUCCESSFUL DEALS ====================
    print("="*120)
    print("📋 All Successful Deals - Choose one to view transcript")
    print("="*120)
    
    for idx, row in df_deals.iterrows():
        price = row['student_price']
        config = row['config']
        role = row['student_role_label']
        created = pd.to_datetime(row['created_at']).strftime('%m-%d %H:%M')
        rounds = row['rounds']
        duration = row['duration']
        
        print(f"{idx:3d}. {row['session_id'][:8]}... | {role:17s} | {config:4s} | ${price:>7,.0f} | {rounds} rounds | {duration:.1f} min | {created}")
    
    print("="*120)
    print("\n⚠️  Set session_to_view below to view a specific transcript\n")
    
    # ==================== STEP 2: VIEW SELECTED TRANSCRIPT ====================
    session_to_view = 10  # ⚠️ CHANGE THIS to view different sessions
    
    if session_to_view >= len(df_deals):
        print(f"❌ Invalid session_to_view: {session_to_view}. Max index is {len(df_deals)-1}")
    else:
        session = df_deals.iloc[session_to_view]
        
        print("\n" + "="*120)
        print(f"📌 Viewing Transcript: {session['session_id'][:8]}...")
        print("="*120)
        print(f"   Student Role: {session['student_role_label']}")
        print(f"   AI Role: {session['ai_role_label']}")
        print(f"   Configuration: {session['config']}")
        print(f"   Final Price: ${session['student_price']:,.0f}")
        print(f"   Rounds: {session['rounds']}")
        print(f"   Duration: {session['duration']:.1f} minutes\n")
        
        transcript = safe_json_load(session['transcript'])
        
        if transcript and len(transcript) > 0:
            print("="*120)
            print("CONVERSATION TRANSCRIPT")
            print("="*120)
            
            for i, message in enumerate(transcript):
                # Parse message format: "Round X.Y - Label: content"
                if " - " in message:
                    parts = message.split(" - ", 1)
                    round_info = parts[0]
                    
                    if len(parts) > 1 and ": " in parts[1]:
                        label, content = parts[1].split(": ", 1)
                        
                        # Determine icon based on role
                        if "Fred" in label or "Buyer" in label:
                            icon = "🏢"
                        elif "Rosalind" in label or "Seller" in label:
                            icon = "🏘️"
                        else:
                            icon = "💬"
                        
                        print(f"\n{icon} {round_info} - {label}")
                        print("─"*120)
                        print(content)
                    else:
                        print(f"\n💬 {round_info}")
                        print("─"*120)
                        print(parts[1] if len(parts) > 1 else message)
                else:
                    print(f"\n💬 Message {i+1}")
                    print("─"*120)
                    print(message)
            
            print("\n" + "="*120)
            print(f"✅ Deal reached at price: ${session['student_price']:,.0f}")
            print("="*120)
        else:
            print("❌ No transcript data available for this session")
# Out:
# ====================================================================================================
#                                    💬 FULL CONVERSATION TRANSCRIPT
# ====================================================================================================
#
# Found 81 successful deals (from filtered data)
#
# ========================================================================================================================
# 📋 All Successful Deals - Choose one to view transcript
# ========================================================================================================================
#   0. f81e9731... | Seller (Rosalind) | Base | $670,000 | 6 rounds | 7.2 min | 12-10 20:01
#   1. b37f26ac... | Seller (Rosalind) | Base | $575,000 | 4 rounds | 7.1 min | 12-10 19:52
#   2. 1da9f9c4... | Seller (Rosalind) | M+P  | $    nan | 4 rounds | 29.1 min | 12-10 19:49
#   3. 0ad06bea... | Seller (Rosalind) | Base | $465,000 | 6 rounds | 11.4 min | 12-10 19:44
#   4. 799f52db... | Seller (Rosalind) | Base | $549,000 | 6 rounds | 27.0 min | 12-10 19:39
#   5. 95e44a5d... | Seller (Rosalind) | Base | $570,000 | 6 rounds | 8.7 min | 12-10 19:38
#   6. 16eceb2c... | Seller (Rosalind) | M+P  | $585,000 | 8 rounds | 42.6 min | 12-10 19:37
#   7. 798d365f... | Buyer (Fred)      | Base | $595,000 | 5 rounds | 12.4 min | 12-10 19:36
#   8. 31db345d... | Seller (Rosalind) | M+P  | $565,000 | 5 rounds | 22.7 min | 12-10 19:35
#   9. 88bdd965... | Seller (Rosalind) | Base | $    nan | 5 rounds | 20.5 min | 12-10 19:35
#  10. 50f35769... | Seller (Rosalind) | Base | $    nan | 5 rounds | 20.2 min | 12-10 19:35
#  11. 1c047b8c... | Seller (Rosalind) | M+P  | $550,000 | 6 rounds | 25.3 min | 12-10 19:35
#  12. 1accb1db... | Seller (Rosalind) | M+P  | $630,000 | 6 rounds | 44.0 min | 12-10 19:35
#  13. bb74becf... | Seller (Rosalind) | Base | $    nan | 6 rounds | 18.4 min | 12-10 19:35
#  14. 91bf642e... | Seller (Rosalind) | M+P  | $525,000 | 6 rounds | 20.2 min | 12-10 19:34
#  15. 7443cda3... | Seller (Rosalind) | M+P  | $540,000 | 5 rounds | 18.1 min | 12-10 19:34
#  16. 562a5935... | Seller (Rosalind) | Base | $590,000 | 6 rounds | 24.7 min | 12-10 19:33
#  17. efc8ced7... | Seller (Rosalind) | M+P  | $560,000 | 6 rounds | 24.0 min | 12-10 19:33
#  18. 98028e11... | Seller (Rosalind) | M+P  | $552,000 | 6 rounds | 25.4 min | 12-10 19:31
#  19. 9864a8ac... | Seller (Rosalind) | Base | $512,500 | 5 rounds | 20.3 min | 12-10 19:31
#  20. 19189653... | Seller (Rosalind) | M+P  | $    nan | 5 rounds | 31.8 min | 12-10 19:31
#  21. 65568ba8... | Seller (Rosalind) | Base | $    nan | 5 rounds | 26.6 min | 12-10 19:30
#  22. 09116786... | Seller (Rosalind) | Base | $650,000 | 6 rounds | 29.2 min | 12-10 19:29
#  23. f8b904d4... | Seller (Rosalind) | M+P  | $585,000 | 7 rounds | 41.2 min | 12-10 19:28
#  24. 2b985adf... | Seller (Rosalind) | Base | $555,000 | 6 rounds | 49.8 min | 12-10 19:28
#  25. 516685e6... | Seller (Rosalind) | M+P  | $    nan | 5 rounds | 38.1 min | 12-10 19:28
#  26. d08ef3f9... | Seller (Rosalind) | M+P  | $    nan | 5 rounds | 34.2 min | 12-10 19:26
#  27. 4eb7d6b7... | Seller (Rosalind) | Base | $550,000 | 6 rounds | 11.5 min | 12-10 19:23
#  28. 0edb4787... | Seller (Rosalind) | M+P  | $508,000 | 5 rounds | 29.3 min | 12-10 19:23
#  29. fef88ef0... | Seller (Rosalind) | Base | $    nan | 6 rounds | 30.3 min | 12-10 15:48
#  30. f8108b66... | Seller (Rosalind) | Base | $490,000 | 5 rounds | 16.4 min | 12-10 15:37
#  31. 8f327691... | Seller (Rosalind) | Base | $545,000 | 6 rounds | 18.6 min | 12-10 15:09
#  32. def6ce77... | Seller (Rosalind) | Base | $530,000 | 6 rounds | 11.0 min | 12-10 15:07
#  33. ff4187e1... | Seller (Rosalind) | M+P  | $570,000 | 6 rounds | 20.5 min | 12-10 15:00
#  34. 2c58997c... | Seller (Rosalind) | Base | $535,000 | 6 rounds | 9.2 min | 12-10 14:59
#  35. 1c64c52d... | Seller (Rosalind) | Base | $600,000 | 6 rounds | 14.9 min | 12-10 14:57
#  36. 320f365c... | Seller (Rosalind) | Base | $600,000 | 6 rounds | 17.3 min | 12-10 14:50
#  37. 583603ec... | Seller (Rosalind) | M+P  | $    nan | 6 rounds | 17.6 min | 12-10 14:50
#  38. 24a24ce4... | Seller (Rosalind) | M+P  | $555,000 | 4 rounds | 15.0 min | 12-10 14:49
#  39. da8e805c... | Seller (Rosalind) | M+P  | $540,000 | 6 rounds | 29.4 min | 12-10 14:48
#  40. bb4f01c8... | Seller (Rosalind) | Base | $535,000 | 6 rounds | 11.5 min | 12-10 14:48
#  41. fefa4d90... | Seller (Rosalind) | Base | $    nan | 5 rounds | 28.4 min | 12-10 14:48
#  42. 53c67d59... | Seller (Rosalind) | M+P  | $    nan | 6 rounds | 30.1 min | 12-10 14:47
#  43. fae036e8... | Seller (Rosalind) | Base | $550,000 | 6 rounds | 20.8 min | 12-10 14:47
#  44. e014a8cd... | Seller (Rosalind) | Base | $550,000 | 6 rounds | 32.3 min | 12-10 14:47
#  45. bf242471... | Seller (Rosalind) | Base | $540,000 | 5 rounds | 10.9 min | 12-10 14:47
#  46. daa71a3a... | Seller (Rosalind) | Base | $540,000 | 6 rounds | 26.5 min | 12-10 14:47
#  47. 187ee6e1... | Seller (Rosalind) | Base | $560,000 | 6 rounds | 18.6 min | 12-10 14:47
#  48. 7ab01b6d... | Seller (Rosalind) | M+P  | $550,000 | 6 rounds | 19.1 min | 12-10 14:47
#  49. a5a7bbed... | Seller (Rosalind) | M+P  | $555,000 | 6 rounds | 25.2 min | 12-10 14:47
#  50. f0c044d9... | Seller (Rosalind) | Base | $575,000 | 6 rounds | 11.3 min | 12-10 14:46
#  51. cba8d9c9... | Seller (Rosalind) | Base | $590,000 | 6 rounds | 21.2 min | 12-10 14:46
#  52. 5c9d6f09... | Seller (Rosalind) | Base | $    nan | 5 rounds | 24.1 min | 12-10 14:46
#  53. 118af3de... | Seller (Rosalind) | Base | $545,000 | 5 rounds | 13.8 min | 12-10 14:46
#  54. 486f9419... | Seller (Rosalind) | Base | $535,000 | 4 rounds | 15.6 min | 12-10 14:46
#  55. 13697589... | Seller (Rosalind) | Base | $480,000 | 6 rounds | 22.9 min | 12-10 14:46
#  56. 81eafc5a... | Seller (Rosalind) | M+P  | $500,000 | 6 rounds | 23.0 min | 12-10 14:45
#  57. fe68b67b... | Seller (Rosalind) | M+P  | $595,000 | 6 rounds | 18.6 min | 12-10 14:45
#  58. a5291dbb... | Seller (Rosalind) | M+P  | $548,000 | 6 rounds | 40.5 min | 12-10 14:45
#  59. baf91c79... | Seller (Rosalind) | M+P  | $550,000 | 6 rounds | 29.5 min | 12-10 14:45
#  60. ed40d7bb... | Seller (Rosalind) | Base | $517,500 | 6 rounds | 31.0 min | 12-10 14:44
#  61. 9a00be6e... | Seller (Rosalind) | M+P  | $    nan | 5 rounds | 18.4 min | 12-10 14:43
#  62. da734cf6... | Seller (Rosalind) | M+P  | $550,000 | 7 rounds | 33.9 min | 12-10 14:43
#  63. 2e473faf... | Seller (Rosalind) | M+P  | $560,000 | 6 rounds | 22.3 min | 12-10 14:43
#  64. 35cd2da6... | Seller (Rosalind) | Base | $549,000 | 6 rounds | 28.1 min | 12-10 14:42
#  65. 73297254... | Seller (Rosalind) | M+P  | $505,000 | 3 rounds | 6.7 min | 12-10 14:42
#  66. 34bd3d91... | Seller (Rosalind) | M+P  | $578,500 | 6 rounds | 31.4 min | 12-10 14:41
#  67. fef6c2b3... | Seller (Rosalind) | M+P  | $520,000 | 6 rounds | 32.3 min | 12-10 14:41
#  68. e15e86b4... | Seller (Rosalind) | M+P  | $540,000 | 5 rounds | 34.2 min | 12-10 14:40
#  69. cdb4b68d... | Seller (Rosalind) | Base | $650,000 | 7 rounds | 27.1 min | 12-10 14:40
#  70. 33365183... | Seller (Rosalind) | M+P  | $538,500 | 6 rounds | 41.2 min | 12-10 14:39
#  71. fabc68b2... | Seller (Rosalind) | Base | $535,000 | 6 rounds | 42.7 min | 12-10 14:39
#  72. 526567fb... | Seller (Rosalind) | M+P  | $    nan | 5 rounds | 24.5 min | 12-10 14:39
#  73. 6a1f1023... | Seller (Rosalind) | M+P  | $510,000 | 6 rounds | 28.9 min | 12-10 14:39
#  74. 746b9508... | Seller (Rosalind) | M+P  | $570,000 | 6 rounds | 34.9 min | 12-10 14:39
#  75. 2527e1ea... | Seller (Rosalind) | Base | $575,000 | 6 rounds | 18.6 min | 12-10 14:39
#  76. 4093ffc5... | Seller (Rosalind) | M+P  | $515,000 | 6 rounds | 21.2 min | 12-10 14:38
#  77. 073b248f... | Seller (Rosalind) | M+P  | $525,000 | 6 rounds | 33.7 min | 12-10 14:38
#  78. 20260374... | Seller (Rosalind) | M+P  | $562,500 | 6 rounds | 26.2 min | 12-10 14:38
#  79. 9992a0ff... | Seller (Rosalind) | Base | $640,000 | 6 rounds | 11.8 min | 12-10 00:31
#  80. 7271f344... | Seller (Rosalind) | Base | $480,000 | 2 rounds | 4.6 min | 12-10 00:11
# ========================================================================================================================
#
# ⚠️  Set session_to_view below to view a specific transcript
#
#
# ========================================================================================================================
# 📌 Viewing Transcript: 50f35769...
# ========================================================================================================================
#    Student Role: Seller (Rosalind)
#    AI Role: Buyer (Fred)
#    Configuration: Base
#    Final Price: $nan
#    Rounds: 5
#    Duration: 20.2 minutes
#
# ========================================================================================================================
# CONVERSATION TRANSCRIPT
# ========================================================================================================================
#
# 🏢 Round 1.1 - Fred Starr (Buyer)
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Rosalind, Fred Starr here. I’ve had my eye on 123 Main. Looking at today’s rents and cap rates, as a stand‑alone triplex it pencils out in the mid‑500s at best, especially with the market a bit soft—lobster prices aren’t helping anyone’s numbers right now.
#
# I’m prepared to do $500,000 for the property.
#
# What’s got you thinking about selling now? Are you on any sort of timeline, and do you already have other offers or a number you’re trying to hit?
#
# 🏘️ Round 1.2 - Rosalind Cain (Seller)
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Thank you for your interest and offer. This however is very far from what I expected to sell at. I have fielded a lot of interest as people see the lobster numbers as a temporary dip and attractive window to bid, since we all know that the prices are bound to recoup and reach their highest levels in history. So I appreciate your entrepreneurial spirit, but I am afraid you are not alone. Tell me, what would you do if we do not agree on a deal here?
#
# 🏢 Round 2.1 - Fred Starr (Buyer)
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Rosalind, I hear you. If we don’t land a deal, I’ll keep pushing ahead on other sites—I’m not forced to buy 123 Main. If you’ve got a written offer at a number you truly like, no hard feelings—take it.
#
# What’s driving your sale right now—freeing up capital or streamlining the portfolio? And are you on any kind of timeline?
#
# On price, the math today is still tight with rents, rates, and looming capex. I can move to $515,000. If there’s a number you’d actually sign this week, tell me what it is.
#
# 🏘️ Round 2.2 - Rosalind Cain (Seller)
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# I've been seeing rates on similar properties for 750,000-800,000. So I feel like you are trying to low ball me here. Given that I am in not a rush but appreciate you being so direct, I could try to do something a bit below market price. 730,000 would be something I could move to, barely. I think that would be a fair deal, given my great reputation here, the location and overall circumstance that I am in no rush to sell here.
#
# 🏢 Round 3.1 - Fred Starr (Buyer)
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Rosalind, 730 isn’t going to work for me. The 750–800 you’re seeing—are those closed sales or just list prices? Because at today’s rents, higher taxes/insurance, and with inevitable capex on an older mixed‑use, those numbers don’t pencil for a triplex in Yarmouth.
#
# If you want a certain, clean exit, I can do $550,000—no financing contingency, as‑is, quick close in 14 days. I’ll put up a strong deposit and keep it simple.
#
# If you’ve truly got a higher, firm offer in hand, I won’t chase it. But if you can meet me in the fives, we can ink this this week. What’s the lowest number you’d actually sign today?
#
# 🏘️ Round 3.2 - Rosalind Cain (Seller)
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Hmm okay I see. I mean those terms do sound good, but I actually do not care about a quick close. If you care about having more time to get the financing right here, I could wait with the close and give you more time to get the capital in place. But on price I am unfortunately not able to move a lot. Is there any world in which we can agree on 690,000? Happy to work around the details of the deal if that price stands.
#
# 🏢 Round 4.1 - Fred Starr (Buyer)
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Rosalind, I appreciate the flexibility, but price is the whole ballgame for me. 690 won’t happen.
#
# On the numbers I’m seeing for a Yarmouth triplex—today’s rents, taxes/insurance, and the capex that comes with an older mixed‑use—this lives in the mid‑fives. Retail is soft right now, and I’m not paying future upside prices.
#
# I can move to 585,000. Straightforward deal, no drama. If that works, I’ll sign this week. If you truly have someone paying a lot more, take it—no hard feelings. Otherwise, are we doing this at 585?
#
# 🏘️ Round 4.2 - Rosalind Cain (Seller)
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Thank you for being flexible, but anything below 650,000 is just not worth my time. Lets sign this right here at 650 and I will keep your goodwill and professionalism in mind for any future negotations. On this property I am just not as flexible in price - I would be happy to work with you for this price even though I'd making some sacrifices.
# Deal?
#
# 🏢 Round 5.1 - Fred Starr (Buyer)
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Rosalind, 650 won’t work for me.
#
# I can stretch to 630,000—this is my ceiling for 123 Main based on today’s rents and the capex it needs. If that number works, I’ll say yes right now and we’re done.
#
# Can you do 630?
#
# 🏘️ Round 5.2 - Rosalind Cain (Seller)
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# $DEAL_REACHED$
#
# 🏢 Round 5.2 - Fred Starr (Buyer)
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# $DEAL_REACHED$
# {
#   "final_price": 630000
# }
#
# ========================================================================================================================
# ✅ Deal reached at price: $nan
# ========================================================================================================================

# %% [markdown]
# ---
# ## 7. 📊 Performance Metrics Dashboard
#
# Comprehensive performance metrics across all sessions

# %%
print_header("📊 PERFORMANCE METRICS DASHBOARD")

# Overall success rates
print_subheader("✅ Success Rates by Configuration")
success_by_config = df_all.groupby('Config').agg({
    'deal_reached': ['sum', 'count', 'mean']
})
success_by_config.columns = ['Successful', 'Total', 'Success Rate']
success_by_config['Success Rate'] = (success_by_config['Success Rate'] * 100).round(1)
print(success_by_config.to_string())

# Duration analysis
if len(df_deals) > 0:
    print_subheader("⏱️ Duration Analysis (Successful Deals Only)")
    duration_by_config = df_deals.groupby('config')['duration'].agg(['count', 'mean', 'median', 'min', 'max'])
    duration_by_config = duration_by_config.round(1)
    duration_by_config.columns = ['N', 'Mean (min)', 'Median (min)', 'Min (min)', 'Max (min)']
    print(duration_by_config.to_string())
    
    # Rounds analysis
    print_subheader("🔄 Rounds Analysis (Successful Deals Only)")
    rounds_by_config = df_deals.groupby('config')['rounds'].agg(['count', 'mean', 'median', 'min', 'max'])
    rounds_by_config = rounds_by_config.round(1)
    rounds_by_config.columns = ['N', 'Mean', 'Median', 'Min', 'Max']
    print(rounds_by_config.to_string())

# Efficiency metrics
print_subheader("⚡ Efficiency: Minutes per Round")
if len(df_deals) > 0:
    df_deals['min_per_round'] = df_deals['duration'] / df_deals['rounds']
    efficiency = df_deals.groupby('config')['min_per_round'].agg(['mean', 'median']).round(2)
    efficiency.columns = ['Mean (min/round)', 'Median (min/round)']
    print(efficiency.to_string())

# Value distribution by role
if len(df_deals) > 0:
    print_subheader("💰 Price Distribution by Student Role")
    
    print("\nWhen Student is BUYER (wants lower price):")
    buyer_deals = df_deals[df_deals['student_role'] == 'side1']
    if len(buyer_deals) > 0:
        buyer_stats = buyer_deals.groupby('config')['student_price'].agg(['count', 'mean', 'median'])
        buyer_stats['mean'] = buyer_stats['mean'].apply(lambda x: f"${x:,.0f}")
        buyer_stats['median'] = buyer_stats['median'].apply(lambda x: f"${x:,.0f}")
        buyer_stats.columns = ['N', 'Mean Price', 'Median Price']
        print(buyer_stats.to_string())
    else:
        print("  No data")
    
    print("\nWhen Student is SELLER (wants higher price):")
    seller_deals = df_deals[df_deals['student_role'] == 'side2']
    if len(seller_deals) > 0:
        seller_stats = seller_deals.groupby('config')['student_price'].agg(['count', 'mean', 'median'])
        seller_stats['mean'] = seller_stats['mean'].apply(lambda x: f"${x:,.0f}")
        seller_stats['median'] = seller_stats['median'].apply(lambda x: f"${x:,.0f}")
        seller_stats.columns = ['N', 'Mean Price', 'Median Price']
        print(seller_stats.to_string())
    else:
        print("  No data")

print("\n" + "="*100)
# Out:
# ====================================================================================================
#                                   📊 PERFORMANCE METRICS DASHBOARD
# ====================================================================================================
#
#
# --------------------------------------------------------------------------------
# ✅ Success Rates by Configuration
# --------------------------------------------------------------------------------
#         Successful  Total  Success Rate
# Config
# Base            40     60          66.7
# M+P             39     51          76.5
#
# --------------------------------------------------------------------------------
# ⏱️ Duration Analysis (Successful Deals Only)
# --------------------------------------------------------------------------------
#          N  Mean (min)  Median (min)  Min (min)  Max (min)
# config
# Base    42        19.9          18.6        4.6       49.8
# M+P     39        27.8          28.9        6.7       44.0
#
# --------------------------------------------------------------------------------
# 🔄 Rounds Analysis (Successful Deals Only)
# --------------------------------------------------------------------------------
#          N  Mean  Median  Min  Max
# config
# Base    42   5.6     6.0    2    7
# M+P     39   5.7     6.0    3    8
#
# --------------------------------------------------------------------------------
# ⚡ Efficiency: Minutes per Round
# --------------------------------------------------------------------------------
#         Mean (min/round)  Median (min/round)
# config
# Base                3.53                3.37
# M+P                 4.88                4.84
#
# --------------------------------------------------------------------------------
# 💰 Price Distribution by Student Role
# --------------------------------------------------------------------------------
#
# When Student is BUYER (wants lower price):
#         N Mean Price Median Price
# config
# Base    1   $595,000     $595,000
#
# When Student is SELLER (wants higher price):
#          N Mean Price Median Price
# config
# Base    34   $556,853     $549,500
# M+P     31   $549,597     $550,000
#
# ====================================================================================================

# %%
# ==================== DATA FILTERING ====================
# 1. Filter by major: Exclude SDS/sds first
df_all = df_all[
    ~df_all['major'].str.lower().isin(['sds']) | df_all['major'].isna()
].copy()

# 2. Define time windows
morning_start = pd.to_datetime('2025-12-10 14:36')
morning_end = pd.to_datetime('2025-12-10 15:48')
afternoon_start = pd.to_datetime('2025-12-10 19:21')
afternoon_end = pd.to_datetime('2025-12-10 20:01')

# 3. Create time period column
def get_time_period(created_at):
    dt = pd.to_datetime(created_at)
    if morning_start <= dt <= morning_end:
        return 'Morning'
    elif afternoon_start <= dt <= afternoon_end:
        return 'Afternoon'
    else:
        return 'Other'

df_all['time_period'] = df_all['created_at'].apply(get_time_period)

# 4. Filter to only include Morning and Afternoon sessions
df_all = df_all[df_all['time_period'].isin(['Morning', 'Afternoon'])].copy()

# ==================== ADD ADDITIONAL COLUMNS ====================
# Recreate derived columns after filtering
df_all['Config'] = df_all.apply(lambda r: get_config_label(r['use_memory'], r['use_plan']), axis=1)
df_all['Duration (min)'] = df_all.apply(lambda r: calculate_duration(r['created_at'], r['updated_at']), axis=1)
df_all['Outcome'] = df_all.apply(lambda r: 
    '✅ Deal' if r['deal_reached'] 
    else '❌ Failed' if r['deal_failed'] 
    else '⏸️ Incomplete', axis=1)
df_all['Role'] = df_all['student_role'].map({
    'side1': '🏢 Buyer (Fred)',
    'side2': '🏘️ Seller (Rosalind)'
})

# Add rounds column
def count_rounds(transcript_json):
    transcript = safe_json_load(transcript_json)
    return len(transcript) // 2 if transcript else 0

df_all['rounds'] = df_all['transcript'].apply(count_rounds)

# Add final price column (with fallback to AI JSON)
def extract_final_price(student_json_str, ai_json_str):
    # Try student JSON first
    student_json = safe_json_load(student_json_str)
    if student_json and 'final_price' in student_json:
        return student_json['final_price']
    
    # Fallback to AI JSON
    ai_json = safe_json_load(ai_json_str)
    if ai_json and 'final_price' in ai_json:
        return ai_json['final_price']
    
    return None

df_all['final_price'] = df_all.apply(
    lambda r: extract_final_price(r['student_deal_json'], r['ai_deal_json']) if r['deal_reached'] else None, 
    axis=1
)

# ==================== OVERALL STATISTICS ====================
print_header("📊 OVERALL STATISTICS (Both Sessions)")

print(f"Total Sessions: {len(df_all)}")
print(f"  Morning (14:36-15:48): {(df_all['time_period'] == 'Morning').sum()}")
print(f"  Afternoon (19:21-20:01): {(df_all['time_period'] == 'Afternoon').sum()}")

print(f"\nSuccessful Deals: {df_all['deal_reached'].sum()}")
print(f"Failed Negotiations: {df_all['deal_failed'].sum()}")
print(f"Incomplete: {(~df_all['deal_reached'] & ~df_all['deal_failed']).sum()}")

print(f"\n📊 Configuration Breakdown:")
print(df_all['Config'].value_counts().to_string())

print(f"\n🎭 Role Distribution:")
print(df_all['Role'].value_counts().to_string())

# ==================== DISPLAY ALL DATA ====================
print("\n" + "="*170)
print("ALL FILTERED DATA")
print("="*170)

display_df = df_all[[
    'session_id', 'time_period', 'Role', 'Config', 'Outcome',
    'major', 'gender', 'negotiation_experience',
    'rounds', 'final_price', 'Duration (min)', 'created_at'
]].copy()

display_df['session_id'] = display_df['session_id'].str[:8]
display_df['created_at'] = pd.to_datetime(display_df['created_at']).dt.strftime('%m-%d %H:%M')
display_df['Duration (min)'] = display_df['Duration (min)'].round(1)
display_df['final_price'] = display_df['final_price'].apply(lambda x: f"${x:,.0f}" if pd.notna(x) else "N/A")
display_df['rounds'] = display_df['rounds'].fillna(0).astype(int)

display_df.columns = ['Session', 'Period', 'Role', 'Config', 'Outcome', 'Major', 'Gender', 'Exp', 'Rounds', 'Final Price', 'Duration', 'Created']

pd.set_option('display.max_rows', None)
display(display_df)


# ==================== FUNCTION: ANALYZE ONE TIME PERIOD ====================
def analyze_time_period(df, period_name, period_label):
    """
    Analyze a specific time period's data
    
    Args:
        df: DataFrame filtered to one time period
        period_name: 'Morning' or 'Afternoon'
        period_label: Display label like '🌅 MORNING SESSION (14:36-15:48)'
    """
    print_header(period_label)
    
    if len(df) == 0:
        print(f"❌ No data for {period_name}")
        return
    
    # Basic statistics
    print(f"Total Sessions: {len(df)}")
    print(f"Successful Deals: {df['deal_reached'].sum()} ({df['deal_reached'].sum()/len(df)*100:.1f}%)")
    print(f"Failed Negotiations: {df['deal_failed'].sum()}")
    print(f"Incomplete: {(~df['deal_reached'] & ~df['deal_failed']).sum()}")
    
    print(f"\n📊 Configuration Breakdown:")
    print(df['Config'].value_counts().to_string())
    
    print(f"\n🎭 Role Distribution:")
    print(df['Role'].value_counts().to_string())
    
    # Demographics
    print_subheader("👥 Demographics")
    
    if df['major'].notna().sum() > 0:
        print("\n📚 Major:")
        major_counts = df['major'].value_counts()
        for major, count in major_counts.items():
            print(f"  {major}: {count}")
    
    if df['gender'].notna().sum() > 0:
        print("\n⚧ Gender:")
        gender_counts = df['gender'].value_counts()
        for gender, count in gender_counts.items():
            print(f"  {gender}: {count}")
    
    if df['negotiation_experience'].notna().sum() > 0:
        print("\n💼 Experience:")
        exp_counts = df['negotiation_experience'].value_counts()
        for exp, count in exp_counts.items():
            print(f"  {exp}: {count}")
    
    # Deal analysis
    df_deals = df[df['deal_reached'] == True].copy()
    
    if len(df_deals) > 0:
        print_subheader("💰 Deal Price Analysis")
        
        # Extract numeric prices for statistics
        df_deals['price_numeric'] = df_deals['final_price']
        valid_prices = df_deals['price_numeric'].dropna()
        
        if len(valid_prices) > 0:
            print(f"\n📊 Overall Price Statistics:")
            print(f"  Average: ${valid_prices.mean():,.0f}")
            print(f"  Median:  ${valid_prices.median():,.0f}")
            print(f"  Min:     ${valid_prices.min():,.0f}")
            print(f"  Max:     ${valid_prices.max():,.0f}")
            print(f"  Std Dev: ${valid_prices.std():,.0f}")
            
            # By configuration
            print(f"\n🔧 By Configuration:")
            for config in ['Base', 'M', 'P', 'M+P']:
                config_deals = df_deals[df_deals['Config'] == config]
                config_prices = config_deals['price_numeric'].dropna()
                if len(config_prices) > 0:
                    print(f"\n  {config}:")
                    print(f"    Count: {len(config_prices)}")
                    print(f"    Average: ${config_prices.mean():,.0f}")
                    print(f"    Median:  ${config_prices.median():,.0f}")
                    print(f"    Range: ${config_prices.min():,.0f} - ${config_prices.max():,.0f}")
            
            # By role
            print(f"\n🎭 By Student Role:")
            
            buyer_deals = df_deals[df_deals['student_role'] == 'side1']
            buyer_prices = buyer_deals['price_numeric'].dropna()
            if len(buyer_prices) > 0:
                print(f"\n  When Student is BUYER (Fred):")
                print(f"    Goal: Minimize price (lower is better)")
                print(f"    Count: {len(buyer_prices)}")
                print(f"    Average: ${buyer_prices.mean():,.0f}")
                print(f"    Range: ${buyer_prices.min():,.0f} - ${buyer_prices.max():,.0f}")
            
            seller_deals = df_deals[df_deals['student_role'] == 'side2']
            seller_prices = seller_deals['price_numeric'].dropna()
            if len(seller_prices) > 0:
                print(f"\n  When Student is SELLER (Rosalind):")
                print(f"    Goal: Maximize price (higher is better)")
                print(f"    Count: {len(seller_prices)}")
                print(f"    Average: ${seller_prices.mean():,.0f}")
                print(f"    Range: ${seller_prices.min():,.0f} - ${seller_prices.max():,.0f}")
        
        # Duration and rounds
        print_subheader("⏱️ Duration & Rounds Analysis")
        
        valid_durations = df_deals['Duration (min)'].dropna()
        if len(valid_durations) > 0:
            print(f"\nDuration Statistics:")
            print(f"  Average: {valid_durations.mean():.1f} minutes")
            print(f"  Median:  {valid_durations.median():.1f} minutes")
            print(f"  Range: {valid_durations.min():.1f} - {valid_durations.max():.1f} minutes")
        
        valid_rounds = df_deals['rounds']
        if len(valid_rounds) > 0:
            print(f"\nRounds Statistics:")
            print(f"  Average: {valid_rounds.mean():.1f} rounds")
            print(f"  Median:  {valid_rounds.median():.0f} rounds")
            print(f"  Range: {valid_rounds.min():.0f} - {valid_rounds.max():.0f} rounds")
    
    # Detailed table
    print_subheader("📋 Detailed Session List")
    
    detail_df = df[[
        'session_id', 'Role', 'Config', 'Outcome', 'major',
        'rounds', 'final_price', 'Duration (min)', 'created_at'
    ]].copy()
    
    detail_df['session_id'] = detail_df['session_id'].str[:8]
    detail_df['created_at'] = pd.to_datetime(detail_df['created_at']).dt.strftime('%H:%M')
    detail_df['Duration (min)'] = detail_df['Duration (min)'].round(1)
    detail_df['final_price'] = detail_df['final_price'].apply(lambda x: f"${x:,.0f}" if pd.notna(x) else "N/A")
    
    detail_df.columns = ['Session', 'Role', 'Config', 'Outcome', 'Major', 'Rounds', 'Price', 'Duration', 'Time']
    
    display(detail_df)


# ==================== MORNING SESSION ANALYSIS ====================
df_morning = df_all[df_all['time_period'] == 'Morning'].copy()
analyze_time_period(df_morning, 'Morning', '🌅 MORNING SESSION (14:36-15:48)')

# ==================== AFTERNOON SESSION ANALYSIS ====================
df_afternoon = df_all[df_all['time_period'] == 'Afternoon'].copy()
analyze_time_period(df_afternoon, 'Afternoon', '🌆 AFTERNOON SESSION (19:21-20:01)')

# ==================== COMPARISON BETWEEN SESSIONS ====================
print_header("⚖️ MORNING vs AFTERNOON COMPARISON")

comparison_data = []

for period_name, df_period in [('Morning', df_morning), ('Afternoon', df_afternoon)]:
    deals = df_period[df_period['deal_reached'] == True]
    prices = deals['final_price'].dropna()
    
    comparison_data.append({
        'Period': period_name,
        'Total Sessions': len(df_period),
        'Deals': len(deals),
        'Success Rate': f"{len(deals)/len(df_period)*100:.1f}%" if len(df_period) > 0 else "N/A",
        'Avg Price': f"${prices.mean():,.0f}" if len(prices) > 0 else "N/A",
        'Avg Rounds': f"{deals['rounds'].mean():.1f}" if len(deals) > 0 else "N/A",
        'Avg Duration': f"{deals['Duration (min)'].mean():.1f} min" if len(deals) > 0 else "N/A"
    })

comparison_df = pd.DataFrame(comparison_data)
display(comparison_df)
# Out:
# ====================================================================================================
#                                 📊 OVERALL STATISTICS (Both Sessions)
# ====================================================================================================
#
# Total Sessions: 109
#   Morning (14:36-15:48): 67
#   Afternoon (19:21-20:01): 42
#
# Successful Deals: 77
# Failed Negotiations: 2
# Incomplete: -188
#
# 📊 Configuration Breakdown:
# Config
# Base    58
# M+P     51
#
# 🎭 Role Distribution:
# Role
# 🏘️ Seller (Rosalind)    108
# 🏢 Buyer (Fred)            1
#
# ==========================================================================================================================================================================
# ALL FILTERED DATA
# ==========================================================================================================================================================================
#       Session     Period                  Role Config        Outcome  \
# 1    b37f26ac  Afternoon  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 2    33f1a7e7  Afternoon  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 3    1da9f9c4  Afternoon  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 4    0ad06bea  Afternoon  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 5    d0f674cd  Afternoon  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 6    799f52db  Afternoon  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 7    95e44a5d  Afternoon  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 8    16eceb2c  Afternoon  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 9    798d365f  Afternoon        🏢 Buyer (Fred)   Base         ✅ Deal
# 10   31db345d  Afternoon  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 11   88bdd965  Afternoon  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 12   50f35769  Afternoon  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 13   1c047b8c  Afternoon  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 14   1accb1db  Afternoon  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 15   bb74becf  Afternoon  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 16   91bf642e  Afternoon  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 17   7443cda3  Afternoon  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 18   938b042a  Afternoon  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 19   562a5935  Afternoon  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 20   0b0c3e36  Afternoon  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 21   efc8ced7  Afternoon  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 22   e4db51d8  Afternoon  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 23   2707b436  Afternoon  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 24   98028e11  Afternoon  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 25   9864a8ac  Afternoon  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 26   19189653  Afternoon  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 27   65568ba8  Afternoon  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 28   09116786  Afternoon  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 29   350ef762  Afternoon  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 30   f8b904d4  Afternoon  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 31   2b985adf  Afternoon  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 32   538cd73f  Afternoon  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 33   516685e6  Afternoon  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 34   ee8d9c66  Afternoon  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 35   d08ef3f9  Afternoon  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 36   e00fe024  Afternoon  🏘️ Seller (Rosalind)   Base       ❌ Failed
# 37   4eb7d6b7  Afternoon  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 38   0edb4787  Afternoon  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 39   b19200a0  Afternoon  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 40   4240e9c5  Afternoon  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 41   6c890dba  Afternoon  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 42   20b90946  Afternoon  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 46   f8108b66    Morning  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 50   44902306    Morning  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 52   519ed03e    Morning  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 53   d61b1421    Morning  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 54   8f327691    Morning  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 55   49f9367b    Morning  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 56   def6ce77    Morning  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 57   a6587ccb    Morning  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 58   ff4187e1    Morning  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 59   2c58997c    Morning  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 60   1c64c52d    Morning  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 61   22e1c990    Morning  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 62   320f365c    Morning  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 63   583603ec    Morning  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 64   f727eff6    Morning  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 65   24a24ce4    Morning  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 66   a027bad3    Morning  🏘️ Seller (Rosalind)   Base       ❌ Failed
# 67   da8e805c    Morning  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 68   bb4f01c8    Morning  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 69   6ba03567    Morning  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 70   fefa4d90    Morning  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 71   3ce4dbec    Morning  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 72   53c67d59    Morning  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 73   fae036e8    Morning  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 74   e014a8cd    Morning  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 75   bf242471    Morning  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 76   daa71a3a    Morning  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 77   187ee6e1    Morning  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 78   7ab01b6d    Morning  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 79   a5a7bbed    Morning  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 80   f0c044d9    Morning  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 81   cba8d9c9    Morning  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 82   dd354523    Morning  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 83   5c9d6f09    Morning  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 84   118af3de    Morning  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 85   486f9419    Morning  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 86   13697589    Morning  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 87   81eafc5a    Morning  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 88   fe68b67b    Morning  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 89   a5291dbb    Morning  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 90   baf91c79    Morning  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 91   f167c9c9    Morning  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 92   ed40d7bb    Morning  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 93   9a00be6e    Morning  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 94   da734cf6    Morning  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 95   023fa610    Morning  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 96   2e473faf    Morning  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 97   35cd2da6    Morning  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 98   73297254    Morning  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 99   34bd3d91    Morning  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 100  fef6c2b3    Morning  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 101  e15e86b4    Morning  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 102  cdb4b68d    Morning  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 103  33365183    Morning  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 104  fabc68b2    Morning  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 105  526567fb    Morning  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 106  6a1f1023    Morning  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 107  746b9508    Morning  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 108  2527e1ea    Morning  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 109  4093ffc5    Morning  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 110  073b248f    Morning  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 111  82de1f8e    Morning  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 112  20260374    Morning  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 113  8fe436e8    Morning  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 114  c29a5a57    Morning  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 115  7fe2649b    Morning  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 116  7f6097c2    Morning  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
#
#                                        Major      Gender              Exp  \
# 1                                    Theater      Female       Occasional
# 2                                    Theater      Female       Occasional
# 3                                        GBS
# 4                                        MBA
# 5                                        GBS
# 6                               MBA Exchange              A few instances
# 7                                        MBA        Male  A few instances
# 8                                        GBS      Female  A few instances
# 9                                        MBA        Male  A few instances
# 10                                      Tech        Male       Occasional
# 11
# 12                                  Business        Male  A few instances
# 13
# 14               Global Business and Society        Male       Occasional
# 15                                  Business        Male             None
# 16                                       MBA      Female       Occasional
# 17                                       GBS      Female
# 18                                    2Y MBA      Female  A few instances
# 19                                       GBS      Female       Occasional
# 20                                       GBS      Female  A few instances
# 21                                       MBA      Female       Occasional
# 22                                       MBA      Female       Occasional
# 23                                   Theater      Female       Occasional
# 24
# 25                                       GBS      Female  A few instances
# 26                                       MBA        Male  A few instances
# 27                                       MBA
# 28                                Management        Male  A few instances
# 29
# 30                      School of Management        Male  A few instances
# 31                                       GBS      Female  A few instances
# 32                                       MBA
# 33                                       GBS        Male  A few instances
# 34                     Healthcare Management      Female  A few instances
# 35                                                  Male  A few instances
# 36                                       MBA        Male  A few instances
# 37                                       MBA        Male  A few instances
# 38                                       GBS      Female  A few instances
# 39                                       MBA        Male  A few instances
# 40                                       MBA        Male  A few instances
# 41   Master of Business Administration (MBA)        Male             None
# 42                                Management        Male       Occasional
# 46                        Health Informatics      Female             None
# 50                                  Business
# 52                                Management        Male  A few instances
# 53
# 54
# 55                                  Business
# 56                             public health      Female             None
# 57                                       MBA        Male         Frequent
# 58                                       GBS      Female  A few instances
# 59                 Global Business & Society        Male       Occasional
# 60                 Global Business & Society        Male  A few instances
# 61                                       GBS      Female  A few instances
# 62                                       GBS      Female             None
# 63                                       GBS        Male             None
# 64                    Mechanical Engineering        Male       Occasional
# 65                                       GBS        Male  A few instances
# 66                                       GBS        Male     Professional
# 67                                Management        Male             None
# 68                                       MBA      Female       Occasional
# 69                 Global Business & Society        Male  A few instances
# 70                                Management      Female  A few instances
# 71
# 72                                  Business        Male       Occasional
# 73                        Management Science      Female       Occasional
# 74                     Technology Management        Male       Occasional
# 75                                       MBA      Female  A few instances
# 76         Master of Business Administration        Male             None
# 77                                       MBA        Male         Frequent
# 78                                       MBA        Male  A few instances
# 79                                       GBS      Female  A few instances
# 80                                       GBS      Female  A few instances
# 81                        Management Science        Male             None
# 82                                       MBA        Male  A few instances
# 83                            Yale SOM - GBS      Female       Occasional
# 84                                       MBA        Male  A few instances
# 85                                       MBA        Male  A few instances
# 86                             Arrchitecture        Male  A few instances
# 87                                Management      Female  A few instances
# 88                  Master in Management GBS      Female
# 89                                       GBS      Female         Frequent
# 90                               Mathematics        Male  A few instances
# 91                 Global Business & Society        Male       Occasional
# 92               Global Business and Society  Non-binary       Occasional
# 93
# 94                          Asset Management        Male  A few instances
# 95                             public health      Female             None
# 96            Masters of Advanced Management        Male       Occasional
# 97                                Management        Male             None
# 98                    Mechanical Engineering        Male       Occasional
# 99         Master of Business Administration      Female  A few instances
# 100                                      GBS        Male             None
# 101                                      GBS      Female  A few instances
# 102                           Global Affairs        Male  A few instances
# 103                                      MBA        Male       Occasional
# 104                               Management        Male  A few instances
# 105
# 106                               Management        Male       Occasional
# 107
# 108                                      MBA        Male  A few instances
# 109              Global business and society        Male  A few instances
# 110                                      Law        Male             None
# 111                               Management        Male       Occasional
# 112              Global Business and Society              A few instances
# 113                               Management        Male       Occasional
# 114                                      MBA
# 115                                      MBA        Male         Frequent
# 116                       Management Science        Male       Occasional
#
#      Rounds Final Price  Duration      Created
# 1         4    $575,000       7.1  12-10 19:52
# 2         0         N/A       0.8  12-10 19:51
# 3         4    $515,000      29.1  12-10 19:49
# 4         6    $465,000      11.4  12-10 19:44
# 5         0         N/A       0.0  12-10 19:44
# 6         6    $549,000      27.0  12-10 19:39
# 7         6    $570,000       8.7  12-10 19:38
# 8         8    $585,000      42.6  12-10 19:37
# 9         5    $595,000      12.4  12-10 19:36
# 10        5    $565,000      22.7  12-10 19:35
# 11        5    $565,000      20.5  12-10 19:35
# 12        5    $630,000      20.2  12-10 19:35
# 13        6    $550,000      25.3  12-10 19:35
# 14        6    $630,000      44.0  12-10 19:35
# 15        6    $600,000      18.4  12-10 19:35
# 16        6    $525,000      20.2  12-10 19:34
# 17        5    $540,000      18.1  12-10 19:34
# 18        5         N/A      19.5  12-10 19:34
# 19        6    $590,000      24.7  12-10 19:33
# 20        0         N/A       0.9  12-10 19:33
# 21        6    $560,000      24.0  12-10 19:33
# 22        0         N/A       1.2  12-10 19:32
# 23        3         N/A      13.5  12-10 19:32
# 24        6    $552,000      25.4  12-10 19:31
# 25        5    $512,500      20.3  12-10 19:31
# 26        5    $529,000      31.8  12-10 19:31
# 27        5    $560,000      26.6  12-10 19:30
# 28        6    $650,000      29.2  12-10 19:29
# 29        0         N/A       0.6  12-10 19:29
# 30        7    $585,000      41.2  12-10 19:28
# 31        6    $555,000      49.8  12-10 19:28
# 32        0         N/A       0.6  12-10 19:28
# 33        5    $505,000      38.1  12-10 19:28
# 34        5         N/A      23.7  12-10 19:27
# 35        5    $550,000      34.2  12-10 19:26
# 36        6         N/A      40.9  12-10 19:25
# 37        6    $550,000      11.5  12-10 19:23
# 38        5    $508,000      29.3  12-10 19:23
# 39        1         N/A       9.9  12-10 19:23
# 40        6         N/A      12.7  12-10 19:23
# 41        4         N/A      16.6  12-10 19:22
# 42        0         N/A       0.0  12-10 19:21
# 46        5    $490,000      16.4  12-10 15:37
# 50        0         N/A       0.5  12-10 15:28
# 52        0         N/A       0.0  12-10 15:25
# 53        5         N/A      11.9  12-10 15:10
# 54        6    $545,000      18.6  12-10 15:09
# 55        0         N/A       0.5  12-10 15:09
# 56        6    $530,000      11.0  12-10 15:07
# 57        0         N/A       0.6  12-10 15:01
# 58        6    $570,000      20.5  12-10 15:00
# 59        6    $535,000       9.2  12-10 14:59
# 60        6    $600,000      14.9  12-10 14:57
# 61        2         N/A       8.5  12-10 14:52
# 62        6    $600,000      17.3  12-10 14:50
# 63        6    $537,500      17.6  12-10 14:50
# 64        0         N/A       0.7  12-10 14:49
# 65        4    $555,000      15.0  12-10 14:49
# 66        6         N/A      20.4  12-10 14:48
# 67        6    $540,000      29.4  12-10 14:48
# 68        6    $535,000      11.5  12-10 14:48
# 69        1         N/A       4.9  12-10 14:48
# 70        5    $550,000      28.4  12-10 14:48
# 71        5         N/A      21.9  12-10 14:47
# 72        6    $555,000      30.1  12-10 14:47
# 73        6    $550,000      20.8  12-10 14:47
# 74        6    $550,000      32.3  12-10 14:47
# 75        5    $540,000      10.9  12-10 14:47
# 76        6    $540,000      26.5  12-10 14:47
# 77        6    $560,000      18.6  12-10 14:47
# 78        6    $550,000      19.1  12-10 14:47
# 79        6    $555,000      25.2  12-10 14:47
# 80        6    $575,000      11.3  12-10 14:46
# 81        6    $590,000      21.2  12-10 14:46
# 82        6         N/A       8.0  12-10 14:46
# 83        5    $535,000      24.1  12-10 14:46
# 84        5    $545,000      13.8  12-10 14:46
# 85        4    $535,000      15.6  12-10 14:46
# 86        6    $480,000      22.9  12-10 14:46
# 87        6    $500,000      23.0  12-10 14:45
# 88        6    $595,000      18.6  12-10 14:45
# 89        6    $548,000      40.5  12-10 14:45
# 90        6    $550,000      29.5  12-10 14:45
# 91        4         N/A      11.8  12-10 14:44
# 92        6    $517,500      31.0  12-10 14:44
# 93        5    $545,000      18.4  12-10 14:43
# 94        7    $550,000      33.9  12-10 14:43
# 95        4         N/A      18.3  12-10 14:43
# 96        6    $560,000      22.3  12-10 14:43
# 97        6    $549,000      28.1  12-10 14:42
# 98        3    $505,000       6.7  12-10 14:42
# 99        6    $578,500      31.4  12-10 14:41
# 100       6    $520,000      32.3  12-10 14:41
# 101       5    $540,000      34.2  12-10 14:40
# 102       7    $650,000      27.1  12-10 14:40
# 103       6    $538,500      41.2  12-10 14:39
# 104       6    $535,000      42.7  12-10 14:39
# 105       5    $560,000      24.5  12-10 14:39
# 106       6    $510,000      28.9  12-10 14:39
# 107       6    $570,000      34.9  12-10 14:39
# 108       6    $575,000      18.6  12-10 14:39
# 109       6    $515,000      21.2  12-10 14:38
# 110       6    $525,000      33.7  12-10 14:38
# 111       0         N/A       0.7  12-10 14:38
# 112       6    $562,500      26.2  12-10 14:38
# 113       0         N/A       1.0  12-10 14:37
# 114       5         N/A      26.1  12-10 14:37
# 115       6         N/A      20.1  12-10 14:36
# 116       6         N/A      28.3  12-10 14:36
# ====================================================================================================
#                                   🌅 MORNING SESSION (14:36-15:48)
# ====================================================================================================
#
# Total Sessions: 67
# Successful Deals: 49 (73.1%)
# Failed Negotiations: 1
# Incomplete: -117
#
# 📊 Configuration Breakdown:
# Config
# Base    36
# M+P     31
#
# 🎭 Role Distribution:
# Role
# 🏘️ Seller (Rosalind)    67
#
# --------------------------------------------------------------------------------
# 👥 Demographics
# --------------------------------------------------------------------------------
#
# 📚 Major:
#   MBA: 12
#   GBS: 11
#   Management: 9
#   : 6
#   Global Business & Society: 4
#   Business: 3
#   Management Science: 3
#   public health: 2
#   Master of Business Administration: 2
#   Mechanical Engineering: 2
#   Global Business and Society: 2
#   Health Informatics: 1
#   Yale SOM - GBS: 1
#   Technology Management: 1
#   Arrchitecture: 1
#   Master in Management GBS: 1
#   Mathematics: 1
#   Asset Management: 1
#   Masters of Advanced Management: 1
#   Global Affairs: 1
#   Global business and society: 1
#   Law: 1
#
# ⚧ Gender:
#   Male: 38
#   Female: 18
#   : 10
#   Non-binary: 1
#
# 💼 Experience:
#   A few instances: 25
#   Occasional: 16
#   None: 11
#   : 10
#   Frequent: 4
#   Professional: 1
#
# --------------------------------------------------------------------------------
# 💰 Deal Price Analysis
# --------------------------------------------------------------------------------
#
# 📊 Overall Price Statistics:
#   Average: $547,888
#   Median:  $548,000
#   Min:     $480,000
#   Max:     $650,000
#   Std Dev: $29,765
#
# 🔧 By Configuration:
#
#   Base:
#     Count: 24
#     Average: $550,479
#     Median:  $545,000
#     Range: $480,000 - $650,000
#
#   M+P:
#     Count: 25
#     Average: $545,400
#     Median:  $550,000
#     Range: $500,000 - $595,000
#
# 🎭 By Student Role:
#
#   When Student is SELLER (Rosalind):
#     Goal: Maximize price (higher is better)
#     Count: 49
#     Average: $547,888
#     Range: $480,000 - $650,000
#
# --------------------------------------------------------------------------------
# ⏱️ Duration & Rounds Analysis
# --------------------------------------------------------------------------------
#
# Duration Statistics:
#   Average: 23.5 minutes
#   Median:  22.9 minutes
#   Range: 6.7 - 42.7 minutes
#
# Rounds Statistics:
#   Average: 5.7 rounds
#   Median:  6 rounds
#   Range: 3 - 7 rounds
#
# --------------------------------------------------------------------------------
# 📋 Detailed Session List
# --------------------------------------------------------------------------------
#       Session                  Role Config        Outcome  \
# 46   f8108b66  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 50   44902306  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 52   519ed03e  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 53   d61b1421  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 54   8f327691  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 55   49f9367b  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 56   def6ce77  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 57   a6587ccb  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 58   ff4187e1  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 59   2c58997c  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 60   1c64c52d  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 61   22e1c990  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 62   320f365c  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 63   583603ec  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 64   f727eff6  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 65   24a24ce4  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 66   a027bad3  🏘️ Seller (Rosalind)   Base       ❌ Failed
# 67   da8e805c  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 68   bb4f01c8  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 69   6ba03567  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 70   fefa4d90  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 71   3ce4dbec  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 72   53c67d59  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 73   fae036e8  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 74   e014a8cd  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 75   bf242471  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 76   daa71a3a  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 77   187ee6e1  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 78   7ab01b6d  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 79   a5a7bbed  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 80   f0c044d9  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 81   cba8d9c9  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 82   dd354523  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 83   5c9d6f09  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 84   118af3de  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 85   486f9419  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 86   13697589  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 87   81eafc5a  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 88   fe68b67b  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 89   a5291dbb  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 90   baf91c79  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 91   f167c9c9  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 92   ed40d7bb  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 93   9a00be6e  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 94   da734cf6  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 95   023fa610  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 96   2e473faf  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 97   35cd2da6  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 98   73297254  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 99   34bd3d91  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 100  fef6c2b3  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 101  e15e86b4  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 102  cdb4b68d  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 103  33365183  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 104  fabc68b2  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 105  526567fb  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 106  6a1f1023  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 107  746b9508  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 108  2527e1ea  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 109  4093ffc5  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 110  073b248f  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 111  82de1f8e  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 112  20260374  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 113  8fe436e8  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 114  c29a5a57  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 115  7fe2649b  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 116  7f6097c2  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
#
#                                  Major  Rounds     Price  Duration   Time
# 46                  Health Informatics       5  $490,000      16.4  15:37
# 50                            Business       0       N/A       0.5  15:28
# 52                          Management       0       N/A       0.0  15:25
# 53                                           5       N/A      11.9  15:10
# 54                                           6  $545,000      18.6  15:09
# 55                            Business       0       N/A       0.5  15:09
# 56                       public health       6  $530,000      11.0  15:07
# 57                                 MBA       0       N/A       0.6  15:01
# 58                                 GBS       6  $570,000      20.5  15:00
# 59           Global Business & Society       6  $535,000       9.2  14:59
# 60           Global Business & Society       6  $600,000      14.9  14:57
# 61                                 GBS       2       N/A       8.5  14:52
# 62                                 GBS       6  $600,000      17.3  14:50
# 63                                 GBS       6  $537,500      17.6  14:50
# 64              Mechanical Engineering       0       N/A       0.7  14:49
# 65                                 GBS       4  $555,000      15.0  14:49
# 66                                 GBS       6       N/A      20.4  14:48
# 67                          Management       6  $540,000      29.4  14:48
# 68                                 MBA       6  $535,000      11.5  14:48
# 69           Global Business & Society       1       N/A       4.9  14:48
# 70                          Management       5  $550,000      28.4  14:48
# 71                                           5       N/A      21.9  14:47
# 72                            Business       6  $555,000      30.1  14:47
# 73                  Management Science       6  $550,000      20.8  14:47
# 74               Technology Management       6  $550,000      32.3  14:47
# 75                                 MBA       5  $540,000      10.9  14:47
# 76   Master of Business Administration       6  $540,000      26.5  14:47
# 77                                 MBA       6  $560,000      18.6  14:47
# 78                                 MBA       6  $550,000      19.1  14:47
# 79                                 GBS       6  $555,000      25.2  14:47
# 80                                 GBS       6  $575,000      11.3  14:46
# 81                  Management Science       6  $590,000      21.2  14:46
# 82                                 MBA       6       N/A       8.0  14:46
# 83                      Yale SOM - GBS       5  $535,000      24.1  14:46
# 84                                 MBA       5  $545,000      13.8  14:46
# 85                                 MBA       4  $535,000      15.6  14:46
# 86                       Arrchitecture       6  $480,000      22.9  14:46
# 87                          Management       6  $500,000      23.0  14:45
# 88            Master in Management GBS       6  $595,000      18.6  14:45
# 89                                 GBS       6  $548,000      40.5  14:45
# 90                         Mathematics       6  $550,000      29.5  14:45
# 91           Global Business & Society       4       N/A      11.8  14:44
# 92         Global Business and Society       6  $517,500      31.0  14:44
# 93                                           5  $545,000      18.4  14:43
# 94                    Asset Management       7  $550,000      33.9  14:43
# 95                       public health       4       N/A      18.3  14:43
# 96      Masters of Advanced Management       6  $560,000      22.3  14:43
# 97                          Management       6  $549,000      28.1  14:42
# 98              Mechanical Engineering       3  $505,000       6.7  14:42
# 99   Master of Business Administration       6  $578,500      31.4  14:41
# 100                                GBS       6  $520,000      32.3  14:41
# 101                                GBS       5  $540,000      34.2  14:40
# 102                     Global Affairs       7  $650,000      27.1  14:40
# 103                                MBA       6  $538,500      41.2  14:39
# 104                         Management       6  $535,000      42.7  14:39
# 105                                          5  $560,000      24.5  14:39
# 106                         Management       6  $510,000      28.9  14:39
# 107                                          6  $570,000      34.9  14:39
# 108                                MBA       6  $575,000      18.6  14:39
# 109        Global business and society       6  $515,000      21.2  14:38
# 110                                Law       6  $525,000      33.7  14:38
# 111                         Management       0       N/A       0.7  14:38
# 112        Global Business and Society       6  $562,500      26.2  14:38
# 113                         Management       0       N/A       1.0  14:37
# 114                                MBA       5       N/A      26.1  14:37
# 115                                MBA       6       N/A      20.1  14:36
# 116                 Management Science       6       N/A      28.3  14:36
# ====================================================================================================
#                                  🌆 AFTERNOON SESSION (19:21-20:01)
# ====================================================================================================
#
# Total Sessions: 42
# Successful Deals: 28 (66.7%)
# Failed Negotiations: 1
# Incomplete: -71
#
# 📊 Configuration Breakdown:
# Config
# Base    22
# M+P     20
#
# 🎭 Role Distribution:
# Role
# 🏘️ Seller (Rosalind)    41
# 🏢 Buyer (Fred)           1
#
# --------------------------------------------------------------------------------
# 👥 Demographics
# --------------------------------------------------------------------------------
#
# 📚 Major:
#   MBA: 13
#   GBS: 10
#   : 5
#   Theater: 3
#   Business: 2
#   Management: 2
#   MBA Exchange: 1
#   Tech: 1
#   Global Business and Society: 1
#   2Y MBA: 1
#   School of Management: 1
#   Healthcare Management: 1
#   Master of Business Administration (MBA): 1
#
# ⚧ Gender:
#   Male: 17
#   Female: 15
#   : 10
#
# 💼 Experience:
#   A few instances: 20
#   Occasional: 10
#   : 10
#   None: 2
#
# --------------------------------------------------------------------------------
# 💰 Deal Price Analysis
# --------------------------------------------------------------------------------
#
# 📊 Overall Price Statistics:
#   Average: $559,482
#   Median:  $557,500
#   Min:     $465,000
#   Max:     $650,000
#   Std Dev: $40,994
#
# 🔧 By Configuration:
#
#   Base:
#     Count: 14
#     Average: $569,036
#     Median:  $567,500
#     Range: $465,000 - $650,000
#
#   M+P:
#     Count: 14
#     Average: $549,929
#     Median:  $550,000
#     Range: $505,000 - $630,000
#
# 🎭 By Student Role:
#
#   When Student is BUYER (Fred):
#     Goal: Minimize price (lower is better)
#     Count: 1
#     Average: $595,000
#     Range: $595,000 - $595,000
#
#   When Student is SELLER (Rosalind):
#     Goal: Maximize price (higher is better)
#     Count: 27
#     Average: $558,167
#     Range: $465,000 - $650,000
#
# --------------------------------------------------------------------------------
# ⏱️ Duration & Rounds Analysis
# --------------------------------------------------------------------------------
#
# Duration Statistics:
#   Average: 25.5 minutes
#   Median:  25.0 minutes
#   Range: 7.1 - 49.8 minutes
#
# Rounds Statistics:
#   Average: 5.6 rounds
#   Median:  6 rounds
#   Range: 4 - 8 rounds
#
# --------------------------------------------------------------------------------
# 📋 Detailed Session List
# --------------------------------------------------------------------------------
#      Session                  Role Config        Outcome  \
# 1   b37f26ac  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 2   33f1a7e7  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 3   1da9f9c4  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 4   0ad06bea  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 5   d0f674cd  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 6   799f52db  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 7   95e44a5d  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 8   16eceb2c  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 9   798d365f        🏢 Buyer (Fred)   Base         ✅ Deal
# 10  31db345d  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 11  88bdd965  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 12  50f35769  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 13  1c047b8c  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 14  1accb1db  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 15  bb74becf  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 16  91bf642e  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 17  7443cda3  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 18  938b042a  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 19  562a5935  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 20  0b0c3e36  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 21  efc8ced7  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 22  e4db51d8  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 23  2707b436  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 24  98028e11  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 25  9864a8ac  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 26  19189653  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 27  65568ba8  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 28  09116786  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 29  350ef762  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 30  f8b904d4  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 31  2b985adf  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 32  538cd73f  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 33  516685e6  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 34  ee8d9c66  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 35  d08ef3f9  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 36  e00fe024  🏘️ Seller (Rosalind)   Base       ❌ Failed
# 37  4eb7d6b7  🏘️ Seller (Rosalind)   Base         ✅ Deal
# 38  0edb4787  🏘️ Seller (Rosalind)    M+P         ✅ Deal
# 39  b19200a0  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 40  4240e9c5  🏘️ Seller (Rosalind)   Base  ⏸️ Incomplete
# 41  6c890dba  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
# 42  20b90946  🏘️ Seller (Rosalind)    M+P  ⏸️ Incomplete
#
#                                       Major  Rounds     Price  Duration   Time
# 1                                   Theater       4  $575,000       7.1  19:52
# 2                                   Theater       0       N/A       0.8  19:51
# 3                                       GBS       4  $515,000      29.1  19:49
# 4                                       MBA       6  $465,000      11.4  19:44
# 5                                       GBS       0       N/A       0.0  19:44
# 6                              MBA Exchange       6  $549,000      27.0  19:39
# 7                                       MBA       6  $570,000       8.7  19:38
# 8                                       GBS       8  $585,000      42.6  19:37
# 9                                       MBA       5  $595,000      12.4  19:36
# 10                                     Tech       5  $565,000      22.7  19:35
# 11                                                5  $565,000      20.5  19:35
# 12                                 Business       5  $630,000      20.2  19:35
# 13                                                6  $550,000      25.3  19:35
# 14              Global Business and Society       6  $630,000      44.0  19:35
# 15                                 Business       6  $600,000      18.4  19:35
# 16                                      MBA       6  $525,000      20.2  19:34
# 17                                      GBS       5  $540,000      18.1  19:34
# 18                                   2Y MBA       5       N/A      19.5  19:34
# 19                                      GBS       6  $590,000      24.7  19:33
# 20                                      GBS       0       N/A       0.9  19:33
# 21                                      MBA       6  $560,000      24.0  19:33
# 22                                      MBA       0       N/A       1.2  19:32
# 23                                  Theater       3       N/A      13.5  19:32
# 24                                                6  $552,000      25.4  19:31
# 25                                      GBS       5  $512,500      20.3  19:31
# 26                                      MBA       5  $529,000      31.8  19:31
# 27                                      MBA       5  $560,000      26.6  19:30
# 28                               Management       6  $650,000      29.2  19:29
# 29                                                0       N/A       0.6  19:29
# 30                     School of Management       7  $585,000      41.2  19:28
# 31                                      GBS       6  $555,000      49.8  19:28
# 32                                      MBA       0       N/A       0.6  19:28
# 33                                      GBS       5  $505,000      38.1  19:28
# 34                    Healthcare Management       5       N/A      23.7  19:27
# 35                                                5  $550,000      34.2  19:26
# 36                                      MBA       6       N/A      40.9  19:25
# 37                                      MBA       6  $550,000      11.5  19:23
# 38                                      GBS       5  $508,000      29.3  19:23
# 39                                      MBA       1       N/A       9.9  19:23
# 40                                      MBA       6       N/A      12.7  19:23
# 41  Master of Business Administration (MBA)       4       N/A      16.6  19:22
# 42                               Management       0       N/A       0.0  19:21
# ====================================================================================================
#                                  ⚖️ MORNING vs AFTERNOON COMPARISON
# ====================================================================================================
#       Period  Total Sessions  Deals Success Rate Avg Price Avg Rounds  \
# 0    Morning              67     49        73.1%  $547,888        5.7
# 1  Afternoon              42     28        66.7%  $559,482        5.6
#
#   Avg Duration
# 0     23.5 min
# 1     25.5 min

# %%
# ============================================================================
# Section 1: 📋 Seller-Only Analysis (Student as Seller)
# ============================================================================

import sqlite3
import pandas as pd
import json
import numpy as np
from datetime import datetime
from IPython.display import display, HTML, Markdown
import warnings
warnings.filterwarnings('ignore')

# ==================== CONFIGURATION ====================
DB_PATH = "negotiations_mainst.db"  # ⚠️ CHANGE THIS TO YOUR DATABASE PATH
SCENARIO_FILTER = "Main_Street"  # Focus on Main Street scenario

conn = sqlite3.connect(DB_PATH)
print(f"✅ Connected to: {DB_PATH}")
print(f"🎯 Analyzing scenario: {SCENARIO_FILTER}")
print(f"🎯 Focus: Student as SELLER only\n")

# ==================== HELPER FUNCTIONS ====================
def safe_json_load(json_str):
    if not json_str or json_str == 'null':
        return None
    try:
        return json.loads(json_str)
    except:
        return None

def calculate_duration(start, end):
    try:
        return (pd.to_datetime(end) - pd.to_datetime(start)).total_seconds() / 60
    except:
        return None

def get_config_label(use_memory, use_plan):
    if use_memory and use_plan:
        return 'M+P'
    elif use_memory:
        return 'M'
    elif use_plan:
        return 'P'
    else:
        return 'Base'

def print_header(title, char='=', width=100):
    print("\n" + char * width)
    print(f"{title.center(width)}")
    print(char * width + "\n")

def print_subheader(title, char='-', width=80):
    print("\n" + char * width)
    print(title)
    print(char * width)

print("✅ Helper functions loaded")

# ==================== LOAD DATA ====================
query_all = f"""
SELECT 
    session_id,
    student_role,
    ai_model,
    student_goes_first,
    use_memory,
    use_plan,
    total_rounds,
    deal_reached,
    deal_failed,
    status,
    created_at,
    updated_at,
    major,
    gender,
    negotiation_experience,
    transcript,
    student_deal_json,
    ai_deal_json
FROM negotiation_sessions
WHERE scenario_name = '{SCENARIO_FILTER}'
ORDER BY created_at DESC
"""

df_all = pd.read_sql_query(query_all, conn)
print(f"✅ Loaded {len(df_all)} sessions from database")

# ==================== DATA FILTERING ====================
print("\n" + "="*100)
print("🔍 APPLYING FILTERS")
print("="*100)

# 1. Filter by major: Exclude SDS/sds
original_count = len(df_all)
df_all = df_all[
    ~df_all['major'].str.lower().isin(['sds']) | df_all['major'].isna()
].copy()
print(f"1. Major filter: {original_count} → {len(df_all)} sessions (excluded SDS/sds)")

# 2. Filter by role: Only keep student as seller (side2)
before_role_filter = len(df_all)
df_all = df_all[df_all['student_role'] == 'side2'].copy()
print(f"2. Role filter: {before_role_filter} → {len(df_all)} sessions (Student = Seller only)")

# 3. Define time windows
morning_start = pd.to_datetime('2025-12-10 14:36')
morning_end = pd.to_datetime('2025-12-10 15:48')
afternoon_start = pd.to_datetime('2025-12-10 19:21')
afternoon_end = pd.to_datetime('2025-12-10 20:01')

# 4. Create time period column
def get_time_period(created_at):
    dt = pd.to_datetime(created_at)
    if morning_start <= dt <= morning_end:
        return 'Morning'
    elif afternoon_start <= dt <= afternoon_end:
        return 'Afternoon'
    else:
        return 'Other'

df_all['time_period'] = df_all['created_at'].apply(get_time_period)

# 5. Filter to only include Morning and Afternoon sessions
before_time_filter = len(df_all)
df_all = df_all[df_all['time_period'].isin(['Morning', 'Afternoon'])].copy()
print(f"3. Time filter: {before_time_filter} → {len(df_all)} sessions (Morning: 14:36-15:48, Afternoon: 19:21-20:01)")

# ==================== ADD ADDITIONAL COLUMNS ====================
print("\n✅ Creating derived columns...")

# Config
df_all['Config'] = df_all.apply(lambda r: get_config_label(r['use_memory'], r['use_plan']), axis=1)

# Duration
df_all['Duration (min)'] = df_all.apply(lambda r: calculate_duration(r['created_at'], r['updated_at']), axis=1)

# Outcome
df_all['Outcome'] = df_all.apply(lambda r: 
    '✅ Deal' if r['deal_reached'] 
    else '❌ Failed' if r['deal_failed'] 
    else '⏸️ Incomplete', axis=1)

# Role (all will be Seller now)
df_all['Role'] = '🏘️ Seller (Rosalind)'

# Rounds
def count_rounds(transcript_json):
    transcript = safe_json_load(transcript_json)
    return len(transcript) // 2 if transcript else 0

df_all['rounds'] = df_all['transcript'].apply(count_rounds)

# Final price (with fallback to AI JSON)
def extract_final_price(student_json_str, ai_json_str):
    # Try student JSON first
    student_json = safe_json_load(student_json_str)
    if student_json and 'final_price' in student_json:
        return student_json['final_price']
    
    # Fallback to AI JSON
    ai_json = safe_json_load(ai_json_str)
    if ai_json and 'final_price' in ai_json:
        return ai_json['final_price']
    
    return None

df_all['final_price'] = df_all.apply(
    lambda r: extract_final_price(r['student_deal_json'], r['ai_deal_json']) if r['deal_reached'] else None, 
    axis=1
)

print("✅ All columns created")

# ==================== OVERALL STATISTICS ====================
print_header("📊 OVERALL STATISTICS - SELLER ONLY (Both Sessions)")

print(f"Total Seller Sessions: {len(df_all)}")
print(f"  Morning (14:36-15:48): {(df_all['time_period'] == 'Morning').sum()}")
print(f"  Afternoon (19:21-20:01): {(df_all['time_period'] == 'Afternoon').sum()}")

print(f"\nSuccessful Deals: {df_all['deal_reached'].sum()} ({df_all['deal_reached'].sum()/len(df_all)*100:.1f}%)")
print(f"Failed Negotiations: {df_all['deal_failed'].sum()}")
print(f"Incomplete: {(~df_all['deal_reached'] & ~df_all['deal_failed']).sum()}")

print(f"\n📊 Configuration Breakdown:")
print(df_all['Config'].value_counts().to_string())

print(f"\n🎯 Who Goes First:")
print(df_all['student_goes_first'].map({True: 'Student First', False: 'AI First'}).value_counts().to_string())

# ==================== DISPLAY ALL DATA ====================
print("\n" + "="*170)
print("ALL FILTERED DATA - SELLER ONLY")
print("="*170)

display_df = df_all[[
    'session_id', 'time_period', 'Config', 'Outcome',
    'major', 'gender', 'negotiation_experience',
    'student_goes_first', 'rounds', 'final_price', 'Duration (min)', 'created_at'
]].copy()

display_df['session_id'] = display_df['session_id'].str[:8]
display_df['created_at'] = pd.to_datetime(display_df['created_at']).dt.strftime('%m-%d %H:%M')
display_df['Duration (min)'] = display_df['Duration (min)'].round(1)
display_df['final_price'] = display_df['final_price'].apply(lambda x: f"${x:,.0f}" if pd.notna(x) else "N/A")
display_df['rounds'] = display_df['rounds'].fillna(0).astype(int)
display_df['student_goes_first'] = display_df['student_goes_first'].map({True: '👤', False: '🤖'})

display_df.columns = ['Session', 'Period', 'Config', 'Outcome', 'Major', 'Gender', 'Exp', 'First', 'Rounds', 'Final Price', 'Duration', 'Created']

pd.set_option('display.max_rows', None)
display(display_df)


# ==================== ANALYSIS FUNCTION ====================
def analyze_time_period(df, period_name, period_label):
    """Analyze a specific time period's data - SELLER ONLY"""
    
    print_header(period_label)
    
    if len(df) == 0:
        print(f"❌ No data for {period_name}")
        return
    
    # Basic statistics
    print(f"Total Seller Sessions: {len(df)}")
    print(f"Successful Deals: {df['deal_reached'].sum()} ({df['deal_reached'].sum()/len(df)*100:.1f}%)")
    print(f"Failed Negotiations: {df['deal_failed'].sum()}")
    print(f"Incomplete: {(~df['deal_reached'] & ~df['deal_failed']).sum()}")
    
    print(f"\n📊 Configuration Breakdown:")
    print(df['Config'].value_counts().to_string())
    
    print(f"\n🎯 Who Goes First:")
    print(df['student_goes_first'].map({True: 'Student First', False: 'AI First'}).value_counts().to_string())
    
    # Demographics
    print_subheader("👥 Demographics")
    
    if df['major'].notna().sum() > 0:
        print("\n📚 Major:")
        major_counts = df['major'].value_counts()
        for major, count in major_counts.items():
            print(f"  {major}: {count}")
    
    if df['gender'].notna().sum() > 0:
        print("\n⚧ Gender:")
        gender_counts = df['gender'].value_counts()
        for gender, count in gender_counts.items():
            print(f"  {gender}: {count}")
    
    if df['negotiation_experience'].notna().sum() > 0:
        print("\n💼 Experience:")
        exp_counts = df['negotiation_experience'].value_counts()
        for exp, count in exp_counts.items():
            print(f"  {exp}: {count}")
    
    # Deal analysis
    df_deals = df[df['deal_reached'] == True].copy()
    
    if len(df_deals) == 0:
        print("\n❌ No successful deals in this period")
        return
    
    print_subheader("💰 Deal Price Analysis - SELLER PERSPECTIVE")
    print("📈 Remember: As SELLER, HIGHER prices are BETTER (Goal: Maximize price)")
    
    # Extract numeric prices
    df_deals['price_numeric'] = df_deals['final_price']
    valid_prices = df_deals['price_numeric'].dropna()
    
    if len(valid_prices) == 0:
        print("\n❌ No valid price data")
        return
    
    print(f"\n📊 Overall Price Statistics:")
    print(f"  Average: ${valid_prices.mean():,.0f}")
    print(f"  Median:  ${valid_prices.median():,.0f}")
    print(f"  Min:     ${valid_prices.min():,.0f}")
    print(f"  Max:     ${valid_prices.max():,.0f}")
    print(f"  Std Dev: ${valid_prices.std():,.0f}")
    
    # ============================================================
    # DETAILED ANALYSIS: BASE vs M+P
    # ============================================================
    print_subheader("🔧 Configuration Deep Dive: BASE vs M+P")
    
    for config in ['Base', 'M+P']:
        config_deals = df_deals[df_deals['Config'] == config].copy()
        config_prices = config_deals['price_numeric'].dropna()
        
        if len(config_prices) == 0:
            print(f"\n{config}: No deals found")
            continue
        
        print(f"\n{'='*80}")
        print(f"📊 {config} Configuration - SELLER Results")
        print(f"{'='*80}")
        print(f"Total Deals: {len(config_prices)}")
        print(f"Average Price: ${config_prices.mean():,.0f} 📈 (Higher is better for seller)")
        print(f"Median Price:  ${config_prices.median():,.0f}")
        print(f"Price Range: ${config_prices.min():,.0f} - ${config_prices.max():,.0f}")
        if len(config_prices) > 1:
            print(f"Std Dev: ${config_prices.std():,.0f}")
        
        # ============================================================
        # WHO GOES FIRST ANALYSIS
        # ============================================================
        print(f"\n🎯 Who Goes First Analysis:")
        
        student_first = config_deals[config_deals['student_goes_first'] == True]
        ai_first = config_deals[config_deals['student_goes_first'] == False]
        
        student_first_prices = student_first['price_numeric'].dropna()
        ai_first_prices = ai_first['price_numeric'].dropna()
        
        print(f"\n  👤 Student First (n={len(student_first_prices)}):")
        if len(student_first_prices) > 0:
            print(f"    Average: ${student_first_prices.mean():,.0f}")
            print(f"    Median:  ${student_first_prices.median():,.0f}")
            print(f"    Range: ${student_first_prices.min():,.0f} - ${student_first_prices.max():,.0f}")
        else:
            print(f"    No data")
        
        print(f"\n  🤖 AI First (n={len(ai_first_prices)}):")
        if len(ai_first_prices) > 0:
            print(f"    Average: ${ai_first_prices.mean():,.0f}")
            print(f"    Median:  ${ai_first_prices.median():,.0f}")
            print(f"    Range: ${ai_first_prices.min():,.0f} - ${ai_first_prices.max():,.0f}")
        else:
            print(f"    No data")
        
        # Calculate impact if both exist
        if len(student_first_prices) > 0 and len(ai_first_prices) > 0:
            diff = student_first_prices.mean() - ai_first_prices.mean()
            print(f"\n  💡 Impact for SELLER:")
            print(f"    Price difference: ${abs(diff):,.0f}")
            if diff > 0:
                print(f"    ✅ BETTER for seller when student goes first (+${diff:,.0f})")
            elif diff < 0:
                print(f"    ❌ WORSE for seller when student goes first (${diff:,.0f})")
            else:
                print(f"    → No difference")
    
    # ============================================================
    # COMPARISON TABLE
    # ============================================================
    print_subheader("📊 Summary Comparison Table - SELLER PERSPECTIVE")
    
    comparison_data = []
    for config in ['Base', 'M+P']:
        config_deals_sub = df_deals[df_deals['Config'] == config]
        config_prices_sub = config_deals_sub['price_numeric'].dropna()
        
        if len(config_prices_sub) == 0:
            continue
        
        # Overall
        comparison_data.append({
            'Config': config,
            'Category': 'Overall',
            'N': len(config_prices_sub),
            'Avg Price': f"${config_prices_sub.mean():,.0f}",
            'Median': f"${config_prices_sub.median():,.0f}",
            'Range': f"${config_prices_sub.min():,.0f}-${config_prices_sub.max():,.0f}"
        })
        
        # Student goes first
        sf = config_deals_sub[config_deals_sub['student_goes_first'] == True]['price_numeric'].dropna()
        if len(sf) > 0:
            comparison_data.append({
                'Config': config,
                'Category': 'Student First',
                'N': len(sf),
                'Avg Price': f"${sf.mean():,.0f}",
                'Median': f"${sf.median():,.0f}",
                'Range': f"${sf.min():,.0f}-${sf.max():,.0f}"
            })
        
        # AI goes first
        af = config_deals_sub[config_deals_sub['student_goes_first'] == False]['price_numeric'].dropna()
        if len(af) > 0:
            comparison_data.append({
                'Config': config,
                'Category': 'AI First',
                'N': len(af),
                'Avg Price': f"${af.mean():,.0f}",
                'Median': f"${af.median():,.0f}",
                'Range': f"${af.min():,.0f}-${af.max():,.0f}"
            })
    
    if comparison_data:
        comp_df = pd.DataFrame(comparison_data)
        display(comp_df)
    
    # Duration and rounds
    print_subheader("⏱️ Duration & Rounds Analysis")
    
    valid_durations = df_deals['Duration (min)'].dropna()
    if len(valid_durations) > 0:
        print(f"\nDuration Statistics:")
        print(f"  Average: {valid_durations.mean():.1f} minutes")
        print(f"  Median:  {valid_durations.median():.1f} minutes")
        print(f"  Range: {valid_durations.min():.1f} - {valid_durations.max():.1f} minutes")
    
    valid_rounds = df_deals['rounds']
    if len(valid_rounds) > 0:
        print(f"\nRounds Statistics:")
        print(f"  Average: {valid_rounds.mean():.1f} rounds")
        print(f"  Median:  {valid_rounds.median():.0f} rounds")
        print(f"  Range: {valid_rounds.min():.0f} - {valid_rounds.max():.0f} rounds")
    
    # Detailed table
    print_subheader("📋 Detailed Session List - SELLER ONLY")
    
    detail_df = df[[
        'session_id', 'Config', 'Outcome', 'major',
        'student_goes_first', 'rounds', 'final_price', 'Duration (min)', 'created_at'
    ]].copy()
    
    detail_df['session_id'] = detail_df['session_id'].str[:8]
    detail_df['created_at'] = pd.to_datetime(detail_df['created_at']).dt.strftime('%H:%M')
    detail_df['Duration (min)'] = detail_df['Duration (min)'].round(1)
    detail_df['final_price'] = detail_df['final_price'].apply(lambda x: f"${x:,.0f}" if pd.notna(x) else "N/A")
    detail_df['student_goes_first'] = detail_df['student_goes_first'].map({True: '👤 Student', False: '🤖 AI'})
    
    detail_df.columns = ['Session', 'Config', 'Outcome', 'Major', 'First', 'Rounds', 'Price', 'Duration', 'Time']
    
    display(detail_df)


# ==================== MORNING SESSION ANALYSIS ====================
df_morning = df_all[df_all['time_period'] == 'Morning'].copy()
analyze_time_period(df_morning, 'Morning', '🌅 MORNING SESSION - SELLER ONLY (14:36-15:48)')

# ==================== AFTERNOON SESSION ANALYSIS ====================
df_afternoon = df_all[df_all['time_period'] == 'Afternoon'].copy()
analyze_time_period(df_afternoon, 'Afternoon', '🌆 AFTERNOON SESSION - SELLER ONLY (19:21-20:01)')

# ==================== COMPARISON BETWEEN SESSIONS ====================
print_header("⚖️ MORNING vs AFTERNOON COMPARISON - SELLER ONLY")

comparison_data = []

for period_name, df_period in [('Morning', df_morning), ('Afternoon', df_afternoon)]:
    deals = df_period[df_period['deal_reached'] == True]
    prices = deals['final_price'].dropna()
    
    comparison_data.append({
        'Period': period_name,
        'Total Sessions': len(df_period),
        'Deals': len(deals),
        'Success Rate': f"{len(deals)/len(df_period)*100:.1f}%" if len(df_period) > 0 else "N/A",
        'Avg Price': f"${prices.mean():,.0f}" if len(prices) > 0 else "N/A",
        'Avg Rounds': f"{deals['rounds'].mean():.1f}" if len(deals) > 0 else "N/A",
        'Avg Duration': f"{deals['Duration (min)'].mean():.1f} min" if len(deals) > 0 else "N/A"
    })

comparison_df = pd.DataFrame(comparison_data)
display(comparison_df)

print("\n✅ Seller-only analysis complete!")
print("📈 Remember: As SELLER, higher prices indicate better negotiation outcomes")
# Out:
# ✅ Connected to: negotiations_mainst.db
# 🎯 Analyzing scenario: Main_Street
# 🎯 Focus: Student as SELLER only
#
# ✅ Helper functions loaded
# ✅ Loaded 154 sessions from database
#
# ====================================================================================================
# 🔍 APPLYING FILTERS
# ====================================================================================================
# 1. Major filter: 154 → 116 sessions (excluded SDS/sds)
# 2. Role filter: 116 → 115 sessions (Student = Seller only)
# 3. Time filter: 115 → 108 sessions (Morning: 14:36-15:48, Afternoon: 19:21-20:01)
#
# ✅ Creating derived columns...
# ✅ All columns created
#
# ====================================================================================================
#                          📊 OVERALL STATISTICS - SELLER ONLY (Both Sessions)
# ====================================================================================================
#
# Total Seller Sessions: 108
#   Morning (14:36-15:48): 67
#   Afternoon (19:21-20:01): 41
#
# Successful Deals: 76 (70.4%)
# Failed Negotiations: 2
# Incomplete: -186
#
# 📊 Configuration Breakdown:
# Config
# Base    57
# M+P     51
#
# 🎯 Who Goes First:
# Series([], )
#
# ==========================================================================================================================================================================
# ALL FILTERED DATA - SELLER ONLY
# ==========================================================================================================================================================================
#       Session     Period Config        Outcome  \
# 1    b37f26ac  Afternoon   Base         ✅ Deal
# 2    33f1a7e7  Afternoon   Base  ⏸️ Incomplete
# 3    1da9f9c4  Afternoon    M+P         ✅ Deal
# 4    0ad06bea  Afternoon   Base         ✅ Deal
# 5    d0f674cd  Afternoon    M+P  ⏸️ Incomplete
# 6    799f52db  Afternoon   Base         ✅ Deal
# 7    95e44a5d  Afternoon   Base         ✅ Deal
# 8    16eceb2c  Afternoon    M+P         ✅ Deal
# 10   31db345d  Afternoon    M+P         ✅ Deal
# 11   88bdd965  Afternoon   Base         ✅ Deal
# 12   50f35769  Afternoon   Base         ✅ Deal
# 13   1c047b8c  Afternoon    M+P         ✅ Deal
# 14   1accb1db  Afternoon    M+P         ✅ Deal
# 15   bb74becf  Afternoon   Base         ✅ Deal
# 16   91bf642e  Afternoon    M+P         ✅ Deal
# 17   7443cda3  Afternoon    M+P         ✅ Deal
# 18   938b042a  Afternoon   Base  ⏸️ Incomplete
# 19   562a5935  Afternoon   Base         ✅ Deal
# 20   0b0c3e36  Afternoon    M+P  ⏸️ Incomplete
# 21   efc8ced7  Afternoon    M+P         ✅ Deal
# 22   e4db51d8  Afternoon    M+P  ⏸️ Incomplete
# 23   2707b436  Afternoon    M+P  ⏸️ Incomplete
# 24   98028e11  Afternoon    M+P         ✅ Deal
# 25   9864a8ac  Afternoon   Base         ✅ Deal
# 26   19189653  Afternoon    M+P         ✅ Deal
# 27   65568ba8  Afternoon   Base         ✅ Deal
# 28   09116786  Afternoon   Base         ✅ Deal
# 29   350ef762  Afternoon   Base  ⏸️ Incomplete
# 30   f8b904d4  Afternoon    M+P         ✅ Deal
# 31   2b985adf  Afternoon   Base         ✅ Deal
# 32   538cd73f  Afternoon   Base  ⏸️ Incomplete
# 33   516685e6  Afternoon    M+P         ✅ Deal
# 34   ee8d9c66  Afternoon   Base  ⏸️ Incomplete
# 35   d08ef3f9  Afternoon    M+P         ✅ Deal
# 36   e00fe024  Afternoon   Base       ❌ Failed
# 37   4eb7d6b7  Afternoon   Base         ✅ Deal
# 38   0edb4787  Afternoon    M+P         ✅ Deal
# 39   b19200a0  Afternoon   Base  ⏸️ Incomplete
# 40   4240e9c5  Afternoon   Base  ⏸️ Incomplete
# 41   6c890dba  Afternoon    M+P  ⏸️ Incomplete
# 42   20b90946  Afternoon    M+P  ⏸️ Incomplete
# 46   f8108b66    Morning   Base         ✅ Deal
# 50   44902306    Morning   Base  ⏸️ Incomplete
# 52   519ed03e    Morning   Base  ⏸️ Incomplete
# 53   d61b1421    Morning   Base  ⏸️ Incomplete
# 54   8f327691    Morning   Base         ✅ Deal
# 55   49f9367b    Morning   Base  ⏸️ Incomplete
# 56   def6ce77    Morning   Base         ✅ Deal
# 57   a6587ccb    Morning   Base  ⏸️ Incomplete
# 58   ff4187e1    Morning    M+P         ✅ Deal
# 59   2c58997c    Morning   Base         ✅ Deal
# 60   1c64c52d    Morning   Base         ✅ Deal
# 61   22e1c990    Morning    M+P  ⏸️ Incomplete
# 62   320f365c    Morning   Base         ✅ Deal
# 63   583603ec    Morning    M+P         ✅ Deal
# 64   f727eff6    Morning    M+P  ⏸️ Incomplete
# 65   24a24ce4    Morning    M+P         ✅ Deal
# 66   a027bad3    Morning   Base       ❌ Failed
# 67   da8e805c    Morning    M+P         ✅ Deal
# 68   bb4f01c8    Morning   Base         ✅ Deal
# 69   6ba03567    Morning   Base  ⏸️ Incomplete
# 70   fefa4d90    Morning   Base         ✅ Deal
# 71   3ce4dbec    Morning   Base  ⏸️ Incomplete
# 72   53c67d59    Morning    M+P         ✅ Deal
# 73   fae036e8    Morning   Base         ✅ Deal
# 74   e014a8cd    Morning   Base         ✅ Deal
# 75   bf242471    Morning   Base         ✅ Deal
# 76   daa71a3a    Morning   Base         ✅ Deal
# 77   187ee6e1    Morning   Base         ✅ Deal
# 78   7ab01b6d    Morning    M+P         ✅ Deal
# 79   a5a7bbed    Morning    M+P         ✅ Deal
# 80   f0c044d9    Morning   Base         ✅ Deal
# 81   cba8d9c9    Morning   Base         ✅ Deal
# 82   dd354523    Morning   Base  ⏸️ Incomplete
# 83   5c9d6f09    Morning   Base         ✅ Deal
# 84   118af3de    Morning   Base         ✅ Deal
# 85   486f9419    Morning   Base         ✅ Deal
# 86   13697589    Morning   Base         ✅ Deal
# 87   81eafc5a    Morning    M+P         ✅ Deal
# 88   fe68b67b    Morning    M+P         ✅ Deal
# 89   a5291dbb    Morning    M+P         ✅ Deal
# 90   baf91c79    Morning    M+P         ✅ Deal
# 91   f167c9c9    Morning   Base  ⏸️ Incomplete
# 92   ed40d7bb    Morning   Base         ✅ Deal
# 93   9a00be6e    Morning    M+P         ✅ Deal
# 94   da734cf6    Morning    M+P         ✅ Deal
# 95   023fa610    Morning    M+P  ⏸️ Incomplete
# 96   2e473faf    Morning    M+P         ✅ Deal
# 97   35cd2da6    Morning   Base         ✅ Deal
# 98   73297254    Morning    M+P         ✅ Deal
# 99   34bd3d91    Morning    M+P         ✅ Deal
# 100  fef6c2b3    Morning    M+P         ✅ Deal
# 101  e15e86b4    Morning    M+P         ✅ Deal
# 102  cdb4b68d    Morning   Base         ✅ Deal
# 103  33365183    Morning    M+P         ✅ Deal
# 104  fabc68b2    Morning   Base         ✅ Deal
# 105  526567fb    Morning    M+P         ✅ Deal
# 106  6a1f1023    Morning    M+P         ✅ Deal
# 107  746b9508    Morning    M+P         ✅ Deal
# 108  2527e1ea    Morning   Base         ✅ Deal
# 109  4093ffc5    Morning    M+P         ✅ Deal
# 110  073b248f    Morning    M+P         ✅ Deal
# 111  82de1f8e    Morning    M+P  ⏸️ Incomplete
# 112  20260374    Morning    M+P         ✅ Deal
# 113  8fe436e8    Morning    M+P  ⏸️ Incomplete
# 114  c29a5a57    Morning    M+P  ⏸️ Incomplete
# 115  7fe2649b    Morning   Base  ⏸️ Incomplete
# 116  7f6097c2    Morning   Base  ⏸️ Incomplete
#
#                                        Major      Gender              Exp  \
# 1                                    Theater      Female       Occasional
# 2                                    Theater      Female       Occasional
# 3                                        GBS
# 4                                        MBA
# 5                                        GBS
# 6                               MBA Exchange              A few instances
# 7                                        MBA        Male  A few instances
# 8                                        GBS      Female  A few instances
# 10                                      Tech        Male       Occasional
# 11
# 12                                  Business        Male  A few instances
# 13
# 14               Global Business and Society        Male       Occasional
# 15                                  Business        Male             None
# 16                                       MBA      Female       Occasional
# 17                                       GBS      Female
# 18                                    2Y MBA      Female  A few instances
# 19                                       GBS      Female       Occasional
# 20                                       GBS      Female  A few instances
# 21                                       MBA      Female       Occasional
# 22                                       MBA      Female       Occasional
# 23                                   Theater      Female       Occasional
# 24
# 25                                       GBS      Female  A few instances
# 26                                       MBA        Male  A few instances
# 27                                       MBA
# 28                                Management        Male  A few instances
# 29
# 30                      School of Management        Male  A few instances
# 31                                       GBS      Female  A few instances
# 32                                       MBA
# 33                                       GBS        Male  A few instances
# 34                     Healthcare Management      Female  A few instances
# 35                                                  Male  A few instances
# 36                                       MBA        Male  A few instances
# 37                                       MBA        Male  A few instances
# 38                                       GBS      Female  A few instances
# 39                                       MBA        Male  A few instances
# 40                                       MBA        Male  A few instances
# 41   Master of Business Administration (MBA)        Male             None
# 42                                Management        Male       Occasional
# 46                        Health Informatics      Female             None
# 50                                  Business
# 52                                Management        Male  A few instances
# 53
# 54
# 55                                  Business
# 56                             public health      Female             None
# 57                                       MBA        Male         Frequent
# 58                                       GBS      Female  A few instances
# 59                 Global Business & Society        Male       Occasional
# 60                 Global Business & Society        Male  A few instances
# 61                                       GBS      Female  A few instances
# 62                                       GBS      Female             None
# 63                                       GBS        Male             None
# 64                    Mechanical Engineering        Male       Occasional
# 65                                       GBS        Male  A few instances
# 66                                       GBS        Male     Professional
# 67                                Management        Male             None
# 68                                       MBA      Female       Occasional
# 69                 Global Business & Society        Male  A few instances
# 70                                Management      Female  A few instances
# 71
# 72                                  Business        Male       Occasional
# 73                        Management Science      Female       Occasional
# 74                     Technology Management        Male       Occasional
# 75                                       MBA      Female  A few instances
# 76         Master of Business Administration        Male             None
# 77                                       MBA        Male         Frequent
# 78                                       MBA        Male  A few instances
# 79                                       GBS      Female  A few instances
# 80                                       GBS      Female  A few instances
# 81                        Management Science        Male             None
# 82                                       MBA        Male  A few instances
# 83                            Yale SOM - GBS      Female       Occasional
# 84                                       MBA        Male  A few instances
# 85                                       MBA        Male  A few instances
# 86                             Arrchitecture        Male  A few instances
# 87                                Management      Female  A few instances
# 88                  Master in Management GBS      Female
# 89                                       GBS      Female         Frequent
# 90                               Mathematics        Male  A few instances
# 91                 Global Business & Society        Male       Occasional
# 92               Global Business and Society  Non-binary       Occasional
# 93
# 94                          Asset Management        Male  A few instances
# 95                             public health      Female             None
# 96            Masters of Advanced Management        Male       Occasional
# 97                                Management        Male             None
# 98                    Mechanical Engineering        Male       Occasional
# 99         Master of Business Administration      Female  A few instances
# 100                                      GBS        Male             None
# 101                                      GBS      Female  A few instances
# 102                           Global Affairs        Male  A few instances
# 103                                      MBA        Male       Occasional
# 104                               Management        Male  A few instances
# 105
# 106                               Management        Male       Occasional
# 107
# 108                                      MBA        Male  A few instances
# 109              Global business and society        Male  A few instances
# 110                                      Law        Male             None
# 111                               Management        Male       Occasional
# 112              Global Business and Society              A few instances
# 113                               Management        Male       Occasional
# 114                                      MBA
# 115                                      MBA        Male         Frequent
# 116                       Management Science        Male       Occasional
#
#     First  Rounds Final Price  Duration      Created
# 1     NaN       4    $575,000       7.1  12-10 19:52
# 2     NaN       0         N/A       0.8  12-10 19:51
# 3     NaN       4    $515,000      29.1  12-10 19:49
# 4     NaN       6    $465,000      11.4  12-10 19:44
# 5     NaN       0         N/A       0.0  12-10 19:44
# 6     NaN       6    $549,000      27.0  12-10 19:39
# 7     NaN       6    $570,000       8.7  12-10 19:38
# 8     NaN       8    $585,000      42.6  12-10 19:37
# 10    NaN       5    $565,000      22.7  12-10 19:35
# 11    NaN       5    $565,000      20.5  12-10 19:35
# 12    NaN       5    $630,000      20.2  12-10 19:35
# 13    NaN       6    $550,000      25.3  12-10 19:35
# 14    NaN       6    $630,000      44.0  12-10 19:35
# 15    NaN       6    $600,000      18.4  12-10 19:35
# 16    NaN       6    $525,000      20.2  12-10 19:34
# 17    NaN       5    $540,000      18.1  12-10 19:34
# 18    NaN       5         N/A      19.5  12-10 19:34
# 19    NaN       6    $590,000      24.7  12-10 19:33
# 20    NaN       0         N/A       0.9  12-10 19:33
# 21    NaN       6    $560,000      24.0  12-10 19:33
# 22    NaN       0         N/A       1.2  12-10 19:32
# 23    NaN       3         N/A      13.5  12-10 19:32
# 24    NaN       6    $552,000      25.4  12-10 19:31
# 25    NaN       5    $512,500      20.3  12-10 19:31
# 26    NaN       5    $529,000      31.8  12-10 19:31
# 27    NaN       5    $560,000      26.6  12-10 19:30
# 28    NaN       6    $650,000      29.2  12-10 19:29
# 29    NaN       0         N/A       0.6  12-10 19:29
# 30    NaN       7    $585,000      41.2  12-10 19:28
# 31    NaN       6    $555,000      49.8  12-10 19:28
# 32    NaN       0         N/A       0.6  12-10 19:28
# 33    NaN       5    $505,000      38.1  12-10 19:28
# 34    NaN       5         N/A      23.7  12-10 19:27
# 35    NaN       5    $550,000      34.2  12-10 19:26
# 36    NaN       6         N/A      40.9  12-10 19:25
# 37    NaN       6    $550,000      11.5  12-10 19:23
# 38    NaN       5    $508,000      29.3  12-10 19:23
# 39    NaN       1         N/A       9.9  12-10 19:23
# 40    NaN       6         N/A      12.7  12-10 19:23
# 41    NaN       4         N/A      16.6  12-10 19:22
# 42    NaN       0         N/A       0.0  12-10 19:21
# 46    NaN       5    $490,000      16.4  12-10 15:37
# 50    NaN       0         N/A       0.5  12-10 15:28
# 52    NaN       0         N/A       0.0  12-10 15:25
# 53    NaN       5         N/A      11.9  12-10 15:10
# 54    NaN       6    $545,000      18.6  12-10 15:09
# 55    NaN       0         N/A       0.5  12-10 15:09
# 56    NaN       6    $530,000      11.0  12-10 15:07
# 57    NaN       0         N/A       0.6  12-10 15:01
# 58    NaN       6    $570,000      20.5  12-10 15:00
# 59    NaN       6    $535,000       9.2  12-10 14:59
# 60    NaN       6    $600,000      14.9  12-10 14:57
# 61    NaN       2         N/A       8.5  12-10 14:52
# 62    NaN       6    $600,000      17.3  12-10 14:50
# 63    NaN       6    $537,500      17.6  12-10 14:50
# 64    NaN       0         N/A       0.7  12-10 14:49
# 65    NaN       4    $555,000      15.0  12-10 14:49
# 66    NaN       6         N/A      20.4  12-10 14:48
# 67    NaN       6    $540,000      29.4  12-10 14:48
# 68    NaN       6    $535,000      11.5  12-10 14:48
# 69    NaN       1         N/A       4.9  12-10 14:48
# 70    NaN       5    $550,000      28.4  12-10 14:48
# 71    NaN       5         N/A      21.9  12-10 14:47
# 72    NaN       6    $555,000      30.1  12-10 14:47
# 73    NaN       6    $550,000      20.8  12-10 14:47
# 74    NaN       6    $550,000      32.3  12-10 14:47
# 75    NaN       5    $540,000      10.9  12-10 14:47
# 76    NaN       6    $540,000      26.5  12-10 14:47
# 77    NaN       6    $560,000      18.6  12-10 14:47
# 78    NaN       6    $550,000      19.1  12-10 14:47
# 79    NaN       6    $555,000      25.2  12-10 14:47
# 80    NaN       6    $575,000      11.3  12-10 14:46
# 81    NaN       6    $590,000      21.2  12-10 14:46
# 82    NaN       6         N/A       8.0  12-10 14:46
# 83    NaN       5    $535,000      24.1  12-10 14:46
# 84    NaN       5    $545,000      13.8  12-10 14:46
# 85    NaN       4    $535,000      15.6  12-10 14:46
# 86    NaN       6    $480,000      22.9  12-10 14:46
# 87    NaN       6    $500,000      23.0  12-10 14:45
# 88    NaN       6    $595,000      18.6  12-10 14:45
# 89    NaN       6    $548,000      40.5  12-10 14:45
# 90    NaN       6    $550,000      29.5  12-10 14:45
# 91    NaN       4         N/A      11.8  12-10 14:44
# 92    NaN       6    $517,500      31.0  12-10 14:44
# 93    NaN       5    $545,000      18.4  12-10 14:43
# 94    NaN       7    $550,000      33.9  12-10 14:43
# 95    NaN       4         N/A      18.3  12-10 14:43
# 96    NaN       6    $560,000      22.3  12-10 14:43
# 97    NaN       6    $549,000      28.1  12-10 14:42
# 98    NaN       3    $505,000       6.7  12-10 14:42
# 99    NaN       6    $578,500      31.4  12-10 14:41
# 100   NaN       6    $520,000      32.3  12-10 14:41
# 101   NaN       5    $540,000      34.2  12-10 14:40
# 102   NaN       7    $650,000      27.1  12-10 14:40
# 103   NaN       6    $538,500      41.2  12-10 14:39
# 104   NaN       6    $535,000      42.7  12-10 14:39
# 105   NaN       5    $560,000      24.5  12-10 14:39
# 106   NaN       6    $510,000      28.9  12-10 14:39
# 107   NaN       6    $570,000      34.9  12-10 14:39
# 108   NaN       6    $575,000      18.6  12-10 14:39
# 109   NaN       6    $515,000      21.2  12-10 14:38
# 110   NaN       6    $525,000      33.7  12-10 14:38
# 111   NaN       0         N/A       0.7  12-10 14:38
# 112   NaN       6    $562,500      26.2  12-10 14:38
# 113   NaN       0         N/A       1.0  12-10 14:37
# 114   NaN       5         N/A      26.1  12-10 14:37
# 115   NaN       6         N/A      20.1  12-10 14:36
# 116   NaN       6         N/A      28.3  12-10 14:36
# ====================================================================================================
#                            🌅 MORNING SESSION - SELLER ONLY (14:36-15:48)
# ====================================================================================================
#
# Total Seller Sessions: 67
# Successful Deals: 49 (73.1%)
# Failed Negotiations: 1
# Incomplete: -117
#
# 📊 Configuration Breakdown:
# Config
# Base    36
# M+P     31
#
# 🎯 Who Goes First:
# Series([], )
#
# --------------------------------------------------------------------------------
# 👥 Demographics
# --------------------------------------------------------------------------------
#
# 📚 Major:
#   MBA: 12
#   GBS: 11
#   Management: 9
#   : 6
#   Global Business & Society: 4
#   Business: 3
#   Management Science: 3
#   public health: 2
#   Master of Business Administration: 2
#   Mechanical Engineering: 2
#   Global Business and Society: 2
#   Health Informatics: 1
#   Yale SOM - GBS: 1
#   Technology Management: 1
#   Arrchitecture: 1
#   Master in Management GBS: 1
#   Mathematics: 1
#   Asset Management: 1
#   Masters of Advanced Management: 1
#   Global Affairs: 1
#   Global business and society: 1
#   Law: 1
#
# ⚧ Gender:
#   Male: 38
#   Female: 18
#   : 10
#   Non-binary: 1
#
# 💼 Experience:
#   A few instances: 25
#   Occasional: 16
#   None: 11
#   : 10
#   Frequent: 4
#   Professional: 1
#
# --------------------------------------------------------------------------------
# 💰 Deal Price Analysis - SELLER PERSPECTIVE
# --------------------------------------------------------------------------------
# 📈 Remember: As SELLER, HIGHER prices are BETTER (Goal: Maximize price)
#
# 📊 Overall Price Statistics:
#   Average: $547,888
#   Median:  $548,000
#   Min:     $480,000
#   Max:     $650,000
#   Std Dev: $29,765
#
# --------------------------------------------------------------------------------
# 🔧 Configuration Deep Dive: BASE vs M+P
# --------------------------------------------------------------------------------
#
# ================================================================================
# 📊 Base Configuration - SELLER Results
# ================================================================================
# Total Deals: 24
# Average Price: $550,479 📈 (Higher is better for seller)
# Median Price:  $545,000
# Price Range: $480,000 - $650,000
# Std Dev: $35,678
#
# 🎯 Who Goes First Analysis:
#
#   👤 Student First (n=10):
#     Average: $561,500
#     Median:  $555,000
#     Range: $480,000 - $650,000
#
#   🤖 AI First (n=14):
#     Average: $542,607
#     Median:  $542,500
#     Range: $490,000 - $600,000
#
#   💡 Impact for SELLER:
#     Price difference: $18,893
#     ✅ BETTER for seller when student goes first (+$18,893)
#
# ================================================================================
# 📊 M+P Configuration - SELLER Results
# ================================================================================
# Total Deals: 25
# Average Price: $545,400 📈 (Higher is better for seller)
# Median Price:  $550,000
# Price Range: $500,000 - $595,000
# Std Dev: $23,213
#
# 🎯 Who Goes First Analysis:
#
#   👤 Student First (n=11):
#     Average: $554,273
#     Median:  $555,000
#     Range: $515,000 - $595,000
#
#   🤖 AI First (n=14):
#     Average: $538,429
#     Median:  $546,500
#     Range: $500,000 - $570,000
#
#   💡 Impact for SELLER:
#     Price difference: $15,844
#     ✅ BETTER for seller when student goes first (+$15,844)
#
# --------------------------------------------------------------------------------
# 📊 Summary Comparison Table - SELLER PERSPECTIVE
# --------------------------------------------------------------------------------
#   Config       Category   N Avg Price    Median              Range
# 0   Base        Overall  24  $550,479  $545,000  $480,000-$650,000
# 1   Base  Student First  10  $561,500  $555,000  $480,000-$650,000
# 2   Base       AI First  14  $542,607  $542,500  $490,000-$600,000
# 3    M+P        Overall  25  $545,400  $550,000  $500,000-$595,000
# 4    M+P  Student First  11  $554,273  $555,000  $515,000-$595,000
# 5    M+P       AI First  14  $538,429  $546,500  $500,000-$570,000
# --------------------------------------------------------------------------------
# ⏱️ Duration & Rounds Analysis
# --------------------------------------------------------------------------------
#
# Duration Statistics:
#   Average: 23.5 minutes
#   Median:  22.9 minutes
#   Range: 6.7 - 42.7 minutes
#
# Rounds Statistics:
#   Average: 5.7 rounds
#   Median:  6 rounds
#   Range: 3 - 7 rounds
#
# --------------------------------------------------------------------------------
# 📋 Detailed Session List - SELLER ONLY
# --------------------------------------------------------------------------------
#       Session Config        Outcome                              Major First  \
# 46   f8108b66   Base         ✅ Deal                 Health Informatics   NaN
# 50   44902306   Base  ⏸️ Incomplete                           Business   NaN
# 52   519ed03e   Base  ⏸️ Incomplete                         Management   NaN
# 53   d61b1421   Base  ⏸️ Incomplete                                      NaN
# 54   8f327691   Base         ✅ Deal                                      NaN
# 55   49f9367b   Base  ⏸️ Incomplete                           Business   NaN
# 56   def6ce77   Base         ✅ Deal                      public health   NaN
# 57   a6587ccb   Base  ⏸️ Incomplete                                MBA   NaN
# 58   ff4187e1    M+P         ✅ Deal                                GBS   NaN
# 59   2c58997c   Base         ✅ Deal          Global Business & Society   NaN
# 60   1c64c52d   Base         ✅ Deal          Global Business & Society   NaN
# 61   22e1c990    M+P  ⏸️ Incomplete                                GBS   NaN
# 62   320f365c   Base         ✅ Deal                                GBS   NaN
# 63   583603ec    M+P         ✅ Deal                                GBS   NaN
# 64   f727eff6    M+P  ⏸️ Incomplete             Mechanical Engineering   NaN
# 65   24a24ce4    M+P         ✅ Deal                                GBS   NaN
# 66   a027bad3   Base       ❌ Failed                                GBS   NaN
# 67   da8e805c    M+P         ✅ Deal                         Management   NaN
# 68   bb4f01c8   Base         ✅ Deal                                MBA   NaN
# 69   6ba03567   Base  ⏸️ Incomplete          Global Business & Society   NaN
# 70   fefa4d90   Base         ✅ Deal                         Management   NaN
# 71   3ce4dbec   Base  ⏸️ Incomplete                                      NaN
# 72   53c67d59    M+P         ✅ Deal                           Business   NaN
# 73   fae036e8   Base         ✅ Deal                 Management Science   NaN
# 74   e014a8cd   Base         ✅ Deal              Technology Management   NaN
# 75   bf242471   Base         ✅ Deal                                MBA   NaN
# 76   daa71a3a   Base         ✅ Deal  Master of Business Administration   NaN
# 77   187ee6e1   Base         ✅ Deal                                MBA   NaN
# 78   7ab01b6d    M+P         ✅ Deal                                MBA   NaN
# 79   a5a7bbed    M+P         ✅ Deal                                GBS   NaN
# 80   f0c044d9   Base         ✅ Deal                                GBS   NaN
# 81   cba8d9c9   Base         ✅ Deal                 Management Science   NaN
# 82   dd354523   Base  ⏸️ Incomplete                                MBA   NaN
# 83   5c9d6f09   Base         ✅ Deal                     Yale SOM - GBS   NaN
# 84   118af3de   Base         ✅ Deal                                MBA   NaN
# 85   486f9419   Base         ✅ Deal                                MBA   NaN
# 86   13697589   Base         ✅ Deal                      Arrchitecture   NaN
# 87   81eafc5a    M+P         ✅ Deal                         Management   NaN
# 88   fe68b67b    M+P         ✅ Deal           Master in Management GBS   NaN
# 89   a5291dbb    M+P         ✅ Deal                                GBS   NaN
# 90   baf91c79    M+P         ✅ Deal                        Mathematics   NaN
# 91   f167c9c9   Base  ⏸️ Incomplete          Global Business & Society   NaN
# 92   ed40d7bb   Base         ✅ Deal        Global Business and Society   NaN
# 93   9a00be6e    M+P         ✅ Deal                                      NaN
# 94   da734cf6    M+P         ✅ Deal                   Asset Management   NaN
# 95   023fa610    M+P  ⏸️ Incomplete                      public health   NaN
# 96   2e473faf    M+P         ✅ Deal     Masters of Advanced Management   NaN
# 97   35cd2da6   Base         ✅ Deal                         Management   NaN
# 98   73297254    M+P         ✅ Deal             Mechanical Engineering   NaN
# 99   34bd3d91    M+P         ✅ Deal  Master of Business Administration   NaN
# 100  fef6c2b3    M+P         ✅ Deal                                GBS   NaN
# 101  e15e86b4    M+P         ✅ Deal                                GBS   NaN
# 102  cdb4b68d   Base         ✅ Deal                     Global Affairs   NaN
# 103  33365183    M+P         ✅ Deal                                MBA   NaN
# 104  fabc68b2   Base         ✅ Deal                         Management   NaN
# 105  526567fb    M+P         ✅ Deal                                      NaN
# 106  6a1f1023    M+P         ✅ Deal                         Management   NaN
# 107  746b9508    M+P         ✅ Deal                                      NaN
# 108  2527e1ea   Base         ✅ Deal                                MBA   NaN
# 109  4093ffc5    M+P         ✅ Deal        Global business and society   NaN
# 110  073b248f    M+P         ✅ Deal                                Law   NaN
# 111  82de1f8e    M+P  ⏸️ Incomplete                         Management   NaN
# 112  20260374    M+P         ✅ Deal        Global Business and Society   NaN
# 113  8fe436e8    M+P  ⏸️ Incomplete                         Management   NaN
# 114  c29a5a57    M+P  ⏸️ Incomplete                                MBA   NaN
# 115  7fe2649b   Base  ⏸️ Incomplete                                MBA   NaN
# 116  7f6097c2   Base  ⏸️ Incomplete                 Management Science   NaN
#
#      Rounds     Price  Duration   Time
# 46        5  $490,000      16.4  15:37
# 50        0       N/A       0.5  15:28
# 52        0       N/A       0.0  15:25
# 53        5       N/A      11.9  15:10
# 54        6  $545,000      18.6  15:09
# 55        0       N/A       0.5  15:09
# 56        6  $530,000      11.0  15:07
# 57        0       N/A       0.6  15:01
# 58        6  $570,000      20.5  15:00
# 59        6  $535,000       9.2  14:59
# 60        6  $600,000      14.9  14:57
# 61        2       N/A       8.5  14:52
# 62        6  $600,000      17.3  14:50
# 63        6  $537,500      17.6  14:50
# 64        0       N/A       0.7  14:49
# 65        4  $555,000      15.0  14:49
# 66        6       N/A      20.4  14:48
# 67        6  $540,000      29.4  14:48
# 68        6  $535,000      11.5  14:48
# 69        1       N/A       4.9  14:48
# 70        5  $550,000      28.4  14:48
# 71        5       N/A      21.9  14:47
# 72        6  $555,000      30.1  14:47
# 73        6  $550,000      20.8  14:47
# 74        6  $550,000      32.3  14:47
# 75        5  $540,000      10.9  14:47
# 76        6  $540,000      26.5  14:47
# 77        6  $560,000      18.6  14:47
# 78        6  $550,000      19.1  14:47
# 79        6  $555,000      25.2  14:47
# 80        6  $575,000      11.3  14:46
# 81        6  $590,000      21.2  14:46
# 82        6       N/A       8.0  14:46
# 83        5  $535,000      24.1  14:46
# 84        5  $545,000      13.8  14:46
# 85        4  $535,000      15.6  14:46
# 86        6  $480,000      22.9  14:46
# 87        6  $500,000      23.0  14:45
# 88        6  $595,000      18.6  14:45
# 89        6  $548,000      40.5  14:45
# 90        6  $550,000      29.5  14:45
# 91        4       N/A      11.8  14:44
# 92        6  $517,500      31.0  14:44
# 93        5  $545,000      18.4  14:43
# 94        7  $550,000      33.9  14:43
# 95        4       N/A      18.3  14:43
# 96        6  $560,000      22.3  14:43
# 97        6  $549,000      28.1  14:42
# 98        3  $505,000       6.7  14:42
# 99        6  $578,500      31.4  14:41
# 100       6  $520,000      32.3  14:41
# 101       5  $540,000      34.2  14:40
# 102       7  $650,000      27.1  14:40
# 103       6  $538,500      41.2  14:39
# 104       6  $535,000      42.7  14:39
# 105       5  $560,000      24.5  14:39
# 106       6  $510,000      28.9  14:39
# 107       6  $570,000      34.9  14:39
# 108       6  $575,000      18.6  14:39
# 109       6  $515,000      21.2  14:38
# 110       6  $525,000      33.7  14:38
# 111       0       N/A       0.7  14:38
# 112       6  $562,500      26.2  14:38
# 113       0       N/A       1.0  14:37
# 114       5       N/A      26.1  14:37
# 115       6       N/A      20.1  14:36
# 116       6       N/A      28.3  14:36
# ====================================================================================================
#                           🌆 AFTERNOON SESSION - SELLER ONLY (19:21-20:01)
# ====================================================================================================
#
# Total Seller Sessions: 41
# Successful Deals: 27 (65.9%)
# Failed Negotiations: 1
# Incomplete: -69
#
# 📊 Configuration Breakdown:
# Config
# Base    21
# M+P     20
#
# 🎯 Who Goes First:
# Series([], )
#
# --------------------------------------------------------------------------------
# 👥 Demographics
# --------------------------------------------------------------------------------
#
# 📚 Major:
#   MBA: 12
#   GBS: 10
#   : 5
#   Theater: 3
#   Business: 2
#   Management: 2
#   MBA Exchange: 1
#   Tech: 1
#   Global Business and Society: 1
#   2Y MBA: 1
#   School of Management: 1
#   Healthcare Management: 1
#   Master of Business Administration (MBA): 1
#
# ⚧ Gender:
#   Male: 16
#   Female: 15
#   : 10
#
# 💼 Experience:
#   A few instances: 19
#   Occasional: 10
#   : 10
#   None: 2
#
# --------------------------------------------------------------------------------
# 💰 Deal Price Analysis - SELLER PERSPECTIVE
# --------------------------------------------------------------------------------
# 📈 Remember: As SELLER, HIGHER prices are BETTER (Goal: Maximize price)
#
# 📊 Overall Price Statistics:
#   Average: $558,167
#   Median:  $555,000
#   Min:     $465,000
#   Max:     $650,000
#   Std Dev: $41,168
#
# --------------------------------------------------------------------------------
# 🔧 Configuration Deep Dive: BASE vs M+P
# --------------------------------------------------------------------------------
#
# ================================================================================
# 📊 Base Configuration - SELLER Results
# ================================================================================
# Total Deals: 13
# Average Price: $567,038 📈 (Higher is better for seller)
# Median Price:  $565,000
# Price Range: $465,000 - $650,000
# Std Dev: $47,199
#
# 🎯 Who Goes First Analysis:
#
#   👤 Student First (n=5):
#     Average: $588,800
#     Median:  $590,000
#     Range: $549,000 - $650,000
#
#   🤖 AI First (n=8):
#     Average: $553,438
#     Median:  $562,500
#     Range: $465,000 - $630,000
#
#   💡 Impact for SELLER:
#     Price difference: $35,362
#     ✅ BETTER for seller when student goes first (+$35,362)
#
# ================================================================================
# 📊 M+P Configuration - SELLER Results
# ================================================================================
# Total Deals: 14
# Average Price: $549,929 📈 (Higher is better for seller)
# Median Price:  $550,000
# Price Range: $505,000 - $630,000
# Std Dev: $34,372
#
# 🎯 Who Goes First Analysis:
#
#   👤 Student First (n=7):
#     Average: $548,429
#     Median:  $552,000
#     Range: $508,000 - $585,000
#
#   🤖 AI First (n=7):
#     Average: $551,429
#     Median:  $550,000
#     Range: $505,000 - $630,000
#
#   💡 Impact for SELLER:
#     Price difference: $3,000
#     ❌ WORSE for seller when student goes first ($-3,000)
#
# --------------------------------------------------------------------------------
# 📊 Summary Comparison Table - SELLER PERSPECTIVE
# --------------------------------------------------------------------------------
#   Config       Category   N Avg Price    Median              Range
# 0   Base        Overall  13  $567,038  $565,000  $465,000-$650,000
# 1   Base  Student First   5  $588,800  $590,000  $549,000-$650,000
# 2   Base       AI First   8  $553,438  $562,500  $465,000-$630,000
# 3    M+P        Overall  14  $549,929  $550,000  $505,000-$630,000
# 4    M+P  Student First   7  $548,429  $552,000  $508,000-$585,000
# 5    M+P       AI First   7  $551,429  $550,000  $505,000-$630,000
# --------------------------------------------------------------------------------
# ⏱️ Duration & Rounds Analysis
# --------------------------------------------------------------------------------
#
# Duration Statistics:
#   Average: 26.0 minutes
#   Median:  25.3 minutes
#   Range: 7.1 - 49.8 minutes
#
# Rounds Statistics:
#   Average: 5.6 rounds
#   Median:  6 rounds
#   Range: 4 - 8 rounds
#
# --------------------------------------------------------------------------------
# 📋 Detailed Session List - SELLER ONLY
# --------------------------------------------------------------------------------
#      Session Config        Outcome                                    Major  \
# 1   b37f26ac   Base         ✅ Deal                                  Theater
# 2   33f1a7e7   Base  ⏸️ Incomplete                                  Theater
# 3   1da9f9c4    M+P         ✅ Deal                                      GBS
# 4   0ad06bea   Base         ✅ Deal                                      MBA
# 5   d0f674cd    M+P  ⏸️ Incomplete                                      GBS
# 6   799f52db   Base         ✅ Deal                             MBA Exchange
# 7   95e44a5d   Base         ✅ Deal                                      MBA
# 8   16eceb2c    M+P         ✅ Deal                                      GBS
# 10  31db345d    M+P         ✅ Deal                                     Tech
# 11  88bdd965   Base         ✅ Deal
# 12  50f35769   Base         ✅ Deal                                 Business
# 13  1c047b8c    M+P         ✅ Deal
# 14  1accb1db    M+P         ✅ Deal              Global Business and Society
# 15  bb74becf   Base         ✅ Deal                                 Business
# 16  91bf642e    M+P         ✅ Deal                                      MBA
# 17  7443cda3    M+P         ✅ Deal                                      GBS
# 18  938b042a   Base  ⏸️ Incomplete                                   2Y MBA
# 19  562a5935   Base         ✅ Deal                                      GBS
# 20  0b0c3e36    M+P  ⏸️ Incomplete                                      GBS
# 21  efc8ced7    M+P         ✅ Deal                                      MBA
# 22  e4db51d8    M+P  ⏸️ Incomplete                                      MBA
# 23  2707b436    M+P  ⏸️ Incomplete                                  Theater
# 24  98028e11    M+P         ✅ Deal
# 25  9864a8ac   Base         ✅ Deal                                      GBS
# 26  19189653    M+P         ✅ Deal                                      MBA
# 27  65568ba8   Base         ✅ Deal                                      MBA
# 28  09116786   Base         ✅ Deal                               Management
# 29  350ef762   Base  ⏸️ Incomplete
# 30  f8b904d4    M+P         ✅ Deal                     School of Management
# 31  2b985adf   Base         ✅ Deal                                      GBS
# 32  538cd73f   Base  ⏸️ Incomplete                                      MBA
# 33  516685e6    M+P         ✅ Deal                                      GBS
# 34  ee8d9c66   Base  ⏸️ Incomplete                    Healthcare Management
# 35  d08ef3f9    M+P         ✅ Deal
# 36  e00fe024   Base       ❌ Failed                                      MBA
# 37  4eb7d6b7   Base         ✅ Deal                                      MBA
# 38  0edb4787    M+P         ✅ Deal                                      GBS
# 39  b19200a0   Base  ⏸️ Incomplete                                      MBA
# 40  4240e9c5   Base  ⏸️ Incomplete                                      MBA
# 41  6c890dba    M+P  ⏸️ Incomplete  Master of Business Administration (MBA)
# 42  20b90946    M+P  ⏸️ Incomplete                               Management
#
#    First  Rounds     Price  Duration   Time
# 1    NaN       4  $575,000       7.1  19:52
# 2    NaN       0       N/A       0.8  19:51
# 3    NaN       4  $515,000      29.1  19:49
# 4    NaN       6  $465,000      11.4  19:44
# 5    NaN       0       N/A       0.0  19:44
# 6    NaN       6  $549,000      27.0  19:39
# 7    NaN       6  $570,000       8.7  19:38
# 8    NaN       8  $585,000      42.6  19:37
# 10   NaN       5  $565,000      22.7  19:35
# 11   NaN       5  $565,000      20.5  19:35
# 12   NaN       5  $630,000      20.2  19:35
# 13   NaN       6  $550,000      25.3  19:35
# 14   NaN       6  $630,000      44.0  19:35
# 15   NaN       6  $600,000      18.4  19:35
# 16   NaN       6  $525,000      20.2  19:34
# 17   NaN       5  $540,000      18.1  19:34
# 18   NaN       5       N/A      19.5  19:34
# 19   NaN       6  $590,000      24.7  19:33
# 20   NaN       0       N/A       0.9  19:33
# 21   NaN       6  $560,000      24.0  19:33
# 22   NaN       0       N/A       1.2  19:32
# 23   NaN       3       N/A      13.5  19:32
# 24   NaN       6  $552,000      25.4  19:31
# 25   NaN       5  $512,500      20.3  19:31
# 26   NaN       5  $529,000      31.8  19:31
# 27   NaN       5  $560,000      26.6  19:30
# 28   NaN       6  $650,000      29.2  19:29
# 29   NaN       0       N/A       0.6  19:29
# 30   NaN       7  $585,000      41.2  19:28
# 31   NaN       6  $555,000      49.8  19:28
# 32   NaN       0       N/A       0.6  19:28
# 33   NaN       5  $505,000      38.1  19:28
# 34   NaN       5       N/A      23.7  19:27
# 35   NaN       5  $550,000      34.2  19:26
# 36   NaN       6       N/A      40.9  19:25
# 37   NaN       6  $550,000      11.5  19:23
# 38   NaN       5  $508,000      29.3  19:23
# 39   NaN       1       N/A       9.9  19:23
# 40   NaN       6       N/A      12.7  19:23
# 41   NaN       4       N/A      16.6  19:22
# 42   NaN       0       N/A       0.0  19:21
# ====================================================================================================
#                           ⚖️ MORNING vs AFTERNOON COMPARISON - SELLER ONLY
# ====================================================================================================
#       Period  Total Sessions  Deals Success Rate Avg Price Avg Rounds  \
# 0    Morning              67     49        73.1%  $547,888        5.7
# 1  Afternoon              41     27        65.9%  $558,167        5.6
#
#   Avg Duration
# 0     23.5 min
# 1     26.0 min
# ✅ Seller-only analysis complete!
# 📈 Remember: As SELLER, higher prices indicate better negotiation outcomes

# %% [markdown]
# ---
# ## 8. Close Database Connection

# %%
conn.close()
print("✅ Database connection closed")
# Out:
# ✅ Database connection closed
